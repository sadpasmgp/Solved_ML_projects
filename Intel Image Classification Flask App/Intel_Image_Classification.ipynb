# %% [markdown]
# # Intel Image Classification

# %% [markdown]
# In this project, we will be working on Intel images i.e. images of buildings, forest, street, etc. We will built a convolutional neural network and train it on this images. This is a multi class classification problem and we will use Keras.

# %%
# Important imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
from os import listdir
from sklearn.preprocessing import  LabelBinarizer
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array, array_to_img
from tensorflow.keras.optimizers import Adam
from PIL import Image
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers import Conv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense, LeakyReLU
from sklearn.model_selection import train_test_split

# %% [markdown]
# We will start by importing some required libraries.

# %% [markdown]
# We will check for folders of class images.

# %%
# Plotting 25 images to check dataset
plt.figure(figsize=(11,11))
path = "./Data/Intel Image Dataset/mountain"
for i in range(1,26):
    plt.subplot(5,5,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(listdir(path))))
    plt.imshow(rand_img)
    plt.title('mountain')
    plt.xlabel(rand_img.shape[1], fontsize = 10)
    plt.ylabel(rand_img.shape[0], fontsize = 10)

# %% [markdown]
# Let's visualize some of the mountain images that we will be working on. Also we will observe x and y dimensions of the image.

# %%
# Setting root directory path and creating empty list
dir = "./Data/Intel Image Dataset"
root_dir = listdir(dir)
image_list, label_list = [], []

# %% [markdown]
# Setting the root directory for the dataset and storing all the folders name of the dataset. We will also create 2 empty list for image and lables.

# %%
# Reading and converting image to numpy array
for directory in root_dir:
  for files in listdir(f"{dir}/{directory}"):
    image_path = f"{dir}/{directory}/{files}"
    image = Image.open(image_path)
    image = image.resize((150,150)) # All images does not have same dimension
    image = img_to_array(image)
    image_list.append(image)
    label_list.append(directory)

# %% [markdown]
# Next we need to resize images as some of the images don't have same dimensions. So, we will read and resize all the images. Then we will convert it into array and appending the list created above with the image and its label.

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts
# Out:
# glacier      553
# mountain     525
# sea          510
# street       501
# forest       474
# buildings    437
# dtype: int64

# %% [markdown]
# Checking for images per class.

# %%
# Checking count of classes
num_classes = len(label_counts)
num_classes
# Out:
# 6

# %% [markdown]
# Storing the number of classes which will be used further in model architecture.

# %%
# Checking x data shape
np.array(image_list).shape
# Out:
# (3000, 150, 150, 3)

# %% [markdown]
# Check the shape of the x data for input layer of model architecture.

# %%
# Checking y data shape
label_list = np.array(label_list)
label_list.shape
# Out:
# (3000,)

# %% [markdown]
# Checking the number of labels in y data which should be equal to total number of images.

# %%
# Splitting dataset into test and train
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %% [markdown]
# Now we will split our dataset into testing and training using train_test_split() from sklearn.

# %%
# Normalize and reshape data
x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape( -1, 150,150,3)
x_test = x_test.reshape( -1, 150,150,3)

# %% [markdown]
# Next we will normalize the images by dividing them with 255 and we will also reshape x_train and x_test data.

# %%
# Binarizing labels
lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.fit_transform(y_test)
print(lb.classes_)
# Out:
# ['buildings' 'forest' 'glacier' 'mountain' 'sea' 'street']

# %% [markdown]
# Here we will use label binarizer to one hot encode our y data. We will also print the sequence of the classes.

# %%
# Splitting the training data set into training and validation data sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %% [markdown]
# Now we will split the training data to validation and training data.

# %%
# Creating model architecture
model = Sequential([
        Conv2D(16, kernel_size = (3,3), input_shape = (150,150,3)),
        BatchNormalization(),
        LeakyReLU(),
          
        Conv2D(32, kernel_size = (3,3)),
        BatchNormalization(),
        LeakyReLU(),
        MaxPooling2D(5,5),
        
        Conv2D(64, kernel_size = (3,3)),
        BatchNormalization(),
        LeakyReLU(),
        
        Conv2D(128, kernel_size = (3,3)),
        BatchNormalization(),
        LeakyReLU(),
        MaxPooling2D(5,5),

        Flatten(),
    
        Dense(64),
        Dropout(rate = 0.2),
        BatchNormalization(),
        LeakyReLU(),
        
        Dense(32),
        Dropout(rate = 0.2),
        BatchNormalization(),
        LeakyReLU(),
    
        Dense(16),
        Dropout(rate = 0.2),
        BatchNormalization(),
        LeakyReLU(1),
    
        Dense(6, activation = 'softmax')    
        ])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 16)      448
#
#  batch_normalization (BatchN  (None, 148, 148, 16)     64
#  ormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 148, 148, 16)      0
#
#  conv2d_1 (Conv2D)           (None, 146, 146, 32)      4640
#
#  batch_normalization_1 (Batc  (None, 146, 146, 32)     128
#  hNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 146, 146, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 29, 29, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 27, 27, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 27, 27, 64)       256
#  hNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 27, 27, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 25, 25, 128)       73856
#
#  batch_normalization_3 (Batc  (None, 25, 25, 128)      512
#  hNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 25, 25, 128)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 3200)              0
#
#  dense (Dense)               (None, 64)                204864
#
#  dropout (Dropout)           (None, 64)                0
#
#  batch_normalization_4 (Batc  (None, 64)               256
#  hNormalization)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  batch_normalization_5 (Batc  (None, 32)               128
#  hNormalization)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 32)                0
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dropout_2 (Dropout)         (None, 16)                0
#
#  batch_normalization_6 (Batc  (None, 16)               64
#  hNormalization)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 16)                0
#
#  dense_3 (Dense)             (None, 6)                 102
#
# =================================================================
# Total params: 306,422
# Trainable params: 305,718
# Non-trainable params: 704
# _________________________________________________________________

# %% [markdown]
# Now we will create a network architecture for the model. We have used different types of layers according to their features namely BatchNormalization (Batch normalization is a technique for training very deep neural networks that standardizes the inputs to a layer for each mini-batch), LeakyRelu (The Leaky ReLU modifies the function to allow small negative values when the input is less than zero), Conv_2d (It is used to create a convolutional kernel that is convolved with the input layer to produce the output tensor), max_pooling2d (It is a downsampling technique which takes out the maximum value over the window defined by poolsize), flatten (It flattens the input and creates a 1D output), Dense (Dense layer produce the output as the dot product of input and kernel). In the last layer we will use softmax as the activation function because it is a multi class classification problem.

# %%
# Compiling model
model.compile(loss = 'categorical_crossentropy', 
              optimizer = Adam(0.0005),
              metrics=['accuracy'])

# %% [markdown]
# For compiling the model we need to pass 3 parameters namely loss, optimizer and metrics. Here we will use loss as categorical_crossentropy, optimizer as Adam and metrics as accuracy.

# %%
# Training the model
epochs = 70
batch_size = 128
history = model.fit(x_train, 
                    y_train, 
                    batch_size = batch_size, 
                    epochs = epochs, 
                    validation_data = (x_val, y_val))
# Out:
# Epoch 1/70
# 15/15 [==============================] - 30s 2s/step - loss: 1.5942 - accuracy: 0.4109 - val_loss: 1.7858 - val_accuracy: 0.2375
# Epoch 2/70
# 15/15 [==============================] - 30s 2s/step - loss: 1.2265 - accuracy: 0.5474 - val_loss: 1.9248 - val_accuracy: 0.2042
# Epoch 3/70
# 15/15 [==============================] - 30s 2s/step - loss: 1.0928 - accuracy: 0.6250 - val_loss: 1.9336 - val_accuracy: 0.1937
# Epoch 4/70
# 15/15 [==============================] - 29s 2s/step - loss: 0.9773 - accuracy: 0.6552 - val_loss: 1.9750 - val_accuracy: 0.1979
# Epoch 5/70
# 15/15 [==============================] - 28s 2s/step - loss: 0.8888 - accuracy: 0.7089 - val_loss: 2.0653 - val_accuracy: 0.1917
# Epoch 6/70
# 15/15 [==============================] - 29s 2s/step - loss: 0.8306 - accuracy: 0.7219 - val_loss: 2.1322 - val_accuracy: 0.1979
# Epoch 7/70
# 15/15 [==============================] - 29s 2s/step - loss: 0.7457 - accuracy: 0.7656 - val_loss: 2.2242 - val_accuracy: 0.1917
# Epoch 8/70
# 15/15 [==============================] - 28s 2s/step - loss: 0.6862 - accuracy: 0.8047 - val_loss: 2.4020 - val_accuracy: 0.2479
# Epoch 9/70
# 15/15 [==============================] - 29s 2s/step - loss: 0.6051 - accuracy: 0.8240 - val_loss: 2.4783 - val_accuracy: 0.2208
# Epoch 10/70
# 15/15 [==============================] - 28s 2s/step - loss: 0.5714 - accuracy: 0.8484 - val_loss: 2.2691 - val_accuracy: 0.2313
# Epoch 11/70
# 15/15 [==============================] - 28s 2s/step - loss: 0.4942 - accuracy: 0.8734 - val_loss: 2.4201 - val_accuracy: 0.2604
# Epoch 12/70
# 15/15 [==============================] - 29s 2s/step - loss: 0.4870 - accuracy: 0.8682 - val_loss: 2.2990 - val_accuracy: 0.2521
# Epoch 13/70
# 15/15 [==============================] - 30s 2s/step - loss: 0.4422 - accuracy: 0.8932 - val_loss: 2.2449 - val_accuracy: 0.2271
# Epoch 14/70
# 15/15 [==============================] - 29s 2s/step - loss: 0.3926 - accuracy: 0.9115 - val_loss: 2.3181 - val_accuracy: 0.2292
# Epoch 15/70
# 15/15 [==============================] - 30s 2s/step - loss: 0.3723 - accuracy: 0.9193 - val_loss: 2.0631 - val_accuracy: 0.2583
# Epoch 16/70
# 15/15 [==============================] - 29s 2s/step - loss: 0.3283 - accuracy: 0.9385 - val_loss: 2.2636 - val_accuracy: 0.2375
# Epoch 17/70
# 15/15 [==============================] - 31s 2s/step - loss: 0.2980 - accuracy: 0.9443 - val_loss: 1.9052 - val_accuracy: 0.2937
# Epoch 18/70
# 15/15 [==============================] - 28s 2s/step - loss: 0.2684 - accuracy: 0.9568 - val_loss: 1.5503 - val_accuracy: 0.4042
# Epoch 19/70
# 15/15 [==============================] - 28s 2s/step - loss: 0.2453 - accuracy: 0.9646 - val_loss: 1.6316 - val_accuracy: 0.3438
# Epoch 20/70
# 15/15 [==============================] - 28s 2s/step - loss: 0.2175 - accuracy: 0.9724 - val_loss: 1.6907 - val_accuracy: 0.4187
# Epoch 21/70
# 15/15 [==============================] - 29s 2s/step - loss: 0.2006 - accuracy: 0.9797 - val_loss: 1.3907 - val_accuracy: 0.4625
# Epoch 22/70
# 15/15 [==============================] - 28s 2s/step - loss: 0.2070 - accuracy: 0.9724 - val_loss: 1.2501 - val_accuracy: 0.4938
# Epoch 23/70
# 15/15 [==============================] - 28s 2s/step - loss: 0.1747 - accuracy: 0.9849 - val_loss: 1.0287 - val_accuracy: 0.6125
# Epoch 24/70
# 15/15 [==============================] - 28s 2s/step - loss: 0.1593 - accuracy: 0.9870 - val_loss: 1.0842 - val_accuracy: 0.5938
# Epoch 25/70
# 15/15 [==============================] - 30s 2s/step - loss: 0.1576 - accuracy: 0.9849 - val_loss: 1.0316 - val_accuracy: 0.6271
# Epoch 26/70
# 15/15 [==============================] - 30s 2s/step - loss: 0.1537 - accuracy: 0.9839 - val_loss: 0.8759 - val_accuracy: 0.6896
# Epoch 27/70
# 15/15 [==============================] - 29s 2s/step - loss: 0.1240 - accuracy: 0.9906 - val_loss: 0.8762 - val_accuracy: 0.6875
# Epoch 28/70
# 15/15 [==============================] - 31s 2s/step - loss: 0.1329 - accuracy: 0.9833 - val_loss: 0.8921 - val_accuracy: 0.6812
# Epoch 29/70
# 15/15 [==============================] - 34s 2s/step - loss: 0.1130 - accuracy: 0.9911 - val_loss: 0.7369 - val_accuracy: 0.7333
# Epoch 30/70
# 15/15 [==============================] - 32s 2s/step - loss: 0.1115 - accuracy: 0.9937 - val_loss: 0.9219 - val_accuracy: 0.6708
# Epoch 31/70
# 15/15 [==============================] - 31s 2s/step - loss: 0.1056 - accuracy: 0.9927 - val_loss: 0.7909 - val_accuracy: 0.7312
# Epoch 32/70
# 15/15 [==============================] - 32s 2s/step - loss: 0.1063 - accuracy: 0.9917 - val_loss: 0.7511 - val_accuracy: 0.7458
# Epoch 33/70
# 15/15 [==============================] - 29s 2s/step - loss: 0.0922 - accuracy: 0.9932 - val_loss: 0.7253 - val_accuracy: 0.7500
# Epoch 34/70
# 15/15 [==============================] - 30s 2s/step - loss: 0.0902 - accuracy: 0.9958 - val_loss: 0.6940 - val_accuracy: 0.7646
# Epoch 35/70
# 15/15 [==============================] - 30s 2s/step - loss: 0.0882 - accuracy: 0.9953 - val_loss: 0.6592 - val_accuracy: 0.7917
# Epoch 36/70
# 15/15 [==============================] - 30s 2s/step - loss: 0.0869 - accuracy: 0.9953 - val_loss: 0.7531 - val_accuracy: 0.7312
# Epoch 37/70
# 15/15 [==============================] - 29s 2s/step - loss: 0.0793 - accuracy: 0.9974 - val_loss: 0.6876 - val_accuracy: 0.7583
# Epoch 38/70
# 15/15 [==============================] - 31s 2s/step - loss: 0.0748 - accuracy: 0.9953 - val_loss: 0.8209 - val_accuracy: 0.7229
# Epoch 39/70
# 15/15 [==============================] - 30s 2s/step - loss: 0.0813 - accuracy: 0.9948 - val_loss: 0.7105 - val_accuracy: 0.7521
# Epoch 40/70
# 15/15 [==============================] - 30s 2s/step - loss: 0.0747 - accuracy: 0.9984 - val_loss: 0.7027 - val_accuracy: 0.7688
# Epoch 41/70
# 15/15 [==============================] - 29s 2s/step - loss: 0.0636 - accuracy: 0.9984 - val_loss: 0.6185 - val_accuracy: 0.7917
# Epoch 42/70
# 15/15 [==============================] - 29s 2s/step - loss: 0.0632 - accuracy: 0.9974 - val_loss: 0.6647 - val_accuracy: 0.7771
# Epoch 43/70
# 15/15 [==============================] - 28s 2s/step - loss: 0.0630 - accuracy: 0.9974 - val_loss: 0.6974 - val_accuracy: 0.7688
# Epoch 44/70
# 15/15 [==============================] - 29s 2s/step - loss: 0.0603 - accuracy: 0.9979 - val_loss: 0.7259 - val_accuracy: 0.7479
# Epoch 45/70
# 15/15 [==============================] - 29s 2s/step - loss: 0.0503 - accuracy: 0.9990 - val_loss: 0.7599 - val_accuracy: 0.7500
# Epoch 46/70
# 15/15 [==============================] - 29s 2s/step - loss: 0.0543 - accuracy: 0.9990 - val_loss: 0.6540 - val_accuracy: 0.7854
# Epoch 47/70
# 15/15 [==============================] - 29s 2s/step - loss: 0.0480 - accuracy: 0.9984 - val_loss: 0.6787 - val_accuracy: 0.7833
# Epoch 48/70
# 15/15 [==============================] - 30s 2s/step - loss: 0.0470 - accuracy: 0.9984 - val_loss: 0.6539 - val_accuracy: 0.7875
# Epoch 49/70
# 15/15 [==============================] - 29s 2s/step - loss: 0.0499 - accuracy: 0.9990 - val_loss: 0.6768 - val_accuracy: 0.7854
# Epoch 50/70
# 15/15 [==============================] - 30s 2s/step - loss: 0.0504 - accuracy: 0.9974 - val_loss: 0.7161 - val_accuracy: 0.7688
# Epoch 51/70
# 15/15 [==============================] - 30s 2s/step - loss: 0.0468 - accuracy: 0.9990 - val_loss: 0.8248 - val_accuracy: 0.7542
# Epoch 52/70
# 15/15 [==============================] - 31s 2s/step - loss: 0.0485 - accuracy: 0.9979 - val_loss: 0.7367 - val_accuracy: 0.7646
# Epoch 53/70
# 15/15 [==============================] - 32s 2s/step - loss: 0.0417 - accuracy: 0.9979 - val_loss: 0.8033 - val_accuracy: 0.7292
# Epoch 54/70
# 15/15 [==============================] - 29s 2s/step - loss: 0.0422 - accuracy: 0.9990 - val_loss: 0.8335 - val_accuracy: 0.7354
# Epoch 55/70
# 15/15 [==============================] - 31s 2s/step - loss: 0.0394 - accuracy: 0.9995 - val_loss: 0.7188 - val_accuracy: 0.7625
# Epoch 56/70
# 15/15 [==============================] - 29s 2s/step - loss: 0.0423 - accuracy: 0.9974 - val_loss: 0.6932 - val_accuracy: 0.7792
# Epoch 57/70
# 15/15 [==============================] - 29s 2s/step - loss: 0.0410 - accuracy: 0.9979 - val_loss: 0.7700 - val_accuracy: 0.7479
# Epoch 58/70
# 15/15 [==============================] - 32s 2s/step - loss: 0.0409 - accuracy: 0.9979 - val_loss: 0.9711 - val_accuracy: 0.7250
# Epoch 59/70
# 15/15 [==============================] - 29s 2s/step - loss: 0.0430 - accuracy: 0.9969 - val_loss: 0.7885 - val_accuracy: 0.7604
# Epoch 60/70
# 15/15 [==============================] - 29s 2s/step - loss: 0.0399 - accuracy: 0.9969 - val_loss: 0.7885 - val_accuracy: 0.7521
# Epoch 61/70
# 15/15 [==============================] - 30s 2s/step - loss: 0.0366 - accuracy: 0.9969 - val_loss: 0.9155 - val_accuracy: 0.7250
# Epoch 62/70
# 15/15 [==============================] - 30s 2s/step - loss: 0.0355 - accuracy: 0.9990 - val_loss: 0.8497 - val_accuracy: 0.7417
# Epoch 63/70
# 15/15 [==============================] - 31s 2s/step - loss: 0.0358 - accuracy: 0.9979 - val_loss: 0.7617 - val_accuracy: 0.7708
# Epoch 64/70
# 15/15 [==============================] - 29s 2s/step - loss: 0.0353 - accuracy: 0.9984 - val_loss: 0.9406 - val_accuracy: 0.7146
# Epoch 65/70
# 15/15 [==============================] - 30s 2s/step - loss: 0.0317 - accuracy: 0.9990 - val_loss: 0.8302 - val_accuracy: 0.7333
# Epoch 66/70
# 15/15 [==============================] - 30s 2s/step - loss: 0.0314 - accuracy: 0.9995 - val_loss: 0.7358 - val_accuracy: 0.7854
# Epoch 67/70
# 15/15 [==============================] - 31s 2s/step - loss: 0.0300 - accuracy: 0.9990 - val_loss: 0.7156 - val_accuracy: 0.7917
# Epoch 68/70
# 15/15 [==============================] - 31s 2s/step - loss: 0.0293 - accuracy: 0.9995 - val_loss: 0.6854 - val_accuracy: 0.7896
# Epoch 69/70
# 15/15 [==============================] - 30s 2s/step - loss: 0.0288 - accuracy: 0.9995 - val_loss: 0.6814 - val_accuracy: 0.7917
# Epoch 70/70
# 15/15 [==============================] - 30s 2s/step - loss: 0.0288 - accuracy: 0.9990 - val_loss: 0.7090 - val_accuracy: 0.7896

# %% [markdown]
# Fitting the model with the data and finding out the accuracy at each epoch to see how our model is learning. Now we will train our model on 70 epochs and a batch size of 128. You can try using more number of epochs to increase accuracy. During each epochs we can see how the model is performing by viewing the training and validation accuracy.

# %%
# Saving model
model.save("./intel_image.h5")

# %% [markdown]
# We will save the model using model.save() to use it later for prediction.

# %%
#Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# Next we will plot the accuracy of the model for the training history.

# %%
#Plot the loss history
plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], color='r')
plt.plot(history.history['val_loss'], color='b')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# Next we will plot the loss of the model for the training history.

# %%
# Calculating test accuracy 
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# 19/19 [==============================] - 2s 94ms/step - loss: 0.7883 - accuracy: 0.7933
# Test Accuracy: 79.3333351612091

# %% [markdown]
# Evaluating the model to know the accuracy of the model on the test data.

# %%
# Storing model predictions
y_pred = model.predict(x_test)

# %% [markdown]
# Generating predictions for test data and storing them into y_pred.

# %%
# Plotting image to compare
img = array_to_img(x_test[1])
img
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x18E6958A940>

# %% [markdown]
# Visualizing an image to be predicted in further steps.

# %%
# Finding max value from predition list and comaparing original value vs predicted
labels = lb.classes_
print(labels)
print("Originally : ",labels[np.argmax(y_test[1])])
print("Predicted : ",labels[np.argmax(y_pred[1])])
# Out:
# ['buildings' 'forest' 'glacier' 'mountain' 'sea' 'street']
# Originally :  buildings
# Predicted :  buildings

# %% [markdown]
# Now, we will create list of labels using object of label binarizer. We will print that list and finally we will print out the prediction and the original label of the image we visualized above using argmax().

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# In this project we saw how we can create a CNN using different layers. Normalizing is an important step when working with any type of dataset. We will use this model to predict the class of the image supplied to the model.

# %% [markdown]
# ## Scope:

# %% [markdown]
# This project has a vast scope, it can be used to classify satellite images, drone images, google images into different classes like sea, mountain, etc.
