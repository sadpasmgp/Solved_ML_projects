# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_json('https://www.mohfw.gov.in/data/datanew.json')
# Reading dataset

# %% [markdown]
# ### This above cell was last run on 12-01-2021, The dataset below is as of 12-01-2021.

# %%
df
# Loading dataset
# Out:
#     sno                                state_name  active  positive     cured  \
# 0     1               Andaman and Nicobar Islands       4     10029      9896
# 1     2                            Andhra Pradesh     507   2319066   2303829
# 2     3                         Arunachal Pradesh      12     64483     64175
# 3     4                                     Assam    1362    724181    716180
# 4     5                                     Bihar      49    830401    818097
# 5     6                                Chandigarh      43     91877     90669
# 6     7                              Chhattisgarh     194   1151892   1137664
# 7     8  Dadra and Nagar Haveli and Daman and Diu       1     11441     11436
# 8     9                                     Delhi     610   1863493   1836738
# 9    10                                       Goa      73    245239    241336
# 10   11                                   Gujarat     414   1223710   1212357
# 11   12                                   Haryana     603    984389    973192
# 12   13                          Himachal Pradesh     368    284293    279795
# 13   14                         Jammu and Kashmir     156    453505    448599
# 14   15                                 Jharkhand     167    435022    429540
# 15   16                                 Karnataka    2108   3944326   3902190
# 16   17                                 Kerala***    7822   6524988   6450028
# 17   18                                    Ladakh      54     28195     27913
# 18   19                               Lakshadweep       1     11402     11349
# 19   20                            Madhya Pradesh     341   1040821   1029747
# 20   21                               Maharashtra    5910   7872032   7722360
# 21   22                                   Manipur     108    137035    134807
# 22   23                                 Meghalaya      60     93702     92052
# 23   24                                   Mizoram    2233    222205    219298
# 24   25                                  Nagaland      39     35458     34661
# 25   26                                    Odisha     688   1286957   1277153
# 26   27                                Puducherry      14    165766    163790
# 27   28                                    Punjab     256    758875    740882
# 28   29                                 Rajasthan     653   1282523   1272319
# 29   30                                    Sikkim      13     39112     38650
# 30   31                                Tamil Nadu     796   3452215   3413394
# 31   32                                 Telangana     777    790637    785749
# 32   33                                   Tripura       1    100870     99950
# 33   34                               Uttarakhand     651    437003    428663
# 34   35                             Uttar Pradesh     924   2070187   2045771
# 35   36                               West Bengal    1169   2016675   1994314
# 36   37                                             29181  43004005  42458543
#
#      death  new_active  new_positive  new_cured  new_death death_reconsille  \
# 0      129           4         10029       9896        129
# 1    14730         536       2319141    2303875      14730
# 2      296          11         64483      64176        296
# 3     6639        1365        724185     716181       6639
# 4    12255          51        830408     818102      12255
# 5     1165          35         91880      90680       1165
# 6    14034         175       1151904    1137695      14034
# 7        4           1         11441      11436          4
# 8    26145         602       1863633    1836886      26145
# 9     3830          64        245243     241349       3830
# 10   10939         384       1223728    1212405      10939
# 11   10594         571        984457     973291      10595
# 12    4130         324        284304     279848       4132
# 13    4750         133        453520     448637       4750
# 14    5315         148        435027     429564       5315
# 15   40028        2055       3944432    3902344      40033
# 16   67182        7289       6525835    6451349      67197               44
# 17     228          47         28200      27925        228
# 18      52           0         11402      11350         52
# 19   10733         291       1040852    1029828      10733
# 20  143762        5684       7872203    7722754     143765
# 21    2120         103        137039     134816       2120
# 22    1590          60         93708      92058       1590
# 23     674        2127        222349     219548        674
# 24     758          38         35459      34663        758
# 25    9116         767       1287036    1277153       9116
# 26    1962          11        165766     163793       1962
# 27   17737         239        758894     740918      17737
# 28    9551         570       1282580    1272459       9551
# 29     449          13         39113      38651        449
# 30   38025         730       3452276    3413521      38025
# 31    4111         738        790689     785840       4111
# 32     919           1        100870      99950        919
# 33    7689         653        437018     428676       7689
# 34   23492         893       2070239    2045854      23492
# 35   21192        1089       2016737    1994455      21193
# 36  516281       27802      43006080   42461926     516352               44
#
#    total state_code
# 0                35
# 1                28
# 2                12
# 3                18
# 4                10
# 5                04
# 6                22
# 7                26
# 8                07
# 9                30
# 10               24
# 11     1         06
# 12     2         02
# 13               01
# 14               20
# 15     5         29
# 16    59         32
# 17               37
# 18               31
# 19               23
# 20     3         27
# 21               14
# 22               17
# 23               15
# 24               13
# 25               21
# 26               34
# 27               03
# 28               08
# 29               11
# 30               33
# 31               36
# 32               16
# 33               05
# 34               09
# 35     1         19
# 36    71

# %% [markdown]
# ### DataUnderstanding

# %%
df.shape
# There are 37 rows and 11 columns
# Out:
# (37, 13)

# %%
df.isnull().sum()
# no null values
# Out:
# sno                 0
# state_name          0
# active              0
# positive            0
# cured               0
# death               0
# new_active          0
# new_positive        0
# new_cured           0
# new_death           0
# death_reconsille    0
# total               0
# state_code          0
# dtype: int64

# %%
df.info()
# type of data present in the columns(int,object)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sno               37 non-null     int64
#  1   state_name        37 non-null     object
#  2   active            37 non-null     int64
#  3   positive          37 non-null     int64
#  4   cured             37 non-null     int64
#  5   death             37 non-null     int64
#  6   new_active        37 non-null     int64
#  7   new_positive      37 non-null     int64
#  8   new_cured         37 non-null     int64
#  9   new_death         37 non-null     int64
#  10  death_reconsille  37 non-null     object
#  11  total             37 non-null     object
#  12  state_code        37 non-null     object
# dtypes: int64(9), object(4)
# memory usage: 3.9+ KB

# %%
df.describe()
# Viewing the descriptive statistics of the data like mean, std deviation, min and max values present in the dataset
# Out:
#              sno        active      positive         cured          death  \
# count  37.000000     37.000000  3.700000e+01  3.700000e+01      37.000000
# mean   19.000000   1577.351351  2.324541e+06  2.295056e+06   27908.270270
# std    10.824355   4925.140896  7.090857e+06  7.000004e+06   86483.566187
# min     1.000000      1.000000  1.002900e+04  9.896000e+03       4.000000
# 25%    10.000000     49.000000  1.008700e+05  9.995000e+04    1165.000000
# 50%    19.000000    341.000000  7.241810e+05  7.161800e+05    6639.000000
# 75%    28.000000    777.000000  1.286957e+06  1.277153e+06   14730.000000
# max    37.000000  29181.000000  4.300400e+07  4.245854e+07  516281.000000
#
#          new_active  new_positive     new_cured      new_death
# count     37.000000  3.700000e+01  3.700000e+01      37.000000
# mean    1502.810811  2.324653e+06  2.295239e+06   27910.918919
# std     4688.353139  7.091203e+06  7.000568e+06   86495.000701
# min        0.000000  1.002900e+04  9.896000e+03       4.000000
# 25%       47.000000  1.008700e+05  9.995000e+04    1165.000000
# 50%      291.000000  7.241850e+05  7.161810e+05    6639.000000
# 75%      738.000000  1.287036e+06  1.277153e+06   14730.000000
# max    27802.000000  4.300608e+07  4.246193e+07  516352.000000

# %%
df.keys()
# Displaying all the column names present in data
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code'],
#       dtype='object')

# %%
df.columns
# Different code but same purpose as above that is displaying all column names
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code'],
#       dtype='object')

# %%
df.nunique()
# The nunique() function is used to count distinct observations over requested axis. It returns Series with number of distinct observations.
# Out:
# sno                 37
# state_name          37
# active              35
# positive            37
# cured               37
# death               37
# new_active          35
# new_positive        37
# new_cured           37
# new_death           37
# death_reconsille     2
# total                7
# state_code          37
# dtype: int64

# %%
df.tail()
# As we can see there is an extra row in the end that may be the total of that column
# Out:
#     sno     state_name  active  positive     cured   death  new_active  \
# 32   33        Tripura       1    100870     99950     919           1
# 33   34    Uttarakhand     651    437003    428663    7689         653
# 34   35  Uttar Pradesh     924   2070187   2045771   23492         893
# 35   36    West Bengal    1169   2016675   1994314   21192        1089
# 36   37                  29181  43004005  42458543  516281       27802
#
#     new_positive  new_cured  new_death death_reconsille total state_code
# 32        100870      99950        919                                16
# 33        437018     428676       7689                                05
# 34       2070239    2045854      23492                                09
# 35       2016737    1994455      21193                      1         19
# 36      43006080   42461926     516352               44    71

# %%
df=df.iloc[:36]
# we apply the iloc function and select all rows except the last row

# %%
df
# This is the dataset that we are to work on
# Out:
#     sno                                state_name  active  positive    cured  \
# 0     1               Andaman and Nicobar Islands       4     10029     9896
# 1     2                            Andhra Pradesh     507   2319066  2303829
# 2     3                         Arunachal Pradesh      12     64483    64175
# 3     4                                     Assam    1362    724181   716180
# 4     5                                     Bihar      49    830401   818097
# 5     6                                Chandigarh      43     91877    90669
# 6     7                              Chhattisgarh     194   1151892  1137664
# 7     8  Dadra and Nagar Haveli and Daman and Diu       1     11441    11436
# 8     9                                     Delhi     610   1863493  1836738
# 9    10                                       Goa      73    245239   241336
# 10   11                                   Gujarat     414   1223710  1212357
# 11   12                                   Haryana     603    984389   973192
# 12   13                          Himachal Pradesh     368    284293   279795
# 13   14                         Jammu and Kashmir     156    453505   448599
# 14   15                                 Jharkhand     167    435022   429540
# 15   16                                 Karnataka    2108   3944326  3902190
# 16   17                                 Kerala***    7822   6524988  6450028
# 17   18                                    Ladakh      54     28195    27913
# 18   19                               Lakshadweep       1     11402    11349
# 19   20                            Madhya Pradesh     341   1040821  1029747
# 20   21                               Maharashtra    5910   7872032  7722360
# 21   22                                   Manipur     108    137035   134807
# 22   23                                 Meghalaya      60     93702    92052
# 23   24                                   Mizoram    2233    222205   219298
# 24   25                                  Nagaland      39     35458    34661
# 25   26                                    Odisha     688   1286957  1277153
# 26   27                                Puducherry      14    165766   163790
# 27   28                                    Punjab     256    758875   740882
# 28   29                                 Rajasthan     653   1282523  1272319
# 29   30                                    Sikkim      13     39112    38650
# 30   31                                Tamil Nadu     796   3452215  3413394
# 31   32                                 Telangana     777    790637   785749
# 32   33                                   Tripura       1    100870    99950
# 33   34                               Uttarakhand     651    437003   428663
# 34   35                             Uttar Pradesh     924   2070187  2045771
# 35   36                               West Bengal    1169   2016675  1994314
#
#      death  new_active  new_positive  new_cured  new_death death_reconsille  \
# 0      129           4         10029       9896        129
# 1    14730         536       2319141    2303875      14730
# 2      296          11         64483      64176        296
# 3     6639        1365        724185     716181       6639
# 4    12255          51        830408     818102      12255
# 5     1165          35         91880      90680       1165
# 6    14034         175       1151904    1137695      14034
# 7        4           1         11441      11436          4
# 8    26145         602       1863633    1836886      26145
# 9     3830          64        245243     241349       3830
# 10   10939         384       1223728    1212405      10939
# 11   10594         571        984457     973291      10595
# 12    4130         324        284304     279848       4132
# 13    4750         133        453520     448637       4750
# 14    5315         148        435027     429564       5315
# 15   40028        2055       3944432    3902344      40033
# 16   67182        7289       6525835    6451349      67197               44
# 17     228          47         28200      27925        228
# 18      52           0         11402      11350         52
# 19   10733         291       1040852    1029828      10733
# 20  143762        5684       7872203    7722754     143765
# 21    2120         103        137039     134816       2120
# 22    1590          60         93708      92058       1590
# 23     674        2127        222349     219548        674
# 24     758          38         35459      34663        758
# 25    9116         767       1287036    1277153       9116
# 26    1962          11        165766     163793       1962
# 27   17737         239        758894     740918      17737
# 28    9551         570       1282580    1272459       9551
# 29     449          13         39113      38651        449
# 30   38025         730       3452276    3413521      38025
# 31    4111         738        790689     785840       4111
# 32     919           1        100870      99950        919
# 33    7689         653        437018     428676       7689
# 34   23492         893       2070239    2045854      23492
# 35   21192        1089       2016737    1994455      21193
#
#    total state_code
# 0                35
# 1                28
# 2                12
# 3                18
# 4                10
# 5                04
# 6                22
# 7                26
# 8                07
# 9                30
# 10               24
# 11     1         06
# 12     2         02
# 13               01
# 14               20
# 15     5         29
# 16    59         32
# 17               37
# 18               31
# 19               23
# 20     3         27
# 21               14
# 22               17
# 23               15
# 24               13
# 25               21
# 26               34
# 27               03
# 28               08
# 29               11
# 30               33
# 31               36
# 32               16
# 33               05
# 34               09
# 35     1         19

# %%
df['active'].sum(axis = 0) 
# The total number of active cases in India is 2,22,526
# Out:
# 29181

# %%
df['positive'].sum(axis = 0) 
# The total number of positive cases in India are 10,466,595
# Out:
# 43004005

# %%
df['cured'].sum(axis = 0)
# The total number of cured cases in India is 10,092,909
# Out:
# 42458543

# %%
df['death'].sum(axis = 0)
# The total number of deaths in India are 1,51,160
# Out:
# 516325

# %%
df['new_active'].sum(axis = 0)
# The total number of new active cases are 2,16,558
# Out:
# 27802

# %%
df['new_positive'].sum(axis = 0)
# The total number of new positive cases are 10,479,179
# Out:
# 43006080

# %%
df['new_cured'].sum(axis = 0)
# The total number of new cured cases are 10,111,294
# Out:
# 42461926

# %%
df['new_death'].sum(axis = 0)
# The total number of new death cases are 1,51,327
# Out:
# 516352

# %% [markdown]
# ### Data Visualization

# %%
sns.pairplot(data=df)
# plotting scatter plots of all data using pairplot

# %%
cases_df=df.sum()
# Storing total cases in cases_df
# Out:
# C:\Users\sadpa\AppData\Local\Temp\ipykernel_9768\3364601121.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   cases_df=df.sum()

# %%
cases_df
# Subset of original dataset
# Out:
# sno                                                           666
# state_name      Andaman and Nicobar IslandsAndhra PradeshAruna...
# active                                                      29181
# positive                                                 43004005
# cured                                                    42458543
# death                                                      516325
# new_active                                                  27802
# new_positive                                             43006080
# new_cured                                                42461926
# new_death                                                  516352
# total                                                     1255931
# state_code      3528121810042226073024060201202932373123271417...
# dtype: object

# %%
cases_df.drop(['sno','state_name','state_code'],inplace=True)
# Dropping unnecessary columns

# %%
cases_df
# Name of case types and their total number
# Out:
# active             29181
# positive        43004005
# cured           42458543
# death             516325
# new_active         27802
# new_positive    43006080
# new_cured       42461926
# new_death         516352
# total            1255931
# dtype: object

# %%
my_data = [29181,43004005,42458543,516325]
my_labels = 'Active','Positive','Cured','Death'
my_explode = (0,0,0,1.2)
my_colors = ['lightblue','lightsteelblue','lightpink','grey']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = False, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()
# Pie chart visualization

# %%
my_data = [216558,10479179,10111294,151327]
my_labels = 'New Active','New Positive','New Cured','New Death'
my_explode = (0,0,0,1.5)
my_colors = ['lightblue','lightsteelblue','lightpink','black']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()
# Pie chart visualization

# %%
my_data = [222526,10466595,10092909,151160,216558,10479179,10111294,151327]
my_labels = 'Active','Positive','Cured','Death','New Active','New Positive','New Cured','New Death'
my_explode = (0,0,0,0,0,0,0,1.5)
my_colors = ['gray','navajowhite','blanchedalmond','grey','lightblue','papayawhip','moccasin','lightpink']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()
# Pie chart visualization

# %%
plt.rcParams['figure.figsize']=(13,8)
# giving figure size

# %%
df[['state_name','active']].groupby(["state_name"]).mean().sort_values(by='active').plot.bar(color='purple')
plt.show()
# We can also use the groupby function to sort values in an ascending order based on the x-axis, y-axis and its keys
# Below we get a clear picture of the states in an increasing order based on their active level of cases.
# Kerela has a higher active cases compared to other states

# %%
df[['state_name','death']].groupby(["state_name"]).mean().sort_values(by='death').plot.bar(color='purple')
plt.show()
# We can also use the groupby function to sort values in an ascending order based on the x-axis, y-axis and its keys
# Below we get a clear picture of the states in an increasing order based on their death cases.
# Maharashtra has a higher death cases compared to other states

# %%
df.columns
# Displaying column names
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code'],
#       dtype='object')

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='active',color='teal',data=df);
# The visualization below shows us that high number of active cases are found in kerala followed by maharashtra

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='positive',color='teal',data=df);
# The below visualization shows us that high number of positive cases can be seen in Maharashtra followed by karnataka

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='cured',color='teal',data=df);
# The visualization below shows us that high number of people have cured in the state of Maharashtra followed by karnataka

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='death',color='teal',data=df);
# The below visualization shows us that high number of deaths taking place in the state of Maharashtra followed by Tamilnadu and karnataka

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_active',color='teal',data=df);
# The following visualization shows us the total number of new cases and kerela has the high number of new active cases

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_positive',color='teal',data=df);
# The following visualization shows us the total number of new positive cases and Maharashtra has the high number of new positive cases

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_cured',color='teal',data=df);
# The following visualization shows us the total number of new cured cases and Maharashtra has the high number of new cured cases

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_death',color='teal',data=df);
# Maharashtra has the highest new death rates in India followed by Karnataka

# %%
df.columns
# column names
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code'],
#       dtype='object')

# %%
df.drop(['sno','state_code'],axis=1,inplace=True)
# we have dropped columns like sno and statecode
# Out:
# C:\Users\sadpa\anaconda3\envs\pyspark\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.head(5)
# This is the resulting data
# Out:
#                     state_name  active  positive    cured  death  new_active  \
# 0  Andaman and Nicobar Islands       4     10029     9896    129           4
# 1               Andhra Pradesh     507   2319066  2303829  14730         536
# 2            Arunachal Pradesh      12     64483    64175    296          11
# 3                        Assam    1362    724181   716180   6639        1365
# 4                        Bihar      49    830401   818097  12255          51
#
#    new_positive  new_cured  new_death death_reconsille total
# 0         10029       9896        129
# 1       2319141    2303875      14730
# 2         64483      64176        296
# 3        724185     716181       6639
# 4        830408     818102      12255

# %%
df=df.set_index('state_name')
# Setting index as statename

# %%
df.head(5)
# Out:
#                              active  positive    cured  death  new_active  \
# state_name
# Andaman and Nicobar Islands       4     10029     9896    129           4
# Andhra Pradesh                  507   2319066  2303829  14730         536
# Arunachal Pradesh                12     64483    64175    296          11
# Assam                          1362    724181   716180   6639        1365
# Bihar                            49    830401   818097  12255          51
#
#                              new_positive  new_cured  new_death  \
# state_name
# Andaman and Nicobar Islands         10029       9896        129
# Andhra Pradesh                    2319141    2303875      14730
# Arunachal Pradesh                   64483      64176        296
# Assam                              724185     716181       6639
# Bihar                              830408     818102      12255
#
#                             death_reconsille total
# state_name
# Andaman and Nicobar Islands
# Andhra Pradesh
# Arunachal Pradesh
# Assam
# Bihar

# %%
df.plot.barh(stacked=True,figsize=(13,8))
# Stacked bar plot
# Out:
# <AxesSubplot:ylabel='state_name'>

# %%
df1=df[['cured', 'death']] 
df1.plot.barh(color={"cured": "purple", "death": "black"},figsize=(13,8))
# bar plot for cured and death
# Out:
# <AxesSubplot:ylabel='state_name'>

# %%
df2=df[['positive', 'death']] 
df2.plot.barh(color={"positive": "aquamarine", "death": "orange"},figsize=(13,8))
# bar plot for positive cases and death rate
# Out:
# <AxesSubplot:ylabel='state_name'>

# %%
df3=df[['death', 'cured']] 
df3.plot.barh(color={"death": "red", "cured": "grey"},figsize=(13,8))
# barplot for death cases and cured cases
# Out:
# <AxesSubplot:ylabel='state_name'>

# %%
df4=df[['active', 'death']] 
df4.plot.barh(color={"active": "black", "death": "orange"},figsize=(13,8))
# bar plot for active and death cases
# Out:
# <AxesSubplot:ylabel='state_name'>
