# %% [markdown]
# ## Dog Breed Prediction

# %% [markdown]
# In this project, we will see how to use Keras and TensorFlow to build, train, and test a Convolutional Neural Network capable of identifying the breed of a dog in a supplied image. This is a supervised learning problem, specifically a multiclass classification problem.

# %% [markdown]
# After searching the data next step would be downloading the data into collab notebook using references found in search option.

# %% [markdown]
# #### Please Download Dog Breed Dataset from Kaggle
# We will unzip the data which is downloaded and remove the irrelevant files.

# %%
# Important library imports
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

from tqdm import tqdm
from keras.preprocessing import image
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# Importing required libraries.

# %%
# Read the labels.csv file and checking shape and records
labels_all = pd.read_csv("labels.csv")
print(labels_all.shape)
labels_all.head()
# Out:
# (10222, 2)
#                                  id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever

# %% [markdown]
# Loading the labels data into dataframe and viewing it. Here we analysed that labels contains 10222 rows and 2 columns.

# %%
# Visualize the number of each breeds
breeds_all = labels_all["breed"]
breed_counts = breeds_all.value_counts()
breed_counts.head()
# Out:
# scottish_deerhound      126
# maltese_dog             117
# afghan_hound            116
# entlebucher             115
# bernese_mountain_dog    114
# Name: breed, dtype: int64

# %% [markdown]
# Here we are finding out the count per class i.e. total data in each class using value_counts() function.

# %%
# Selecting first 3 breeds (Limitation due to computation power)
CLASS_NAMES = ['scottish_deerhound','maltese_dog','bernese_mountain_dog']
labels = labels_all[(labels_all['breed'].isin(CLASS_NAMES))]
labels = labels.reset_index()
labels.head()
# Out:
#    index                                id                 breed
# 0      9  0042188c895a2f14ef64a918ed9c7b64    scottish_deerhound
# 1     12  00693b8bc2470375cc744a6391d397ec           maltese_dog
# 2     79  01e787576c003930f96c966f9c3e1d44    scottish_deerhound
# 3     90  022b34fd8734b39995a9f38a4f3e7b6b           maltese_dog
# 4    118  02d54f0dfb40038765e838459ae8c956  bernese_mountain_dog

# %% [markdown]
# We will work on only 3 breeds due to limited computational power. You can consider more classes as per your system computational power.

# %%
# Creating numpy matrix with zeros
X_data = np.zeros((len(labels), 224, 224, 3), dtype='float32')
# One hot encoding
Y_data = label_binarize(labels['breed'], classes = CLASS_NAMES)

# Reading and converting image to numpy array and normalizing dataset
for i in tqdm(range(len(labels))):
    img = image.load_img('train/%s.jpg' % labels['id'][i], target_size=(224, 224))
    img = image.img_to_array(img)
    x = np.expand_dims(img.copy(), axis=0)
    X_data[i] = x / 255.0
    
# Printing train image and one hot encode shape & size
print('\nTrain Images shape: ',X_data.shape,' size: {:,}'.format(X_data.size))
print('One-hot encoded output shape: ',Y_data.shape,' size: {:,}'.format(Y_data.size))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 357/357 [00:02<00:00, 165.31it/s]
# Train Images shape:  (357, 224, 224, 3)  size: 53,738,496
# One-hot encoded output shape:  (357, 3)  size: 1,071

# %% [markdown]
# As we are working with the classification dataset first we need to one hot encode the target value i.e. the classes. After that we will read images and convert them into numpy array and finally normalizing the array.

# %%
# Building the Model
model = Sequential()

model.add(Conv2D(filters = 64, kernel_size = (5,5), activation ='relu', input_shape = (224,224,3)))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 32, kernel_size = (3,3), activation ='relu', kernel_regularizer = 'l2'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 16, kernel_size = (7,7), activation ='relu', kernel_regularizer = 'l2'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 8, kernel_size = (5,5), activation ='relu', kernel_regularizer = 'l2'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(128, activation = "relu", kernel_regularizer = 'l2'))
model.add(Dense(64, activation = "relu", kernel_regularizer = 'l2'))
model.add(Dense(len(CLASS_NAMES), activation = "softmax"))

model.compile(loss = 'categorical_crossentropy', 
              optimizer = Adam(0.0001),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 220, 220, 64)      4864
#
#  max_pooling2d (MaxPooling2D  (None, 110, 110, 64)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 108, 108, 32)      18464
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 16)        25104
#
#  max_pooling2d_2 (MaxPooling  (None, 24, 24, 16)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 20, 20, 8)         3208
#
#  max_pooling2d_3 (MaxPooling  (None, 10, 10, 8)        0
#  2D)
#
#  flatten (Flatten)           (None, 800)               0
#
#  dense (Dense)               (None, 128)               102528
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 162,619
# Trainable params: 162,619
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Next we will create a network architecture for the model. We have used different types of layers according to their features namely Conv_2d (It is used to create a convolutional kernel that is convolved with the input layer to produce the output tensor), max_pooling2d (It is a downsampling technique which takes out the maximum value over the window defined by poolsize), flatten (It flattens the input and creates a 1D output), Dense (Dense layer produce the output as the dot product of input and kernel).

# %% [markdown]
# After defining the network architecture we found out the total parameters as 162,619.

# %%
# Splitting the data set into training and testing data sets
X_train_and_val, X_test, Y_train_and_val, Y_test = train_test_split(X_data, Y_data, test_size = 0.1)
# Splitting the training data set into training and validation data sets
X_train, X_val, Y_train, Y_val = train_test_split(X_train_and_val, Y_train_and_val, test_size = 0.2)

# %% [markdown]
# After defining the network architecture we will start with splitting the test and train data then dividing train data in train and validation data.

# %%
# Training the model
epochs = 100
batch_size = 128

history = model.fit(X_train, Y_train, 
                    batch_size = batch_size, 
                    epochs = epochs, 
                    validation_data = (X_val, Y_val),
                   )
# Out:
# Epoch 1/100
# 2/2 [==============================] - 10s 5s/step - loss: 4.8954 - accuracy: 0.3281 - val_loss: 4.8807 - val_accuracy: 0.4000
# Epoch 2/100
# 2/2 [==============================] - 8s 4s/step - loss: 4.8670 - accuracy: 0.3906 - val_loss: 4.8533 - val_accuracy: 0.3385
# Epoch 3/100
# 2/2 [==============================] - 8s 4s/step - loss: 4.8409 - accuracy: 0.3789 - val_loss: 4.8292 - val_accuracy: 0.3385
# Epoch 4/100
# 2/2 [==============================] - 8s 4s/step - loss: 4.8158 - accuracy: 0.3750 - val_loss: 4.8050 - val_accuracy: 0.3385
# Epoch 5/100
# 2/2 [==============================] - 8s 4s/step - loss: 4.7898 - accuracy: 0.3789 - val_loss: 4.7833 - val_accuracy: 0.3538
# Epoch 6/100
# 2/2 [==============================] - 8s 4s/step - loss: 4.7653 - accuracy: 0.3789 - val_loss: 4.7602 - val_accuracy: 0.3538
# Epoch 7/100
# 2/2 [==============================] - 8s 4s/step - loss: 4.7400 - accuracy: 0.3789 - val_loss: 4.7348 - val_accuracy: 0.3538
# Epoch 8/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.7144 - accuracy: 0.3750 - val_loss: 4.7109 - val_accuracy: 0.3385
# Epoch 9/100
# 2/2 [==============================] - 9s 4s/step - loss: 4.6899 - accuracy: 0.3750 - val_loss: 4.6880 - val_accuracy: 0.3538
# Epoch 10/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.6641 - accuracy: 0.3789 - val_loss: 4.6643 - val_accuracy: 0.3692
# Epoch 11/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.6389 - accuracy: 0.3906 - val_loss: 4.6403 - val_accuracy: 0.3846
# Epoch 12/100
# 2/2 [==============================] - 8s 4s/step - loss: 4.6137 - accuracy: 0.3984 - val_loss: 4.6148 - val_accuracy: 0.3846
# Epoch 13/100
# 2/2 [==============================] - 9s 4s/step - loss: 4.5874 - accuracy: 0.3984 - val_loss: 4.5892 - val_accuracy: 0.3846
# Epoch 14/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.5614 - accuracy: 0.4258 - val_loss: 4.5626 - val_accuracy: 0.3846
# Epoch 15/100
# 2/2 [==============================] - 8s 4s/step - loss: 4.5348 - accuracy: 0.4297 - val_loss: 4.5361 - val_accuracy: 0.4462
# Epoch 16/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.5072 - accuracy: 0.4648 - val_loss: 4.5064 - val_accuracy: 0.4615
# Epoch 17/100
# 2/2 [==============================] - 8s 4s/step - loss: 4.4795 - accuracy: 0.4883 - val_loss: 4.4777 - val_accuracy: 0.4769
# Epoch 18/100
# 2/2 [==============================] - 8s 4s/step - loss: 4.4492 - accuracy: 0.4844 - val_loss: 4.4481 - val_accuracy: 0.4615
# Epoch 19/100
# 2/2 [==============================] - 8s 4s/step - loss: 4.4182 - accuracy: 0.4961 - val_loss: 4.4155 - val_accuracy: 0.4615
# Epoch 20/100
# 2/2 [==============================] - 9s 4s/step - loss: 4.3848 - accuracy: 0.5117 - val_loss: 4.3813 - val_accuracy: 0.4769
# Epoch 21/100
# 2/2 [==============================] - 8s 4s/step - loss: 4.3507 - accuracy: 0.5234 - val_loss: 4.3445 - val_accuracy: 0.4923
# Epoch 22/100
# 2/2 [==============================] - 9s 4s/step - loss: 4.3143 - accuracy: 0.5742 - val_loss: 4.3022 - val_accuracy: 0.6000
# Epoch 23/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.2744 - accuracy: 0.6250 - val_loss: 4.2695 - val_accuracy: 0.5692
# Epoch 24/100
# 2/2 [==============================] - 8s 4s/step - loss: 4.2343 - accuracy: 0.6250 - val_loss: 4.2312 - val_accuracy: 0.5846
# Epoch 25/100
# 2/2 [==============================] - 9s 4s/step - loss: 4.1913 - accuracy: 0.6367 - val_loss: 4.1796 - val_accuracy: 0.6462
# Epoch 26/100
# 2/2 [==============================] - 8s 4s/step - loss: 4.1491 - accuracy: 0.6641 - val_loss: 4.1422 - val_accuracy: 0.6462
# Epoch 27/100
# 2/2 [==============================] - 8s 4s/step - loss: 4.1034 - accuracy: 0.6602 - val_loss: 4.0989 - val_accuracy: 0.6462
# Epoch 28/100
# 2/2 [==============================] - 9s 4s/step - loss: 4.0617 - accuracy: 0.6680 - val_loss: 4.0610 - val_accuracy: 0.6769
# Epoch 29/100
# 2/2 [==============================] - 9s 5s/step - loss: 4.0123 - accuracy: 0.7031 - val_loss: 4.0186 - val_accuracy: 0.6462
# Epoch 30/100
# 2/2 [==============================] - 9s 4s/step - loss: 3.9731 - accuracy: 0.7305 - val_loss: 3.9866 - val_accuracy: 0.6923
# Epoch 31/100
# 2/2 [==============================] - 8s 4s/step - loss: 3.9275 - accuracy: 0.7344 - val_loss: 3.9462 - val_accuracy: 0.6615
# Epoch 32/100
# 2/2 [==============================] - 9s 4s/step - loss: 3.8861 - accuracy: 0.7227 - val_loss: 3.9238 - val_accuracy: 0.6923
# Epoch 33/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.8465 - accuracy: 0.7383 - val_loss: 3.8787 - val_accuracy: 0.6769
# Epoch 34/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.8216 - accuracy: 0.7305 - val_loss: 3.8654 - val_accuracy: 0.6923
# Epoch 35/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.7811 - accuracy: 0.7305 - val_loss: 3.8152 - val_accuracy: 0.7231
# Epoch 36/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.7434 - accuracy: 0.7422 - val_loss: 3.7815 - val_accuracy: 0.7077
# Epoch 37/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.7024 - accuracy: 0.7578 - val_loss: 3.7619 - val_accuracy: 0.6923
# Epoch 38/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.6947 - accuracy: 0.7773 - val_loss: 3.7312 - val_accuracy: 0.7231
# Epoch 39/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.6535 - accuracy: 0.7695 - val_loss: 3.7109 - val_accuracy: 0.7077
# Epoch 40/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.6344 - accuracy: 0.7812 - val_loss: 3.7026 - val_accuracy: 0.7538
# Epoch 41/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.5957 - accuracy: 0.7656 - val_loss: 3.6768 - val_accuracy: 0.7077
# Epoch 42/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.5656 - accuracy: 0.7930 - val_loss: 3.6992 - val_accuracy: 0.7692
# Epoch 43/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.5516 - accuracy: 0.8047 - val_loss: 3.6341 - val_accuracy: 0.7231
# Epoch 44/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.5195 - accuracy: 0.8008 - val_loss: 3.6206 - val_accuracy: 0.7231
# Epoch 45/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.5096 - accuracy: 0.8164 - val_loss: 3.6188 - val_accuracy: 0.7692
# Epoch 46/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.4947 - accuracy: 0.8008 - val_loss: 3.5912 - val_accuracy: 0.7385
# Epoch 47/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.4698 - accuracy: 0.8125 - val_loss: 3.6017 - val_accuracy: 0.7385
# Epoch 48/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.4435 - accuracy: 0.8125 - val_loss: 3.5623 - val_accuracy: 0.7231
# Epoch 49/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.4078 - accuracy: 0.8477 - val_loss: 3.5709 - val_accuracy: 0.7692
# Epoch 50/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.4059 - accuracy: 0.8320 - val_loss: 3.5427 - val_accuracy: 0.7538
# Epoch 51/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.3602 - accuracy: 0.8594 - val_loss: 3.5205 - val_accuracy: 0.7231
# Epoch 52/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.3453 - accuracy: 0.8438 - val_loss: 3.5291 - val_accuracy: 0.7538
# Epoch 53/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.3328 - accuracy: 0.8516 - val_loss: 3.4950 - val_accuracy: 0.7692
# Epoch 54/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.3169 - accuracy: 0.8438 - val_loss: 3.4910 - val_accuracy: 0.7385
# Epoch 55/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.2935 - accuracy: 0.8672 - val_loss: 3.5005 - val_accuracy: 0.7538
# Epoch 56/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.2752 - accuracy: 0.8672 - val_loss: 3.4623 - val_accuracy: 0.7538
# Epoch 57/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.2606 - accuracy: 0.8516 - val_loss: 3.4563 - val_accuracy: 0.7692
# Epoch 58/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.2329 - accuracy: 0.8828 - val_loss: 3.4515 - val_accuracy: 0.7846
# Epoch 59/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.2099 - accuracy: 0.8828 - val_loss: 3.4279 - val_accuracy: 0.7231
# Epoch 60/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.2006 - accuracy: 0.8711 - val_loss: 3.4273 - val_accuracy: 0.7692
# Epoch 61/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.1890 - accuracy: 0.8867 - val_loss: 3.4084 - val_accuracy: 0.7692
# Epoch 62/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.1558 - accuracy: 0.9062 - val_loss: 3.3949 - val_accuracy: 0.7231
# Epoch 63/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.1561 - accuracy: 0.8750 - val_loss: 3.4013 - val_accuracy: 0.7692
# Epoch 64/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.1360 - accuracy: 0.8945 - val_loss: 3.3910 - val_accuracy: 0.7692
# Epoch 65/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.1260 - accuracy: 0.8906 - val_loss: 3.3646 - val_accuracy: 0.7385
# Epoch 66/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.0893 - accuracy: 0.9141 - val_loss: 3.3891 - val_accuracy: 0.7385
# Epoch 67/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.0970 - accuracy: 0.9023 - val_loss: 3.3455 - val_accuracy: 0.7385
# Epoch 68/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.0743 - accuracy: 0.8789 - val_loss: 3.3333 - val_accuracy: 0.7538
# Epoch 69/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.0568 - accuracy: 0.9023 - val_loss: 3.3845 - val_accuracy: 0.7538
# Epoch 70/100
# 2/2 [==============================] - 10s 5s/step - loss: 3.0451 - accuracy: 0.8984 - val_loss: 3.3181 - val_accuracy: 0.7231
# Epoch 71/100
# 2/2 [==============================] - 9s 5s/step - loss: 3.0283 - accuracy: 0.8984 - val_loss: 3.3139 - val_accuracy: 0.7538
# Epoch 72/100
# 2/2 [==============================] - 10s 5s/step - loss: 2.9931 - accuracy: 0.9336 - val_loss: 3.3141 - val_accuracy: 0.7538
# Epoch 73/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.9819 - accuracy: 0.9180 - val_loss: 3.2790 - val_accuracy: 0.7538
# Epoch 74/100
# 2/2 [==============================] - 10s 5s/step - loss: 2.9720 - accuracy: 0.9258 - val_loss: 3.2797 - val_accuracy: 0.7538
# Epoch 75/100
# 2/2 [==============================] - 10s 5s/step - loss: 2.9463 - accuracy: 0.9336 - val_loss: 3.2635 - val_accuracy: 0.7385
# Epoch 76/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.9346 - accuracy: 0.9297 - val_loss: 3.2573 - val_accuracy: 0.7538
# Epoch 77/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.9234 - accuracy: 0.9258 - val_loss: 3.2573 - val_accuracy: 0.7231
# Epoch 78/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.8993 - accuracy: 0.9453 - val_loss: 3.2406 - val_accuracy: 0.7538
# Epoch 79/100
# 2/2 [==============================] - 10s 5s/step - loss: 2.8923 - accuracy: 0.9297 - val_loss: 3.2458 - val_accuracy: 0.7538
# Epoch 80/100
# 2/2 [==============================] - 10s 5s/step - loss: 2.8731 - accuracy: 0.9336 - val_loss: 3.2340 - val_accuracy: 0.7385
# Epoch 81/100
# 2/2 [==============================] - 10s 5s/step - loss: 2.8646 - accuracy: 0.9297 - val_loss: 3.2227 - val_accuracy: 0.7385
# Epoch 82/100
# 2/2 [==============================] - 10s 5s/step - loss: 2.8448 - accuracy: 0.9453 - val_loss: 3.2154 - val_accuracy: 0.7538
# Epoch 83/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.8268 - accuracy: 0.9414 - val_loss: 3.2258 - val_accuracy: 0.7231
# Epoch 84/100
# 2/2 [==============================] - 10s 5s/step - loss: 2.8170 - accuracy: 0.9453 - val_loss: 3.1999 - val_accuracy: 0.7385
# Epoch 85/100
# 2/2 [==============================] - 10s 5s/step - loss: 2.8027 - accuracy: 0.9453 - val_loss: 3.1966 - val_accuracy: 0.7385
# Epoch 86/100
# 2/2 [==============================] - 10s 5s/step - loss: 2.7852 - accuracy: 0.9492 - val_loss: 3.1936 - val_accuracy: 0.7385
# Epoch 87/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.7723 - accuracy: 0.9531 - val_loss: 3.1866 - val_accuracy: 0.7231
# Epoch 88/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.7581 - accuracy: 0.9531 - val_loss: 3.1843 - val_accuracy: 0.7538
# Epoch 89/100
# 2/2 [==============================] - 10s 5s/step - loss: 2.7465 - accuracy: 0.9570 - val_loss: 3.1752 - val_accuracy: 0.7231
# Epoch 90/100
# 2/2 [==============================] - 10s 5s/step - loss: 2.7318 - accuracy: 0.9492 - val_loss: 3.1801 - val_accuracy: 0.7385
# Epoch 91/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.7264 - accuracy: 0.9609 - val_loss: 3.1665 - val_accuracy: 0.7385
# Epoch 92/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.7129 - accuracy: 0.9492 - val_loss: 3.1600 - val_accuracy: 0.7231
# Epoch 93/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.7009 - accuracy: 0.9492 - val_loss: 3.1652 - val_accuracy: 0.7231
# Epoch 94/100
# 2/2 [==============================] - 9s 4s/step - loss: 2.6783 - accuracy: 0.9570 - val_loss: 3.1450 - val_accuracy: 0.7538
# Epoch 95/100
# 2/2 [==============================] - 9s 5s/step - loss: 2.6688 - accuracy: 0.9570 - val_loss: 3.1636 - val_accuracy: 0.7231
# Epoch 96/100
# 2/2 [==============================] - 9s 4s/step - loss: 2.6547 - accuracy: 0.9648 - val_loss: 3.1342 - val_accuracy: 0.7538
# Epoch 97/100
# 2/2 [==============================] - 8s 4s/step - loss: 2.6492 - accuracy: 0.9609 - val_loss: 3.1442 - val_accuracy: 0.7231
# Epoch 98/100
# 2/2 [==============================] - 9s 4s/step - loss: 2.6257 - accuracy: 0.9688 - val_loss: 3.1436 - val_accuracy: 0.7538
# Epoch 99/100
# 2/2 [==============================] - 8s 4s/step - loss: 2.6138 - accuracy: 0.9648 - val_loss: 3.1210 - val_accuracy: 0.7538
# Epoch 100/100
# 2/2 [==============================] - 8s 4s/step - loss: 2.6093 - accuracy: 0.9688 - val_loss: 3.1215 - val_accuracy: 0.7231

# %% [markdown]
# Now we will train our model on 100 epochs and a batch size of 128. You can try using more number of epochs to increase accuracy. During each epochs we can see how the model is performing by viewing the training and validation accuracy.

# %%
# Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %% [markdown]
# Here we analyse how the model is learning with each epoch in terms of accuracy.

# %%
Y_pred = model.predict(X_test)
score = model.evaluate(X_test, Y_test)
print('Accuracy over the test set: \n ', round((score[1]*100), 2), '%')
# Out:
# 2/2 [==============================] - 0s 24ms/step - loss: 3.1982 - accuracy: 0.8056
# Accuracy over the test set:
#   80.56 %

# %% [markdown]
# We will use predict function to make predictions using this model also we are finding out the accuracy on the test set.

# %%
# Plotting image to compare
plt.imshow(X_test[1,:,:,:])
plt.show()

# Finding max value from predition list and comaparing original value vs predicted
print("Originally : ",labels['breed'][np.argmax(Y_test[1])])
print("Predicted : ",labels['breed'][np.argmax(Y_pred[1])])
# Out:
# Originally :  scottish_deerhound
# Predicted :  scottish_deerhound

# %%
# Plotting image to compare
plt.imshow(X_test[3,:,:,:])
plt.show()

# Finding max value from predition list and comaparing original value vs predicted
print("Originally : ",labels['breed'][np.argmax(Y_test[3])])
print("Predicted : ",labels['breed'][np.argmax(Y_pred[3])])
# Out:
# Originally :  scottish_deerhound
# Predicted :  scottish_deerhound

# %%
# Plotting image to compare
plt.imshow(X_test[7,:,:,:])
plt.show()

# Finding max value from predition list and comaparing original value vs predicted
print("Originally : ",labels['breed'][np.argmax(Y_test[7])])
print("Predicted : ",labels['breed'][np.argmax(Y_pred[7])])
# Out:
# Originally :  maltese_dog
# Predicted :  maltese_dog

# %% [markdown]
# Here you can see image with its original and predicted label.

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# We started with downloading the dataset creating the model and finding out the predictions using the model. We can optimize different hyper parameters in order to tune this model for a higher accuracy. This model can be used to predict different breeds of dogs which can be further used by different NGO's working on saving animals and for educational purposes also.
