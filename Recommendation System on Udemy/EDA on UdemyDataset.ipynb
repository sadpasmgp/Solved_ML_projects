# %% [markdown]
# ### Questions to Solve
#
# + Course Title
# 	- What is the most frequent words in course title
# 	- Longest/Shortest course title
# 	- How can we build recommendation systems via title using similarity
# 	- Most famous courses by number of subscribers
#
# + Subjects/Category
# 	- What is the distribution of subjects
# 	- How many courses per subject
# 	- Distribution of subjects per year
# 	- How many people purchase a particular subject
# 	- Which subject is the most popular
#
# + Published Year
# 	- Number of courses per year
# 	- Which year has the highest number of courses
# 	- What is the trend of courses per year
#
# + Levels
# 	- How many levels do we have
# 	- What is the distribution of courses per levels
# 	- Which subject have the highest levels
# 	- How many subscribers per levels
# 	- How many courses per levels
#
# + Duration of Course
# 	- Which courses have the highest duration (paid or not)
# 	- Which courses have higher duration
# 	- Duration vs number of subscribers
#
# + Subscribers
# 	- Which course have the highest number of subscribers
# 	- Average number of subscribers
# 	- Number of subscribers per Subject
# 	- Number of subscribers per year
#
# + Price
# 	- What is the average price of a course
# 	- What is the min/max price
# 	- How much does Udemy earn
# 	- The most profitable courses
#
# + Correlation Questions
# 	- Does number of subscribers depend on
# 	- number of reviews
# 	- price
# 	- number of lectures
# 	- content duration

# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('udemy_course_data.csv')
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
# 3             2451           11            36          All Levels
# 4             1276           45            26  Intermediate Level
#
#   content_duration   published_timestamp           subject  profit  \
# 0        1.5 hours  2017-01-18T20:58:58Z  Business Finance  429400
# 1         39 hours  2017-03-09T16:34:20Z  Business Finance  209400
# 2        2.5 hours  2016-12-19T19:26:30Z  Business Finance   97830
# 3          3 hours  2017-05-30T20:07:24Z  Business Finance  232845
# 4          2 hours  2016-12-13T14:57:18Z  Business Finance  255200
#
#   published_date published_time  year  month  day
# 0     2017-01-18      20:58:58Z  2017      1   18
# 1     2017-03-09      16:34:20Z  2017      3    9
# 2     2016-12-19      19:26:30Z  2016     12   19
# 3     2017-05-30      20:07:24Z  2017      5   30
# 4     2016-12-13      14:57:18Z  2016     12   13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3683 entries, 0 to 3682
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3683 non-null   int64
#  1   course_title         3683 non-null   object
#  2   url                  3683 non-null   object
#  3   is_paid              3683 non-null   bool
#  4   price                3683 non-null   int64
#  5   num_subscribers      3683 non-null   int64
#  6   num_reviews          3683 non-null   int64
#  7   num_lectures         3683 non-null   int64
#  8   level                3683 non-null   object
#  9   content_duration     3683 non-null   object
#  10  published_timestamp  3683 non-null   object
#  11  subject              3683 non-null   object
#  12  profit               3683 non-null   int64
#  13  published_date       3683 non-null   object
#  14  published_time       3682 non-null   object
#  15  year                 3683 non-null   int64
#  16  month                3683 non-null   int64
#  17  day                  3683 non-null   int64
# dtypes: bool(1), int64(9), object(8)
# memory usage: 492.9+ KB

# %% [markdown]
# ### EDA on Subject/Category
#
# + Subjects/Category
# 	- What is the distribution of subjects
# 	- How many courses per subject
# 	- Distribution of subjects per year
# 	- How many people purchase a particular subject
# 	- Which subject is the most popular

# %%
len(df['course_title'].unique())
# Out:
# 3668

# %%
plt.figure(figsize=(15,7))
sn.countplot(df['subject'],palette='plasma')
# Out:
# C:\Users\sadpa\anaconda3\envs\pyspark\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='subject', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
df['subject'].value_counts().plot(kind='pie')
plt.show()

# %% [markdown]
# ### EDA on Subscribers
# + Subscribers
# 	- Which course have the highest number of subscribers
# 	- Average number of subscribers
# 	- Number of subscribers per Subject
# 	- Number of subscribers per year

# %%
df.groupby('subject')['num_subscribers'].count().plot(kind = 'barh')
# Out:
# <AxesSubplot:ylabel='subject'>

# %%
df.groupby('subject')['num_subscribers'].sum().plot(kind = 'barh')
# Out:
# <AxesSubplot:ylabel='subject'>

# %%
df.groupby('subject')['num_subscribers'].sum().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='num_subscribers'>

# %% [markdown]
# ### EDA on Levels
#
# + Levels
# 	- How many levels do we have
# 	- What is the distribution of courses per levels
# 	- Which subject have the highest levels
# 	- How many subscribers per levels
# 	- How many courses per levels

# %%
df['level'].value_counts().plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %%
## grouping the level as per persons intrest

df.groupby(['level'])['num_subscribers'].count().plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='level'>

# %%
df.groupby(['level'])['num_subscribers'].sum().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='level'>

# %%
# How many levels per subject category

df.groupby(['subject'])['level'].count().plot(kind = 'bar',color = 'red')
# Out:
# <AxesSubplot:xlabel='subject'>

# %%
# Plot of How many levels per subject category

plt.figure(figsize=(15,7))
df.groupby(['subject'])['level'].value_counts().plot(kind = 'bar')

plt.xticks(fontsize = 20,fontweight = 'bold')
plt.yticks(fontsize = 20,fontweight = 'bold')
plt.xlabel('Subject Category',fontsize = 20,fontweight = 'bold',color = 'blue')
plt.ylabel('Count of Levels',fontsize = 20,fontweight = 'bold',color = 'blue')
# Out:
# Text(0, 0.5, 'Count of Levels')

# %%
# number of levels and subscribers count

plt.figure(figsize=(16,9))
sn.barplot(x='level',y='num_subscribers', hue='subject',data=df)
plt.xticks(fontsize = 20,fontweight = 'bold')
plt.yticks(fontsize = 20,fontweight = 'bold')
plt.xlabel('Level',fontsize = 20,fontweight = 'bold',
           color = 'blue')
plt.ylabel('Subscribers Count',fontsize = 20,fontweight = 'bold',
           color = 'blue')
plt.xticks(rotation = 'vertical')
plt.show()

# %%
# number of levels and number of lectures count

plt.figure(figsize=(16,9))
sn.barplot(x='level',y='num_lectures', hue='subject',data=df)
plt.xticks(fontsize = 20,fontweight = 'bold')
plt.yticks(fontsize = 20,fontweight = 'bold')
plt.xlabel('Level',fontsize = 20,fontweight = 'bold',
           color = 'blue')
plt.ylabel('Lectures Count',fontsize = 20,fontweight = 'bold',
           color = 'blue')
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject', 'profit',
#        'published_date', 'published_time', 'year', 'month', 'day'],
#       dtype='object')

# %%
# reviews_level plot and lectures_level plot

def plotdata(df,feature):
    plt.figure(figsize=(10,7))
    plt.title("Plot of {} per level per subject".format(feature))
    sn.barplot(x = 'level',y = feature,data=df,hue = 'subject')
    plt.show()
    
    
featureslist = ['num_subscribers', 'num_reviews', 'num_lectures']
for feature in featureslist:
    plotdata(df,feature)

# %% [markdown]
# ### EDA on Price
# + Price
# 	- What is the average price of a course
# 	- What is the min/max price
# 	- How much does Udemy earn
# 	- The most profitable courses

# %%
df['price'].unique()
# Out:
# array([200,  75,  45,  95, 150,  65, 195,  30,  20,  50, 175, 140, 115,
#        190, 125,  60, 145, 105, 155, 185, 180, 120,  25, 160,  40,   0,
#        100,  90,  35,  80,  70,  55, 165, 130,  85, 170, 110, 135],
#       dtype=int64)

# %%
# replacing the Free/True courses with 0 

# df['price'] = df['price'].str.replace('TRUE|Free','0')

# df['price'].unique()

# %%
df['price'] = df['price'].astype('float')

# %%
plt.figure(figsize=(15,7))
df['price'].value_counts().plot(kind = 'bar',color = 'violet')
# Out:
# <AxesSubplot:>

# %%
# What is the most profitable course
# price x num_subscriber

df['profit'] = df['price'] * df['num_subscribers']
df.head(3)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True  200.0
# 1      https://www.udemy.com/goods-and-services-tax/     True   75.0
# 2  https://www.udemy.com/financial-modeling-for-b...     True   45.0
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
#
#   content_duration   published_timestamp           subject    profit  \
# 0        1.5 hours  2017-01-18T20:58:58Z  Business Finance  429400.0
# 1         39 hours  2017-03-09T16:34:20Z  Business Finance  209400.0
# 2        2.5 hours  2016-12-19T19:26:30Z  Business Finance   97830.0
#
#   published_date published_time  year  month  day
# 0     2017-01-18      20:58:58Z  2017      1   18
# 1     2017-03-09      16:34:20Z  2017      3    9
# 2     2016-12-19      19:26:30Z  2016     12   19

# %%
# The most profitable course
    
df[df['profit']==df['profit'].max()].style.background_gradient(cmap = 'plasma')
# Out:
# <style type="text/css">
# #T_ceb99_row0_col0, #T_ceb99_row0_col4, #T_ceb99_row0_col5, #T_ceb99_row0_col6, #T_ceb99_row0_col7, #T_ceb99_row0_col12, #T_ceb99_row0_col15, #T_ceb99_row0_col16, #T_ceb99_row0_col17 {
#   background-color: #0d0887;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ceb99_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >course_id</th>
#       <th class="col_heading level0 col1" >course_title</th>
#       <th class="col_heading level0 col2" >url</th>
#       <th class="col_heading level0 col3" >is_paid</th>
#       <th class="col_heading level0 col4" >price</th>
#       <th class="col_heading level0 col5" >num_subscribers</th>
#       <th class="col_heading level0 col6" >num_reviews</th>
#       <th class="col_heading level0 col7" >num_lectures</th>
#       <th class="col_heading level0 col8" >level</th>
#       <th class="col_heading level0 col9" >content_duration</th>
#       <th class="col_heading level0 col10" >published_timestamp</th>
#       <th class="col_heading level0 col11" >subject</th>
#       <th class="col_heading level0 col12" >profit</th>
#       <th class="col_heading level0 col13" >published_date</th>
#       <th class="col_heading level0 col14" >published_time</th>
#       <th class="col_heading level0 col15" >year</th>
#       <th class="col_heading level0 col16" >month</th>
#       <th class="col_heading level0 col17" >day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ceb99_level0_row0" class="row_heading level0 row0" >3235</th>
#       <td id="T_ceb99_row0_col0" class="data row0 col0" >625204</td>
#       <td id="T_ceb99_row0_col1" class="data row0 col1" >The Web Developer Bootcamp</td>
#       <td id="T_ceb99_row0_col2" class="data row0 col2" >https://www.udemy.com/the-web-developer-bootcamp/</td>
#       <td id="T_ceb99_row0_col3" class="data row0 col3" >True</td>
#       <td id="T_ceb99_row0_col4" class="data row0 col4" >200.000000</td>
#       <td id="T_ceb99_row0_col5" class="data row0 col5" >121584</td>
#       <td id="T_ceb99_row0_col6" class="data row0 col6" >27445</td>
#       <td id="T_ceb99_row0_col7" class="data row0 col7" >342</td>
#       <td id="T_ceb99_row0_col8" class="data row0 col8" >All Levels</td>
#       <td id="T_ceb99_row0_col9" class="data row0 col9" >43 hours</td>
#       <td id="T_ceb99_row0_col10" class="data row0 col10" >2015-11-02T21:13:27Z</td>
#       <td id="T_ceb99_row0_col11" class="data row0 col11" >Web Development</td>
#       <td id="T_ceb99_row0_col12" class="data row0 col12" >24316800.000000</td>
#       <td id="T_ceb99_row0_col13" class="data row0 col13" >2015-11-02</td>
#       <td id="T_ceb99_row0_col14" class="data row0 col14" >21:13:27Z</td>
#       <td id="T_ceb99_row0_col15" class="data row0 col15" >2015</td>
#       <td id="T_ceb99_row0_col16" class="data row0 col16" >11</td>
#       <td id="T_ceb99_row0_col17" class="data row0 col17" >2</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.iloc[3235]
# Out:
# course_id                                                         625204
# course_title                                  The Web Developer Bootcamp
# url                    https://www.udemy.com/the-web-developer-bootcamp/
# is_paid                                                             True
# price                                                              200.0
# num_subscribers                                                   121584
# num_reviews                                                        27445
# num_lectures                                                         342
# level                                                         All Levels
# content_duration                                                43 hours
# published_timestamp                                 2015-11-02T21:13:27Z
# subject                                                  Web Development
# profit                                                        24316800.0
# published_date                                                2015-11-02
# published_time                                                 21:13:27Z
# year                                                                2015
# month                                                                 11
# day                                                                    2
# Name: 3235, dtype: object

# %%
# The least profitable course,these may be free course
    
df[df['profit']==df['profit'].min()].style.background_gradient(cmap = 'plasma')
# Out:
# <style type="text/css">
# #T
# df['is_paid'] = df['is_paid'].map(paid_dict)

# df['is_paid'].unique()
# Out:
# array([nan], dtype=object)

# %%
# sn.countplot(x = 'is_paid', data=df, palette='plasma')

# %%
# df.groupby(['is_paid'])['subject'].value_counts()
# Out:
# Series([], Name: subject, dtype: int64)

# %%
# # paid courses with subjects

# df[df['is_paid']==True].groupby(['is_paid'])['subject'].value_counts().plot(kind = 'bar',color = 'magenta')

# %%
# # free courses with subjects

# df[df['is_paid']==False].groupby(['is_paid'])['subject'].value_counts().plot(kind = 'bar',color = 'magenta')

# %% [markdown]
# ### Correlation Question
# + Correlation Questions
# 	- Does number of subscribers depend on
# 	- number of reviews
# 	- price
# 	- number of lectures
# 	- content duration

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject', 'profit',
#        'published_date', 'published_time', 'year', 'month', 'day'],
#       dtype='object')

# %%
sn.scatterplot(data=df,x='price',y='num_subscribers')
# Out:
# <AxesSubplot:xlabel='price', ylabel='num_subscribers'>

# %%
sn.scatterplot(data=df,x = 'price',y = 'num_reviews')
# Out:
# <AxesSubplot:xlabel='price', ylabel='num_reviews'>

# %%
plt.figure(figsize=(20,10))
plt.title("Does Price Influence Subscription Per Subject Category",
         fontsize = 20,fontweight = 'bold')

sn.lineplot(data=df,x='price',y='num_subscribers',hue='subject')

plt.xticks(fontsize = 20,fontweight = 'bold',rotation = 45)
plt.yticks(fontsize = 20,fontweight = 'bold',rotation = 45)
plt.xlabel('Price',fontsize = 20,fontweight = 'bold',
           color = 'blue')
plt.ylabel('Number of Subscribers',fontsize = 20,fontweight = 'bold',
           color = 'blue')

plt.show()

# %% [markdown]
# <div class="text_cell_render border-box-sizing rendered_html">
# <h3>Question on Time<a class="anchor-link" href="#Question-on-Time">¶</a>
# </h3>
# <ul>
# <li>Published Year<ul>
# <li>Number of courses per year</li>
# <li>Distribution of subjects per year</li>
# <li>Which year has the highest number of courses</li>
# <li>What is the trend of courses per year</li>
# </ul>
# </li>
# </ul>
#
# </div>

# %%
df['published_timestamp'].head()
# Out:
# 0    2017-01-18T20:58:58Z
# 1    2017-03-09T16:34:20Z
# 2    2016-12-19T19:26:30Z
# 3    2017-05-30T20:07:24Z
# 4    2016-12-13T14:57:18Z
# Name: published_timestamp, dtype: object

# %%
# we need to extract year,month,date from the published timestamp

# so for that i will extract the year-month-date from the timestamp 

df['published_date'] = df['published_timestamp'].apply(lambda x:x.split('T')[0])

# %%
df.head(2)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
#
#                                                  url is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     NaN  200.0
# 1      https://www.udemy.com/goods-and-services-tax/     NaN   75.0
#
#    num_subscribers  num_reviews  num_lectures       level content_duration  \
# 0             2147           23            51  All Levels        1.5 hours
# 1             2792          923           274  All Levels         39 hours
#
#     published_timestamp           subject    profit published_date  \
# 0  2017-01-18T20:58:58Z  Business Finance  429400.0     2017-01-18
# 1  2017-03-09T16:34:20Z  Business Finance  209400.0     2017-03-09
#
#   published_time  year  month  day
# 0      20:58:58Z  2017      1   18
# 1      16:34:20Z  2017      3    9

# %%
# converting the published date to pandas datetime object

df['published_date'] = df['published_date'].apply(lambda x: pd.to_datetime(x, errors = 'coerce').date() )

# %%
df[df['published_date']=='3 hours']
# Out:
# Empty DataFrame
# Columns: [course_id, course_title, url, is_paid, price, num_subscribers, num_reviews, num_lectures, level, content_duration, published_timestamp, subject, profit, published_date, published_time, year, month, day]
# Index: []

# %%
# dropping of that

df = df.drop(df.index[2066])

# checking if the row has been dropped or not

df[df['published_date']=='3 hours']
# Out:
# Empty DataFrame
# Columns: [course_id, course_title, url, is_paid, price, num_subscribers, num_reviews, num_lectures, level, content_duration, published_timestamp, subject, profit, published_date, published_time, year, month, day]
# Index: []

# %%
# converting the published date to pandas datetime object

df['published_date'] = pd.to_datetime(df['published_date'],format="%Y-%m-%d")

# %%
df['Year'] = df['published_date'].dt.year

df['Month'] = df['published_date'].dt.month

df['Day'] = df['published_date'].dt.day

df['Month_name'] = df['published_date'].dt.month_name()


df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     NaN  200.0
# 1      https://www.udemy.com/goods-and-services-tax/     NaN   75.0
# 2  https://www.udemy.com/financial-modeling-for-b...     NaN   45.0
# 3  https://www.udemy.com/complete-excel-finance-c...     NaN   95.0
# 4  https://www.udemy.com/how-to-maximize-your-pro...     NaN  200.0
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
# 3             2451           11            36          All Levels
# 4             1276           45            26  Intermediate Level
#
#   content_duration  ...    profit published_date  published_time  year month  \
# 0        1.5 hours  ...  429400.0     2017-01-18       20:58:58Z  2017     1
# 1         39 hours  ...  209400.0     2017-03-09       16:34:20Z  2017     3
# 2        2.5 hours  ...   97830.0     2016-12-19       19:26:30Z  2016    12
# 3          3 hours  ...  232845.0     2017-05-30       20:07:24Z  2017     5
# 4          2 hours  ...  255200.0     2016-12-13       14:57:18Z  2016    12
#
#    day  Year  Month  Day  Month_name
# 0   18  2017      1   18     January
# 1    9  2017      3    9       March
# 2   19  2016     12   19    December
# 3   30  2017      5   30         May
# 4   13  2016     12   13    December
#
# [5 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject', 'profit',
#        'published_date', 'published_time', 'year', 'month', 'day', 'Year',
#        'Month', 'Day', 'Month_name'],
#       dtype='object')

# %%
# profit year wise

plt.figure(figsize=(15,7))
df.groupby(['Year'])['profit'].sum().plot(kind = 'bar')
plt.xticks(fontsize = 20,fontweight = 'bold',rotation = 45)
plt.yticks(fontsize = 20,fontweight = 'bold',rotation = 45)
plt.xlabel('Year',fontsize = 20,fontweight = 'bold',
           color = 'blue')
plt.ylabel('Profit',fontsize = 20,fontweight = 'bold',
           color = 'blue')
# Out:
# Text(0, 0.5, 'Profit')

# %%
# profit month wise

plt.figure(figsize=(15,7))
df.groupby(['Month_name'])['profit'].sum().plot(kind = 'bar')
plt.xticks(fontsize = 20,fontweight = 'bold',rotation = 45)
plt.yticks(fontsize = 20,fontweight = 'bold',rotation = 45)
plt.xlabel('Year',fontsize = 20,fontweight = 'bold',
           color = 'blue')
plt.ylabel('Profit',fontsize = 20,fontweight = 'bold',
           color = 'blue')
# Out:
# Text(0, 0.5, 'Profit')

# %%
# number of subscribers per year

plt.figure(figsize=(15,7))
df.groupby(['Year'])['num_subscribers'].sum().plot(kind = 'bar',color = 'green')

plt.xticks(fontsize = 20,fontweight = 'bold',rotation = 45)
plt.yticks(fontsize = 20,fontweight = 'bold',rotation = 45)
plt.xlabel('Year',fontsize = 20,fontweight = 'bold',
           color = 'blue')
plt.ylabel('Number of Subscribers',fontsize = 20,fontweight = 'bold',
           color = 'blue')
# Out:
# Text(0, 0.5, 'Number of Subscribers')

# %%
# number of subscribers month wise

plt.figure(figsize=(15,7))
df.groupby(['Month_name'])['num_subscribers'].sum().plot(kind = 'bar',
                                                         color = '#b57edc')

plt.xticks(fontsize = 20,fontweight = 'bold',rotation = 45)
plt.yticks(fontsize = 20,fontweight = 'bold',rotation = 45)
plt.xlabel('Year',fontsize = 20,fontweight = 'bold',
           color = 'blue')
plt.ylabel('Number of Subscribers',fontsize = 20,fontweight = 'bold',
           color = 'blue')
# Out:
# Text(0, 0.5, 'Number of Subscribers')

# %% [markdown]
# <div class="text_cell_render border-box-sizing rendered_html">
# <h4>Questions on Course Title<a class="anchor-link" href="#Questions-on-Course-Title">¶</a>
# </h4>
# <ul>
# <li>Course Title<ul>
# <li>What is the most frequent words in course title</li>
# <li>Longest/Shortest course title</li>
# <li>How can we build recommendation systems via title using similarity</li>
# <li>Most famous courses by number of subscribers</li>
# </ul>
# </li>
# </ul>
#
# </div>

# %%
df.head(3)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
#
#                                                  url is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     NaN  200.0
# 1      https://www.udemy.com/goods-and-services-tax/     NaN   75.0
# 2  https://www.udemy.com/financial-modeling-for-b...     NaN   45.0
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
#
#   content_duration  ...    profit published_date  published_time  year month  \
# 0        1.5 hours  ...  429400.0     2017-01-18       20:58:58Z  2017     1
# 1         39 hours  ...  209400.0     2017-03-09       16:34:20Z  2017     3
# 2        2.5 hours  ...   97830.0     2016-12-19       19:26:30Z  2016    12
#
#    day  Year  Month  Day  Month_name
# 0   18  2017      1   18     January
# 1    9  2017      3    9       March
# 2   19  2016     12   19    December
#
# [3 rows x 22 columns]

# %%
# course with maximum length

df[df['course_title'].str.len()==max(df['course_title'].str.len())]
# Out:
#       course_id                                       course_title  \
# 2191     286898  Aprende a tocar el Acordeón 'de oído y con téc...
#
#                                                     url is_paid  price  \
# 2191  https://www.udemy.com/aprende-los-secretos-de-...     NaN   75.0
#
#       num_subscribers  num_reviews  num_lectures       level content_duration  \
# 2191              158           17            59  All Levels        2.5 hours
#
#       ...   profit published_date  published_time  year month  day  Year  \
# 2191  ...  11850.0     2014-07-28       13:55:43Z  2014     7   28  2014
#
#       Month  Day  Month_name
# 2191      7   28        July
#
# [1 rows x 22 columns]

# %%
df['course_title'].iloc[2190]
# Out:
# 'Aprende a tocar el Acordeón \'de oído y con técnica",https://www.udemy.com/aprende-a-tocar-el-acordeon-de-oido-y-con-tecnica/,true,25,93,21,34,Beginner Level,4 hours,2014-09-16T19:51:45Z\n263432,Aprende los Secretos de la Armónica con HARP&SOUL"'

# %%
df.iloc[2190]
# Out:
# course_id                                                         286898
# course_title           Aprende a tocar el Acordeón 'de oído y con téc...
# url                    https://www.udemy.com/aprende-los-secretos-de-...
# is_paid                                                              NaN
# price                                                               75.0
# num_subscribers                                                      158
# num_reviews                                                           17
# num_lectures                                                          59
# level                                                         All Levels
# content_duration                                               2.5 hours
# published_timestamp                                 2014-07-28T13:55:43Z
# subject                                              Musical Instruments
# profit                                                           11850.0
# published_date                                       2014-07-28 00:00:00
# published_time                                                 13:55:43Z
# year                                                                2014
# month                                                                  7
# day                                                                   28
# Year                                                                2014
# Month                                                                  7
# Day                                                                   28
# Month_name                                                          July
# Name: 2191, dtype: object

# %%
# most reviewed course

df[df['num_reviews']==max(df['num_reviews'])]
# Out:
#       course_id                course_title  \
# 3235     625204  The Web Developer Bootcamp
#
#                                                     url is_paid  price  \
# 3235  https://www.udemy.com/the-web-developer-bootcamp/     NaN  200.0
#
#       num_subscribers  num_reviews  num_lectures       level content_duration  \
# 3235           121584        27445           342  All Levels         43 hours
#
#       ...      profit published_date  published_time  year month  day  Year  \
# 3235  ...  24316800.0     2015-11-02       21:13:27Z  2015    11    2  2015
#
#       Month  Day  Month_name
# 3235     11    2    November
#
# [1 rows x 22 columns]

# %%
# course with maximum length

df[df['course_title'].str.len()==min(df['course_title'].str.len())]
# Out:
#       course_id course_title                              url is_paid  price  \
# 1328    1164570       调色高级讲解  https://www.udemy.com/dezepioy/     NaN  200.0
# 1674    1164720       调色中级课程  https://www.udemy.com/ixlnjjvn/     NaN  200.0
#
#       num_subscribers  num_reviews  num_lectures           level  \
# 1328                4            2             8  Beginner Level
# 1674                5            3             7  Beginner Level
#
#      content_duration  ...  profit published_date  published_time  year month  \
# 1328           1 hour  ...   800.0     2017-03-31       17:16:15Z  2017     3
# 1674           1 hour  ...  1000.0     2017-03-31       17:19:38Z  2017     3
#
#       day  Year  Month  Day  Month_name
# 1328   31  2017      3   31       March
# 1674   31  2017      3   31       March
#
# [2 rows x 22 columns]

# %%
df['course_title'].iloc[1327]
# Out:
# '超基礎！超入門！〜作りながら学ぶ。完全無料3DCGソフトBlender〜'

# %%
df.iloc[1327]
# Out:
# course_id                                              1009622
# course_title              超基礎！超入門！〜作りながら学ぶ。完全無料3DCGソフトBlender〜
# url                    https://www.udemy.com/blender-beginner/
# is_paid                                                    NaN
# price                                                     80.0
# num_subscribers                                              8
# num_reviews                                                  1
# num_lectures                                                43
# level                                           Beginner Level
# content_duration                                     5.5 hours
# published_timestamp                       2016-12-14T01:25:19Z
# subject                                         Graphic Design
# profit                                                   640.0
# published_date                             2016-12-14 00:00:00
# published_time                                       01:25:19Z
# year                                                      2016
# month                                                       12
# day                                                         14
# Year                                                      2016
# Month                                                       12
# Day                                                         14
# Month_name                                            December
# Name: 1327, dtype: object

# %% [markdown]
# ### Keyword Extraction
#
# <ul>
# <li>Rake</li>
# <li>Yakes</li>
# <li>Collection</li>
# </ul>

# %%
# this library we will use for removing stopwords and tokenization

# !pip install neattext
# Out:
# Collecting neattext
#   Downloading neattext-0.1.2-py3-none-any.whl (114 kB)
# Installing collected packages: neattext
# Successfully installed neattext-0.1.2

# %%
# Text Cleaning to remove stopwords
import neattext.functions as nfx

# %%
dir(nfx)
# Out:
# ['BTC_ADDRESS_REGEX',
#  'CURRENCY_REGEX',
#  'CURRENCY_SYMB_REGEX',
#  'Counter',
#  'DATE_REGEX',
#  'EMAIL_REGEX',
#  'EMOJI_REGEX',
#  'HASTAG_REGEX',
#  'MASTERCard_REGEX',
#  'MD5_SHA_REGEX',
#  'MOST_COMMON_PUNCT_REGEX',
#  'NUMBERS_REGEX',
#  'PHONE_REGEX',
#  'PoBOX_REGEX',
#  'SPECIAL_CHARACTERS_REGEX',
#  'STOPWORDS',
#  'STOPWORDS_de',
#  'STOPWORDS_en',
#  'STOPWORDS_es',
#  'STOPWORDS_fr',
#  'STOPWORDS_ru',
#  'STOPWORDS_yo',
#  'STREET_ADDRESS_REGEX',
#  'TextFrame',
#  'URL_PATTERN',
#  'USER_HANDLES_REGEX',
#  'VISACard_REGEX',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__generate_text',
#  '__loader__',
#  '__name__',
#  '__numbers_dict',
#  '__package__',
#  '__spec__',
#  '_lex_richness_herdan',
#  '_lex_richness_maas_ttr',
#  'clean_text',
#  'defaultdict',
#  'digit2words',
#  'extract_btc_address',
#  'extract_currencies',
#  'extract_currency_symbols',
#  'extract_dates',
#  'extract_emails',
#  'extract_emojis',
#  'extract_hashtags',
#  'extract_html_tags',
#  'extract_mastercard_addr',
#  'extract_md5sha',
#  'extract_numbers',
#  'extract_pattern',
#  'extract_phone_numbers',
#  'extract_postoffice_box',
#  'extract_shortwords',
#  'extract_special_characters',
#  'extract_stopwords',
#  'extract_street_address',
#  'extract_terms_in_bracket',
#  'extract_urls',
#  'extract_userhandles',
#  'extract_visacard_addr',
#  'fix_contractions',
#  'generate_sentence',
#  'hamming_distance',
#  'inverse_df',
#  'lexical_richness',
#  'markov_chain',
#  'math',
#  'nlargest',
#  'normalize',
#  'num2words',
#  'random',
#  're',
#  'read_txt',
#  'remove_bad_quotes',
#  'remove_btc_address',
#  'remove_currencies',
#  'remove_currency_symbols',
#  'remove_custom_pattern',
#  'remove_custom_words',
#  'remove_dates',
#  'remove_emails',
#  'remove_emojis',
#  'remove_hashtags',
#  'remove_html_tags',
#  'remove_mastercard_addr',
#  'remove_md5sha',
#  'remove_multiple_spaces',
#  'remove_non_ascii',
#  'remove_numbers',
#  'remove_phone_numbers',
#  'remove_postoffice_box',
#  'remove_puncts',
#  'remove_punctuations',
#  'remove_shortwords',
#  'remove_special_characters',
#  'remove_stopwords',
#  'remove_street_address',
#  'remove_terms_in_bracket',
#  'remove_urls',
#  'remove_userhandles',
#  'remove_visacard_addr',
#  'replace_bad_quotes',
#  'replace_currencies',
#  'replace_currency_symbols',
#  'replace_dates',
#  'replace_emails',
#  'replace_emojis',
#  'replace_numbers',
#  'replace_phone_numbers',
#  'replace_special_characters',
#  'replace_term',
#  'replace_urls',
#  'string',
#  'term_freq',
#  'to_txt',
#  'word_freq',
#  'word_length_freq']

# %%
# removing all the stopwords

df['Clean_title'] = df['course_title'].apply(nfx.remove_shortwords)
df['Clean_title'].iloc[1:5]
# Out:
# 1    Complete Course Certification Grow Your Practice
# 2    Financial Modeling Business Analysts Consultants
# 3              Beginner Financial Analysis Excel 2017
# 4               Maximize Your Profits Trading Options
# Name: Clean_title, dtype: object

# %%
# head on head comparision

temp = df[['Clean_title','course_title']]

temp.head()
# Out:
#                                         Clean_title  \
# 0                Ultimate Investment Banking Course
# 1  Complete Course Certification Grow Your Practice
# 2  Financial Modeling Business Analysts Consultants
# 3            Beginner Financial Analysis Excel 2017
# 4             Maximize Your Profits Trading Options
#
#                                         course_title
# 0                 Ultimate Investment Banking Course
# 1  Complete GST Course & Certification - Grow You...
# 2  Financial Modeling for Business Analysts and C...
# 3  Beginner to Pro - Financial Analysis in Excel ...
# 4       How To Maximize Your Profits Trading Options

# %%
# # finding the maximum length of the clean title

# temp[temp['Clean_title'].str.len()==max(len(temp['Clean_title']))]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [74], in <cell line: 3>()
#       1 # finding the maximum length of the clean title
# ----> 3 temp[temp['Clean_title'].str.len()==max(temp['Clean_title'].len())]
#
# File ~\anaconda3\envs\pyspark\lib\site-packages\pandas\core\generic.py:5487, in NDFrame.__getattr__(self, name)
#    5480 if (
#    5481     name not in self._internal_names_set
#    5482     and name not in self._metadata
#    5483     and name not in self._accessors
#    5484     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5485 ):
#    5486     return self[name]
# -> 5487 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'len'

# %%
temp['Clean_title'].iloc[293]
# Out:
# 'Multiply your returns using Value Investing https udemy multiply your returns using value investing true 1942 Levels hours 2015 23T00 874284 Weekly Forex Analysis Baraq'

# %%
temp['course_title'].iloc[293]
# Out:
# 'Multiply your returns using \'Value Investing",https://www.udemy.com/multiply-your-returns-using-value-investing/,true,20,1942,19,63,All Levels,4.5 hours,2015-07-23T00:08:33Z\n874284,Weekly Forex Analysis by Baraq FX"'

# %%
# we can observe special characters in clean title,we'll remove them

df['Clean_title'] = df['Clean_title'].apply(nfx.remove_special_characters)
df['Clean_title'].iloc[1:5]
# Out:
# 1    Complete Course Certification Grow Your Practice
# 2    Financial Modeling Business Analysts Consultants
# 3              Beginner Financial Analysis Excel 2017
# 4               Maximize Your Profits Trading Options
# Name: Clean_title, dtype: object

# %%
# tokenisation

all_title_list = df['Clean_title'].to_list()

all_title_list[1:5]
# Out:
# ['Complete Course Certification Grow Your Practice',
#  'Financial Modeling Business Analysts Consultants',
#  'Beginner Financial Analysis Excel 2017',
#  'Maximize Your Profits Trading Options']

# %%
alltokens = [token for line in all_title_list for token in line.split()]

print(len(alltokens))

print(alltokens[1:4])
# Out:
# 18227
# ['Investment', 'Banking', 'Course']

# %%
## top50 frequently used words 

from collections import Counter

freq_words = dict(Counter(alltokens).most_common(50))

freq_words
# Out:
# {'Learn': 495,
#  'Trading': 281,
#  'with': 278,
#  'Course': 235,
#  'Beginners': 235,
#  'Guitar': 211,
#  'Design': 189,
#  'Complete': 181,
#  'Piano': 179,
#  'Photoshop': 169,
#  'Forex': 165,
#  'Build': 164,
#  'Financial': 139,
#  'Beginner': 138,
#  'Create': 136,
#  'JavaScript': 124,
#  'Your': 119,
#  'HTML': 118,
#  'Guide': 116,
#  'Accounting': 114,
#  'Website': 111,
#  'from': 111,
#  'Development': 110,
#  'Options': 101,
#  'From': 101,
#  'Play': 100,
#  'Adobe': 100,
#  'With': 99,
#  'Introduction': 93,
#  'Master': 92,
#  'Illustrator': 90,
#  'Basics': 89,
#  'Scratch': 83,
#  'WordPress': 83,
#  'Level': 80,
#  'Professional': 79,
#  'Analysis': 78,
#  'Advanced': 77,
#  'Easy': 76,
#  'Lessons': 73,
#  'HTML5': 68,
#  'Trade': 66,
#  'Stock': 65,
#  'Bootstrap': 64,
#  'Business': 62,
#  'play': 61,
#  'Angular': 58,
#  'your': 57,
#  'Building': 56,
#  'Stocks': 55}

# %%
plt.figure(figsize=(30,15))
plt.bar(*zip(*freq_words.items()))
plt.xticks(rotation = 45)

plt.xticks(fontsize = 15,fontweight = 'bold',rotation = 45)
plt.yticks(fontsize = 10,fontweight = 'bold',rotation = 45)
plt.xlabel('Frequent Words',fontsize = 20,fontweight = 'bold',
           color = 'blue')
plt.ylabel('Count of Frequent Words',fontsize = 20,fontweight = 'bold',
           color = 'blue')

plt.show()

# %%
# !pip install rake_nltk
# Out:
# Collecting rake_nltk
#   Downloading rake_nltk-1.0.6-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: nltk<4.0.0,>=3.6.2 in c:\users\sadpa\anaconda3\envs\pyspark\lib\site-packages (from rake_nltk) (3.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\sadpa\anaconda3\envs\pyspark\lib\site-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (2021.8.3)
# Requirement already satisfied: tqdm in c:\users\sadpa\anaconda3\envs\pyspark\lib\site-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (4.63.0)
# Requirement already satisfied: joblib in c:\users\sadpa\anaconda3\envs\pyspark\lib\site-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (1.1.0)
# Requirement already satisfied: click in c:\users\sadpa\anaconda3\envs\pyspark\lib\site-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (7.1.2)
# Requirement already satisfied: colorama in c:\users\sadpa\anaconda3\envs\pyspark\lib\site-packages (from tqdm->nltk<4.0.0,>=3.6.2->rake_nltk) (0.4.4)
# Installing collected packages: rake-nltk
# Successfully installed rake-nltk-1.0.6

# %% [markdown]
# ##### Tokenization

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sadpa\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
from rake_nltk import Rake
rake = Rake()

allwords = ''.join(alltokens)

rake.extract_keywords_from_text(allwords)

# %%
rake.get_ranked_phrases_with_scores()
# Out:
# [(1.0,
#   '...')]
