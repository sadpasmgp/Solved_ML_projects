# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import re
import datetime as dt
# %matplotlib inline

# %%
'''
Importing the text file which contains the chat of the group
in read mode using utf-8 encoding!
This is my clg group chat,it contains chats from 2018,so its a very big
file,will preview it after we've done adding regular expressions!

'''

f = open('Emotion(angry).csv','r',encoding='utf-8')

data = f.read()

# %%
dummy = data.split('\n')
dummy
# Out:
# ['content,sentiment',
#  '"Sometimes I’m not angry, I’m hurt and there’s a big difference.",angry',
#  'Not available for busy people☺,angry',
#  'I do not exist to impress the world. I exist to live my life in a way that will make me happy.,angry',
#  '"Everything is getting expensive except some people, they are getting cheaper.",angry',
#  'My phone screen is brighter than my future 🙁,angry',
#  'Anger is a feeling that makes your mouth work than faster your mind..,angry',
#  '"This man, is man, a man, good man, way man, to man, keep man, an man, idiot man, busy man, for man, 30 man, seconds man! NOW READ WITHOUT MAN",angry',
#  'Sometimes the best way to get someone\\’s attention is to stop giving them yours.,angry',
#  '"People like to bring up your past, when your present and future look better than theirs.",angry',
#  'Wakeup>job>noluv>daaru>sleep>repeat..,angry',
#  'To all u Haters!!! Thanks for making me famous. I don’t give a Sh***t if u talk behind my back.,angry',
#  'Its hurts the worst when the person that made you feel so special yesterday makes you feel so unwanted today.,angry',
#  'Life is too short don’t waste it by reading my whatsapp status,angry',
#  '"If I treated you the way you treat me, you would hate my guts.",angry',
#  'Girls r like potato chips…you can’t have 1,angry',
#  'Had you asked for my life i would have sacrificed it with a smile… but you’ve stripped me of my pride,angry',
#  'People always miss you more when they find out how much happier you are without them.,angry',
#  '"People change for one of two reasons: They have learned a lot, or they have been hurt too many times.",angry',
#  'If you fail and feels the shame then you are only few steps away from success ☺,angry',
#  'You get betrayed by people you never thought of…,angry',
#  'Does your ass ever get jealous of all the shit that comes out of ur mouth?,angry',
#  '"When you give lots of importance to someone, you loss your own importance in their life….",angry',
#  'There are no solutions when you only focus on the negative,angry',
#  'Out of every negative is a positive.. its up to you to find out what it is and utilize it..,angry',
#  'If you always focus on the negative you will never see the positive!!!,angry',
#  'Negativity is a cancer of the soul that spreads like the flu..,angry',
#  '"If you realized how powerful your thoughts are, you would never think a negative thought.",angry',
#  '"When life give u lemons, squeeze it in people’s eyes ….",angry',
#  '"I’m take a nice long shit, so don’t stress me !",angry',
#  '"Don’t disturb me, I am disturbed enough already.",angry',
#  'Please don’t interrupt me while I’m ignoring you,angry',
#  'Stop letting the world change you. Be yourself and change the world.,angry',
#  '"Just when I think things are looking up, here comes the Fuck up Fairy again. Why can’t things go right for a change?",angry',
#  '"Looking at the past, yeah…Alot of it hurt but you know it only made me stronger.",angry',
#  'You talk behind my back only because you are afraid to say things to my face.,angry',
#  'why does no one ever want to talk in an elevator?,angry',
#  'What you heard is not what I said. Listen better next time.,angry',
#  '"Think again before you assume, And next time don’t be so quick to judge. You’ll never know what it’s like to be in my shoes.",angry',
#  'is wishing that SOME people would understand that: IT’S NOT ALL ABOUT YOU!!,angry',
#  '"Go ahead and ignore me,..I can play that game too, and I’m probably better at it than you are…",angry',
#  '"No time for disrespectful, immature, selfish individuals!",angry',
#  'Ever notice its those people saying they hate drama that start it? It doesn’t make sense to me.,angry',
#  'is wondering if certain people have to work to be annoying or if it just comes naturally,angry',
#  'The people that work hard don’t get the credit.The people that just do nothing get everything.,angry',
#  'There are a few people out there who are just like trees; they take forever to grow up.,angry',
#  'ugh. your so fake i bet if you look at the bottom of your foot it say made in china,angry',
#  '"Life is to short to let other people get to you, If they can’t handle who I am then I don’t need them in my life!",angry',
#  '"I don\'t care about what others think about me, I just care about what I think about myself.",angry',
#  'People are selfish now a days.,angry',
#  '"Don’t tell me to change, I can’t perfect myself anymore.",angry',
#  'You killed what was left of the good in me.,angry',
#  'I never dreamed about success. I worked for it.,angry',
#  '"If you don\'t like me remember it\'s mind over matter, I don\'t mind and you don\'t matter.",angry',
#  'Be yourself because an original is worth more than a copy.,angry',
#  'Yes i am selfish i don’t want to share you with people.,angry',
#  "I'm only selfish when it comes to you.,angry",
#  '"I done what i like, i don\'t care what you think?",angry',
#  '"I am who I am, your approval isn\'t needed.",angry',
#  '"I\'d rather be hated for being real, than loved for being fake.",angry',
#  '"Be good to yourself, you’re all you’ve got.",angry',
#  '"I am simple, complex, generous, selfish, unattractive, beautiful, lazy, and driven.",angry',
#  '"Beauty captures your attention, but personality captures your heart.",angry',
#  '"You left without a reason, so please don\'t come back with an excuse.",angry',
#  '"I’m born to express, not to impress.",angry',
#  'If your ego speaks with me then my attitude replies to you.,angry',
#  '"Before you judge me, Make sure that you’re perfect.",angry',
#  '"I don’t treat people badly, I treat them accordingly.",angry',
#  '"My life ,my rule,that’s my attitude… ",angry',
#  '"If you dont want me , Dont fuck with my feelings.",angry',
#  'Never Love Someone At The Cost Of Your Dignity And Self Respect...!!!,angry',
#  'Beauty is only skin deep.Attitude is down to the bone.,angry',
#  '"You treated me like an option, so i left you like a choice",angry',
#  '"There are two ways to be happy: Change your situation, or change your mindset towards it.",angry',
#  '"Your attitude may hurt me, But mine can Kill You!!",angry',
#  "I'm a very private person. You don’t ask i don’t tell.,angry",
#  'I am not your toy.,angry',
#  'Sometimes I want to treat people how they treat me But I don’t because It’s out of my character.,angry',
#  '"If you ever think I am ignoring you, I swear I am. My phone is in my hand 24×7 ",angry',
#  '"Take care of Your Status, don’t be care taker of My Status",angry',
#  'If there is no one to hold your hand put your hands in your pocket and continue your walk.,angry',
#  '"Don’t be afraid of being outnumbered , eagles fly alone. Pigeons flock together.",angry',
#  "I am who i am and i won't change for anyone.,angry",
#  '"I don’t care for people, who don’t care for me.",angry',
#  'Nobody can teach me who I am.,angry',
#  '"Yes, I’m smiling. But you’re not the reason anymore.",angry',
#  '"Choose me or lose me. I am not a backup plan, and definitely not a second choice.",angry',
#  'I don’t go crazy. I am crazy. I just go normal from time to time….,angry',
#  '"Never, never, never, never give up.",angry',
#  'There’s a difference between somebody who wants you and somebody who would do anything to keep you. Remember that.,angry',
#  '"Before you judge me, Make sure that you’re perfect.",angry',
#  'I dont have enough middle fingers to show you how i feel.,angry',
#  '"Yes, i have changed. Pain does that to People.",angry',
#  '"Dear Girls, Stop comparing all guys with your ex. Not all of us are players and jerks.",angry',
#  'The bravest thing I ever did was continuing my life when I wanted to die.,angry',
#  '"Show me, don\'t tell me.",angry',
#  '"I don’t fear commitment, I fear wasting my time.",angry',
#  '"I live, I love, I fight, I cry, but I never give up",angry',
#  'How he treats you is how he feels about you.,angry',
#  '"Someone Asked me what is UR attitude then i simply replied... "" BEING SINGLE IS MY ATTITUDE…""",angry',
#  'My attitude depends on the people in front of me.,angry',
#  'Im not selfish but whats Mine is MINE . End of story,angry',
#  '"if you want me let me know, if you dont, please gently let me go.",angry',
#  "They laughed at me because I'm different. I laughed at them because they're all the same.,angry",
#  '"I don’t insult people , I just describe them.",angry',
#  '"Two fundamentals of cool life – Walk like you are the king OR walk like you don’t care ,who is the king.",angry',
#  '"I trusted you but now your words mean nothing to me, because your actions spoke the truth.",angry',
#  '"If you like me Then raise your hand, If not then raise your standard.",angry',
#  '"Beauty Fades After Time, But Personality Is Forever!",angry',
#  '"Dear broken hearted girls , Hold your head up high and you middle finger higher , let him know what he is missing",angry',
#  '"Be a girl with a mind, a bitch with an attitude, and a lady with class.",angry',
#  '"I have no need for people who come to me when they need me,then throw me aside when they\'re fine.",angry',
#  'This is how it goes. I will respect those who respect me & forget those who forget me. Simple as that.,angry',
#  'When Sum One Hates You for no reason. Give them a reason.,angry',
#  'Never give up on something you love,angry',
#  '"Excellence is not a skill, It is an attitude. ",angry',
#  '"If you want me, come and get me. If you want me to come, forget it.",angry',
#  '"Good girls are bad girls, who never get caught.",angry',
#  '"To keep a relationship, you must keep your business to yourself and your partner, The whole world doesnt need to know your problems.",angry',
#  'If your are still hate me!then No Problem!.,angry',
#  '"Problem is not a problem, but problem is that,is your attitude towards the problem.",angry',
#  '"Girls are like parking spaces, all the good ones are already taken.",angry',
#  'Seeing your ex go through what they put you through.. Priceless.,angry',
#  '"Stop asking for faithful girls, when you are too busy chasing hoes.",angry',
#  'The only difference between a good day and a bad day is your attitude.,angry',
#  '"I don\'t trust easily. So when I tell you that ""I trust you"", please don\'t make me regret it.",angry',
#  '"I\'m Not a Tumblr Girl, But I\'m Beautiful",angry',
#  "To all the girls that say gentlemen don't exist anymore: They do exist but gentlemen are attracted to ladies. Not sluts.,angry",
#  '"Don\'t even try and judge me dude,You have no idea what the Fuck I\'ve been through.",angry',
#  '"If you want me let me know. If you don\'t, please gently let me go.",angry',
#  '"Putting in headphones, to avoid people\'s bullshit.",angry',
#  'i am scared to see you with someone else.,angry',
#  'Silence is the best way to react while angry.,angry',
#  'I hate the moment when suddenly my anger turns into tears.,angry',
#  'Silence is the best way to react while angry.,angry',
#  'Some things can never be forgotten and nor forgiven.,angry',
#  'There are no words to describe the anger and frustration that I am feeling right now.,angry',
#  "Don't make so many promises when you can't even keep one.,angry",
#  '"Sometimes i’m not angry, i’m hurt and there’s a big difference.",angry',
#  '"It’s better to cry than to be angry because anger hurts others, while tears flow silently through the soul and cleaneses the heart..",angry',
#  '"If I delete your number, you’re basically deleted from my life.",angry',
#  'Getting angry is actually punishing yourself with the mistakes of others.,angry',
#  'Some people never realise the emotional and mental damage they do to others.,angry',
#  '"Your mistake is letting me go, my mistake was letting you in.",angry',
#  '"Nobody makes you angry, you decide to use anger as a response.",angry',
#  "The same person who said the sweetest things to me also said some of the meanest things I've ever heard.,angry",
#  '"Never forget what someone says to you when they are angry, because that’s when the truth comes out",angry',
#  '"When we don’t know who to hate, we hate ourselves.",angry',
#  'Some people need to open their small minds instead of their big mouths.,angry',
#  'Anger is a feeling that makes your mouth work faster than your mind.,angry',
#  '"When you are angry, your text speed increases by a ridiculous amount.",angry',
#  'For every minute you are angry….. you lose sixty seconds of happiness… Think about It,angry',
#  'It sucks when you realize you rejected other people for that one person who wasted your time.,angry',
#  '"Anger is our natural deffense against pain. So when i say i hate you, it really means you hurt me.",angry',
#  '"Everything is getting expensive except some people, they are getting cheaper…",angry',
#  'Anger is poison. You must purge it from your mind or else it will corrupt your better nature.,angry',
#  'They say milk is good for your teeth. You know what else is good for your teeth? Minding your own damn business.,angry',
#  '"Anger makes you smaller, while forgiviness forces you to grow beyond what you were..",angry',
#  '"[\'Hating Me Won’T Make You Pretty.\', \'Anger Is One Letter Short Of Danger.\', \'I Am If I Changed, But You Changed Too.\', \'Anger Is My Power So Don’t Make Me Angry.\', \'Even The Nicest People Have Their Limits.\', \'Whatever Is Begun In Anger Ends In Shame.\', \'Don’T Make Me Angry And Change Your Status.\', \'Silence Is The Best Way To React While Angry. ( Angry Whatsapp Status\\xa0\', \'I Hope Karma Slaps You In The Face Before I Do.\', \'An Angry Man Opens His Mouth And Shuts His Eyes.\', \'I Am Not In A Bad Mood, Everyone Is Just Annoying.\', \'A Quick Temper Will Make A Fool Of You Soon Enough.\', \'Yes I Am Smiling But You Are Not The Reason Anymore.\', \'My Attitude Will Always Be Based On How You Treat Me.\', \'You Blocked Me On Facebook & Noe You’Re Going To Die.\', \'Anger Tears Me Up Inside…My Own…Or Anyone Else’S. (\\xa0Angry\\xa0Quotes\\xa0\', \'You Should Make A Woman Angry If You Wish Her To Love.\', \'Sometimes I’M Not Angry. I’M Hurt And There’S A Big Diff.\', \'Never Go To Bed Angry, Stay Awake And Plot Your Revenge.\', \'It’S Easier To Say You’re Mad Than To Admit You’Re Hurt.\', \'Don’T Make So Many Promises When You Can’T Even Keep One.\', \'We Met For A Reason, Either You’Re A Blessing Or A Lesson.\', \'I Hate The Moments When Suddenly My Anger Turns Into Tears.\', \'Tell The Truth, Or Eventually Someone Will Tell It For You. (\\xa0Angry Status\\xa0\', \'Its Just A Chapter In Your Life, Turn The Page And Move On.\', \'When People Get Angry With Him, I Remind Them That He’S Kid.\', \'If Someone Is Angry With You And You Laugh At Them, You Win.\', \'Nobody Makes You Angry. You Decide To Use Anger As A Response.\', \'I Miss You That True But It Doesn’t Mean I Forget Your Lies.\', \'The Best Revenge Is To Be Unlike Hi Who Performed The Injury.\', \'Anger Is Never Without A Reason, Butt Seldom With A Good One.\', \'If I Delete Your Number, You’Re Basically Deleted For My Life. (\\xa0Angry Whatsapp Status\\xa0\', \'Don’T Judge Someone Just Because They Sin Differently Than You.\', \'People Change. Things Go Wrong. Shit Happens. But Life Goes On.\', \'Anger Is Feeling That Make Your Mouth Work Faster Than Your Mind.\', \'Don’T Be Angry With People Who Don’T Have The Capacity To Change.\', \'All Angry Persons Are To Be Treated, By The Prudent, As Children.\', \'When U Are Angry, Ur Text Speed Increases By A Ridiculous Amount.\', \'If You Wake Me Up & I Don’T Get Angry, You Must Be Pretty Special.\', \'Control Your ” Anger “. It Is Just One Letter Away From “D” Anger.\\xa0( Angry Whatsapp Status\\xa0\', \'For Every Minute You Are Angry You Lose Sixty Seconds Of Happiness.\', \'Anger Is A Condition In Which The Tongue Works Faster Than The Mind.\', \'I Don’T Need Anger Management, I Need People To Stop Pissing Me Off.\', \'Unless I Am Sitting On Your Face My Weight Is None Of Your Business!\', \'People Won’T Have Time For You If You Are Always Angry Or Complaining.\', \'Just Because You’Re Angry, Doesn’T Mean You Have The Right To Be Cruel.\', \'Sometimes I Get To The Point Of Frustration, That I Just Become Silent.\', \'Some People Need To Open Their Small Minds Instead Of Their Big Mouths.\', \'When I’M Shouting, Your Fine. It’S When I Go Silent You Need To Worried.\\xa0(\\xa0Anger Status for Whatsapp\\xa0\', \'Anger Is Nothing Than An Outward Expression Of Hurt, Fear & Frustration.\', \'Never Do Anything When U Are In A Temper, For U Will Do Everything Wrong.\', \'Never Regret Anything, Because At One Time It Was Exactly What You Wanted.\', \'Sometimes I Feel Like Giving People A High-Five In That Face, With A Chair.\', \'Six Letters, Two Words, Easy To Say, Hard To Explain, Harder To Do. Move On.\', \'You Will Not Be Punished For Your Anger, You Will Be Punished By Your Anger.\', \'Holding On To Anger Is Like Drinking Poison And Expecting The Person To Die. ( Angry Whatsapp Status\\xa0\', \'No Matter How Angry You Get, You Always End Up Forgiving The People You Love.\', \'Life Is Too Short To Spend Tim ...
#  '"[\'Hating Me Won’T Make You Pretty.\', \'Anger Is One Letter Short Of Danger.\', \'I Am If I Changed, But You Changed Too.\', \'Anger Is My Power So Don’t Make Me Angry.\', \'Even The Nicest People Have Their Limits.\', \'Whatever Is Begun In Anger Ends In Shame.\', \'Don’T Make Me Angry And Change Your Status.\', \'Silence Is The Best Way To React While Angry. ( Angry Whatsapp Status\\xa0\', \'I Hope Karma Slaps You In The Face Before I Do.\', \'An Angry Man Opens His Mouth And Shuts His Eyes.\', \'I Am Not In A Bad Mood, Everyone Is Just Annoying.\', \'A Quick Temper Will Make A Fool Of You Soon Enough.\', \'Yes I Am Smiling But You Are Not The Reason Anymore.\', \'My Attitude Will Always Be Based On How You Treat Me.\', \'You Blocked Me On Facebook & Noe You’Re Going To Die.\', \'Anger Tears Me Up Inside…My Own…Or Anyone Else’S. (\\xa0Angry\\xa0Quotes\\xa0\', \'You Should Make A Woman Angry If You Wish Her To Love.\', \'Sometimes I’M Not Angry. I’M Hurt And There’S A Big Diff.\', \'Never Go To Bed Angry, Stay Awake And Plot Your Revenge.\', \'It’S Easier To Say You’re Mad Than To Admit You’Re Hurt.\', \'Don’T Make So Many Promises When You Can’T Even Keep One.\', \'We Met For A Reason, Either You’Re A Blessing Or A Lesson.\', \'I Hate The Moments When Suddenly My Anger Turns Into Tears.\', \'Tell The Truth, Or Eventually Someone Will Tell It For You. (\\xa0Angry Status\\xa0\', \'Its Just A Chapter In Your Life, Turn The Page And Move On.\', \'When People Get Angry With Him, I Remind Them That He’S Kid.\', \'If Someone Is Angry With You And You Laugh At Them, You Win.\', \'Nobody Makes You Angry. You Decide To Use Anger As A Response.\', \'I Miss You That True But It Doesn’t Mean I Forget Your Lies.\', \'The Best Revenge Is To Be Unlike Hi Who Performed The Injury.\', \'Anger Is Never Without A Reason, Butt Seldom With A Good One.\', \'If I Delete Your Number, You’Re Basically Deleted For My Life. (\\xa0Angry Whatsapp Status\\xa0\', \'Don’T Judge Someone Just Because They Sin Differently Than You.\', \'People Change. Things Go Wrong. Shit Happens. But Life Goes On.\', \'Anger Is Feeling That Make Your Mouth Work Faster Than Your Mind.\', \'Don’T Be Angry With People Who Don’T Have The Capacity To Change.\', \'All Angry Persons Are To Be Treated, By The Prudent, As Children.\', \'When U Are Angry, Ur Text Speed Increases By A Ridiculous Amount.\', \'If You Wake Me Up & I Don’T Get Angry, You Must Be Pretty Special.\', \'Control Your ” Anger “. It Is Just One Letter Away From “D” Anger.\\xa0( Angry Whatsapp Status\\xa0\', \'For Every Minute You Are Angry You Lose Sixty Seconds Of Happiness.\', \'Anger Is A Condition In Which The Tongue Works Faster Than The Mind.\', \'I Don’T Need Anger Management, I Need People To Stop Pissing Me Off.\', \'Unless I Am Sitting On Your Face My Weight Is None Of Your Business!\', \'People Won’T Have Time For You If You Are Always Angry Or Complaining.\', \'Just Because You’Re Angry, Doesn’T Mean You Have The Right To Be Cruel.\', \'Sometimes I Get To The Point Of Frustration, That I Just Become Silent.\', \'Some People Need To Open Their Small Minds Instead Of Their Big Mouths.\', \'When I’M Shouting, Your Fine. It’S When I Go Silent You Need To Worried.\\xa0(\\xa0Anger Status for Whatsapp\\xa0\', \'Anger Is Nothing Than An Outward Expression Of Hurt, Fear & Frustration.\', \'Never Do Anything When U Are In A Temper, For U Will Do Everything Wrong.\', \'Never Regret Anything, Because At One Time It Was Exactly What You Wanted.\', \'Sometimes I Feel Like Giving People A High-Five In That Face, With A Chair.\', \'Six Letters, Two Words, Easy To Say, Hard To Explain, Harder To Do. Move On.\', \'You Will Not Be Punished For Your Anger, You Will Be Punished By Your Anger.\', \'Holding On To Anger Is Like Drinking Poison And Expecting The Person To Die. ( Angry Whatsapp Status\\xa0\', \'No Matter How Angry You Get, You Always End Up Forgiving The People You Love.\', \'Life Is Too Short To Spend Tim ...
#  '"[\'Hating Me Won’T Make You Pretty.\', \'Anger Is One Letter Short Of Danger.\', \'I Am If I Changed, But You Changed Too.\', \'Anger Is My Power So Don’t Make Me Angry.\', \'Even The Nicest People Have Their Limits.\', \'Whatever Is Begun In Anger Ends In Shame.\', \'Don’T Make Me Angry And Change Your Status.\', \'Silence Is The Best Way To React While Angry. ( Angry Whatsapp Status\\xa0\', \'I Hope Karma Slaps You In The Face Before I Do.\', \'An Angry Man Opens His Mouth And Shuts His Eyes.\', \'I Am Not In A Bad Mood, Everyone Is Just Annoying.\', \'A Quick Temper Will Make A Fool Of You Soon Enough.\', \'Yes I Am Smiling But You Are Not The Reason Anymore.\', \'My Attitude Will Always Be Based On How You Treat Me.\', \'You Blocked Me On Facebook & Noe You’Re Going To Die.\', \'Anger Tears Me Up Inside…My Own…Or Anyone Else’S. (\\xa0Angry\\xa0Quotes\\xa0\', \'You Should Make A Woman Angry If You Wish Her To Love.\', \'Sometimes I’M Not Angry. I’M Hurt And There’S A Big Diff.\', \'Never Go To Bed Angry, Stay Awake And Plot Your Revenge.\', \'It’S Easier To Say You’re Mad Than To Admit You’Re Hurt.\', \'Don’T Make So Many Promises When You Can’T Even Keep One.\', \'We Met For A Reason, Either You’Re A Blessing Or A Lesson.\', \'I Hate The Moments When Suddenly My Anger Turns Into Tears.\', \'Tell The Truth, Or Eventually Someone Will Tell It For You. (\\xa0Angry Status\\xa0\', \'Its Just A Chapter In Your Life, Turn The Page And Move On.\', \'When People Get Angry With Him, I Remind Them That He’S Kid.\', \'If Someone Is Angry With You And You Laugh At Them, You Win.\', \'Nobody Makes You Angry. You Decide To Use Anger As A Response.\', \'I Miss You That True But It Doesn’t Mean I Forget Your Lies.\', \'The Best Revenge Is To Be Unlike Hi Who Performed The Injury.\', \'Anger Is Never Without A Reason, Butt Seldom With A Good One.\', \'If I Delete Your Number, You’Re Basically Deleted For My Life. (\\xa0Angry Whatsapp Status\\xa0\', \'Don’T Judge Someone Just Because They Sin Differently Than You.\', \'People Change. Things Go Wrong. Shit Happens. But Life Goes On.\', \'Anger Is Feeling That Make Your Mouth Work Faster Than Your Mind.\', \'Don’T Be Angry With People Who Don’T Have The Capacity To Change.\', \'All Angry Persons Are To Be Treated, By The Prudent, As Children.\', \'When U Are Angry, Ur Text Speed Increases By A Ridiculous Amount.\', \'If You Wake Me Up & I Don’T Get Angry, You Must Be Pretty Special.\', \'Control Your ” Anger “. It Is Just One Letter Away From “D” Anger.\\xa0( Angry Whatsapp Status\\xa0\', \'For Every Minute You Are Angry You Lose Sixty Seconds Of Happiness.\', \'Anger Is A Condition In Which The Tongue Works Faster Than The Mind.\', \'I Don’T Need Anger Management, I Need People To Stop Pissing Me Off.\', \'Unless I Am Sitting On Your Face My Weight Is None Of Your Business!\', \'People Won’T Have Time For You If You Are Always Angry Or Complaining.\', \'Just Because You’Re Angry, Doesn’T Mean You Have The Right To Be Cruel.\', \'Sometimes I Get To The Point Of Frustration, That I Just Become Silent.\', \'Some People Need To Open Their Small Minds Instead Of Their Big Mouths.\', \'When I’M Shouting, Your Fine. It’S When I Go Silent You Need To Worried.\\xa0(\\xa0Anger Status for Whatsapp\\xa0\', \'Anger Is Nothing Than An Outward Expression Of Hurt, Fear & Frustration.\', \'Never Do Anything When U Are In A Temper, For U Will Do Everything Wrong.\', \'Never Regret Anything, Because At One Time It Was Exactly What You Wanted.\', \'Sometimes I Feel Like Giving People A High-Five In That Face, With A Chair.\', \'Six Letters, Two Words, Easy To Say, Hard To Explain, Harder To Do. Move On.\', \'You Will Not Be Punished For Your Anger, You Will Be Punished By Your Anger.\', \'Holding On To Anger Is Like Drinking Poison And Expecting The Person To Die. ( Angry Whatsapp Status\\xa0\', \'No Matter How Angry You Get, You Always End Up Forgiving The People You Love.\', \'Life Is Too Short To Spend Tim ...
#  '"[\'Hating Me Won’T Make You Pretty.\', \'Anger Is One Letter Short Of Danger.\', \'I Am If I Changed, But You Changed Too.\', \'Anger Is My Power So Don’t Make Me Angry.\', \'Even The Nicest People Have Their Limits.\', \'Whatever Is Begun In Anger Ends In Shame.\', \'Don’T Make Me Angry And Change Your Status.\', \'Silence Is The Best Way To React While Angry. ( Angry Whatsapp Status\\xa0\', \'I Hope Karma Slaps You In The Face Before I Do.\', \'An Angry Man Opens His Mouth And Shuts His Eyes.\', \'I Am Not In A Bad Mood, Everyone Is Just Annoying.\', \'A Quick Temper Will Make A Fool Of You Soon Enough.\', \'Yes I Am Smiling But You Are Not The Reason Anymore.\', \'My Attitude Will Always Be Based On How You Treat Me.\', \'You Blocked Me On Facebook & Noe You’Re Going To Die.\', \'Anger Tears Me Up Inside…My Own…Or Anyone Else’S. (\\xa0Angry\\xa0Quotes\\xa0\', \'You Should Make A Woman Angry If You Wish Her To Love.\', \'Sometimes I’M Not Angry. I’M Hurt And There’S A Big Diff.\', \'Never Go To Bed Angry, Stay Awake And Plot Your Revenge.\', \'It’S Easier To Say You’re Mad Than To Admit You’Re Hurt.\', \'Don’T Make So Many Promises When You Can’T Even Keep One.\', \'We Met For A Reason, Either You’Re A Blessing Or A Lesson.\', \'I Hate The Moments When Suddenly My Anger Turns Into Tears.\', \'Tell The Truth, Or Eventually Someone Will Tell It For You. (\\xa0Angry Status\\xa0\', \'Its Just A Chapter In Your Life, Turn The Page And Move On.\', \'When People Get Angry With Him, I Remind Them That He’S Kid.\', \'If Someone Is Angry With You And You Laugh At Them, You Win.\', \'Nobody Makes You Angry. You Decide To Use Anger As A Response.\', \'I Miss You That True But It Doesn’t Mean I Forget Your Lies.\', \'The Best Revenge Is To Be Unlike Hi Who Performed The Injury.\', \'Anger Is Never Without A Reason, Butt Seldom With A Good One.\', \'If I Delete Your Number, You’Re Basically Deleted For My Life. (\\xa0Angry Whatsapp Status\\xa0\', \'Don’T Judge Someone Just Because They Sin Differently Than You.\', \'People Change. Things Go Wrong. Shit Happens. But Life Goes On.\', \'Anger Is Feeling That Make Your Mouth Work Faster Than Your Mind.\', \'Don’T Be Angry With People Who Don’T Have The Capacity To Change.\', \'All Angry Persons Are To Be Treated, By The Prudent, As Children.\', \'When U Are Angry, Ur Text Speed Increases By A Ridiculous Amount.\', \'If You Wake Me Up & I Don’T Get Angry, You Must Be Pretty Special.\', \'Control Your ” Anger “. It Is Just One Letter Away From “D” Anger.\\xa0( Angry Whatsapp Status\\xa0\', \'For Every Minute You Are Angry You Lose Sixty Seconds Of Happiness.\', \'Anger Is A Condition In Which The Tongue Works Faster Than The Mind.\', \'I Don’T Need Anger Management, I Need People To Stop Pissing Me Off.\', \'Unless I Am Sitting On Your Face My Weight Is None Of Your Business!\', \'People Won’T Have Time For You If You Are Always Angry Or Complaining.\', \'Just Because You’Re Angry, Doesn’T Mean You Have The Right To Be Cruel.\', \'Sometimes I Get To The Point Of Frustration, That I Just Become Silent.\', \'Some People Need To Open Their Small Minds Instead Of Their Big Mouths.\', \'When I’M Shouting, Your Fine. It’S When I Go Silent You Need To Worried.\\xa0(\\xa0Anger Status for Whatsapp\\xa0\', \'Anger Is Nothing Than An Outward Expression Of Hurt, Fear & Frustration.\', \'Never Do Anything When U Are In A Temper, For U Will Do Everything Wrong.\', \'Never Regret Anything, Because At One Time It Was Exactly What You Wanted.\', \'Sometimes I Feel Like Giving People A High-Five In That Face, With A Chair.\', \'Six Letters, Two Words, Easy To Say, Hard To Explain, Harder To Do. Move On.\', \'You Will Not Be Punished For Your Anger, You Will Be Punished By Your Anger.\', \'Holding On To Anger Is Like Drinking Poison And Expecting The Person To Die. ( Angry Whatsapp Status\\xa0\', \'No Matter How Angry You Get, You Always End Up Forgiving The People You Love.\', \'Life Is Too Short To Spend Tim ...
#  '"[\'Hating Me Won’T Make You Pretty.\', \'Anger Is One Letter Short Of Danger.\', \'I Am If I Changed, But You Changed Too.\', \'Anger Is My Power So Don’t Make Me Angry.\', \'Even The Nicest People Have Their Limits.\', \'Whatever Is Begun In Anger Ends In Shame.\', \'Don’T Make Me Angry And Change Your Status.\', \'Silence Is The Best Way To React While Angry. ( Angry Whatsapp Status\\xa0\', \'I Hope Karma Slaps You In The Face Before I Do.\', \'An Angry Man Opens His Mouth And Shuts His Eyes.\', \'I Am Not In A Bad Mood, Everyone Is Just Annoying.\', \'A Quick Temper Will Make A Fool Of You Soon Enough.\', \'Yes I Am Smiling But You Are Not The Reason Anymore.\', \'My Attitude Will Always Be Based On How You Treat Me.\', \'You Blocked Me On Facebook & Noe You’Re Going To Die.\', \'Anger Tears Me Up Inside…My Own…Or Anyone Else’S. (\\xa0Angry\\xa0Quotes\\xa0\', \'You Should Make A Woman Angry If You Wish Her To Love.\', \'Sometimes I’M Not Angry. I’M Hurt And There’S A Big Diff.\', \'Never Go To Bed Angry, Stay Awake And Plot Your Revenge.\', \'It’S Easier To Say You’re Mad Than To Admit You’Re Hurt.\', \'Don’T Make So Many Promises When You Can’T Even Keep One.\', \'We Met For A Reason, Either You’Re A Blessing Or A Lesson.\', \'I Hate The Moments When Suddenly My Anger Turns Into Tears.\', \'Tell The Truth, Or Eventually Someone Will Tell It For You. (\\xa0Angry Status\\xa0\', \'Its Just A Chapter In Your Life, Turn The Page And Move On.\', \'When People Get Angry With Him, I Remind Them That He’S Kid.\', \'If Someone Is Angry With You And You Laugh At Them, You Win.\', \'Nobody Makes You Angry. You Decide To Use Anger As A Response.\', \'I Miss You That True But It Doesn’t Mean I Forget Your Lies.\', \'The Best Revenge Is To Be Unlike Hi Who Performed The Injury.\', \'Anger Is Never Without A Reason, Butt Seldom With A Good One.\', \'If I Delete Your Number, You’Re Basically Deleted For My Life. (\\xa0Angry Whatsapp Status\\xa0\', \'Don’T Judge Someone Just Because They Sin Differently Than You.\', \'People Change. Things Go Wrong. Shit Happens. But Life Goes On.\', \'Anger Is Feeling That Make Your Mouth Work Faster Than Your Mind.\', \'Don’T Be Angry With People Who Don’T Have The Capacity To Change.\', \'All Angry Persons Are To Be Treated, By The Prudent, As Children.\', \'When U Are Angry, Ur Text Speed Increases By A Ridiculous Amount.\', \'If You Wake Me Up & I Don’T Get Angry, You Must Be Pretty Special.\', \'Control Your ” Anger “. It Is Just One Letter Away From “D” Anger.\\xa0( Angry Whatsapp Status\\xa0\', \'For Every Minute You Are Angry You Lose Sixty Seconds Of Happiness.\', \'Anger Is A Condition In Which The Tongue Works Faster Than The Mind.\', \'I Don’T Need Anger Management, I Need People To Stop Pissing Me Off.\', \'Unless I Am Sitting On Your Face My Weight Is None Of Your Business!\', \'People Won’T Have Time For You If You Are Always Angry Or Complaining.\', \'Just Because You’Re Angry, Doesn’T Mean You Have The Right To Be Cruel.\', \'Sometimes I Get To The Point Of Frustration, That I Just Become Silent.\', \'Some People Need To Open Their Small Minds Instead Of Their Big Mouths.\', \'When I’M Shouting, Your Fine. It’S When I Go Silent You Need To Worried.\\xa0(\\xa0Anger Status for Whatsapp\\xa0\', \'Anger Is Nothing Than An Outward Expression Of Hurt, Fear & Frustration.\', \'Never Do Anything When U Are In A Temper, For U Will Do Everything Wrong.\', \'Never Regret Anything, Because At One Time It Was Exactly What You Wanted.\', \'Sometimes I Feel Like Giving People A High-Five In That Face, With A Chair.\', \'Six Letters, Two Words, Easy To Say, Hard To Explain, Harder To Do. Move On.\', \'You Will Not Be Punished For Your Anger, You Will Be Punished By Your Anger.\', \'Holding On To Anger Is Like Drinking Poison And Expecting The Person To Die. ( Angry Whatsapp Status\\xa0\', \'No Matter How Angry You Get, You Always End Up Forgiving The People You Love.\', \'Life Is Too Short To Spend Tim ...
#  '"[\'Hating Me Won’T Make You Pretty.\', \'Anger Is One Letter Short Of Danger.\', \'I Am If I Changed, But You Changed Too.\', \'Anger Is My Power So Don’t Make Me Angry.\', \'Even The Nicest People Have Their Limits.\', \'Whatever Is Begun In Anger Ends In Shame.\', \'Don’T Make Me Angry And Change Your Status.\', \'Silence Is The Best Way To React While Angry. ( Angry Whatsapp Status\\xa0\', \'I Hope Karma Slaps You In The Face Before I Do.\', \'An Angry Man Opens His Mouth And Shuts His Eyes.\', \'I Am Not In A Bad Mood, Everyone Is Just Annoying.\', \'A Quick Temper Will Make A Fool Of You Soon Enough.\', \'Yes I Am Smiling But You Are Not The Reason Anymore.\', \'My Attitude Will Always Be Based On How You Treat Me.\', \'You Blocked Me On Facebook & Noe You’Re Going To Die.\', \'Anger Tears Me Up Inside…My Own…Or Anyone Else’S. (\\xa0Angry\\xa0Quotes\\xa0\', \'You Should Make A Woman Angry If You Wish Her To Love.\', \'Sometimes I’M Not Angry. I’M Hurt And There’S A Big Diff.\', \'Never Go To Bed Angry, Stay Awake And Plot Your Revenge.\', \'It’S Easier To Say You’re Mad Than To Admit You’Re Hurt.\', \'Don’T Make So Many Promises When You Can’T Even Keep One.\', \'We Met For A Reason, Either You’Re A Blessing Or A Lesson.\', \'I Hate The Moments When Suddenly My Anger Turns Into Tears.\', \'Tell The Truth, Or Eventually Someone Will Tell It For You. (\\xa0Angry Status\\xa0\', \'Its Just A Chapter In Your Life, Turn The Page And Move On.\', \'When People Get Angry With Him, I Remind Them That He’S Kid.\', \'If Someone Is Angry With You And You Laugh At Them, You Win.\', \'Nobody Makes You Angry. You Decide To Use Anger As A Response.\', \'I Miss You That True But It Doesn’t Mean I Forget Your Lies.\', \'The Best Revenge Is To Be Unlike Hi Who Performed The Injury.\', \'Anger Is Never Without A Reason, Butt Seldom With A Good One.\', \'If I Delete Your Number, You’Re Basically Deleted For My Life. (\\xa0Angry Whatsapp Status\\xa0\', \'Don’T Judge Someone Just Because They Sin Differently Than You.\', \'People Change. Things Go Wrong. Shit Happens. But Life Goes On.\', \'Anger Is Feeling That Make Your Mouth Work Faster Than Your Mind.\', \'Don’T Be Angry With People Who Don’T Have The Capacity To Change.\', \'All Angry Persons Are To Be Treated, By The Prudent, As Children.\', \'When U Are Angry, Ur Text Speed Increases By A Ridiculous Amount.\', \'If You Wake Me Up & I Don’T Get Angry, You Must Be Pretty Special.\', \'Control Your ” Anger “. It Is Just One Letter Away From “D” Anger.\\xa0( Angry Whatsapp Status\\xa0\', \'For Every Minute You Are Angry You Lose Sixty Seconds Of Happiness.\', \'Anger Is A Condition In Which The Tongue Works Faster Than The Mind.\', \'I Don’T Need Anger Management, I Need People To Stop Pissing Me Off.\', \'Unless I Am Sitting On Your Face My Weight Is None Of Your Business!\', \'People Won’T Have Time For You If You Are Always Angry Or Complaining.\', \'Just Because You’Re Angry, Doesn’T Mean You Have The Right To Be Cruel.\', \'Sometimes I Get To The Point Of Frustration, That I Just Become Silent.\', \'Some People Need To Open Their Small Minds Instead Of Their Big Mouths.\', \'When I’M Shouting, Your Fine. It’S When I Go Silent You Need To Worried.\\xa0(\\xa0Anger Status for Whatsapp\\xa0\', \'Anger Is Nothing Than An Outward Expression Of Hurt, Fear & Frustration.\', \'Never Do Anything When U Are In A Temper, For U Will Do Everything Wrong.\', \'Never Regret Anything, Because At One Time It Was Exactly What You Wanted.\', \'Sometimes I Feel Like Giving People A High-Five In That Face, With A Chair.\', \'Six Letters, Two Words, Easy To Say, Hard To Explain, Harder To Do. Move On.\', \'You Will Not Be Punished For Your Anger, You Will Be Punished By Your Anger.\', \'Holding On To Anger Is Like Drinking Poison And Expecting The Person To Die. ( Angry Whatsapp Status\\xa0\', \'No Matter How Angry You Get, You Always End Up Forgiving The People You Love.\', \'Life Is Too Short To Spend Tim ...
#  '"[\'Hating Me Won’T Make You Pretty.\', \'Anger Is One Letter Short Of Danger.\', \'I Am If I Changed, But You Changed Too.\', \'Anger Is My Power So Don’t Make Me Angry.\', \'Even The Nicest People Have Their Limits.\', \'Whatever Is Begun In Anger Ends In Shame.\', \'Don’T Make Me Angry And Change Your Status.\', \'Silence Is The Best Way To React While Angry. ( Angry Whatsapp Status\\xa0\', \'I Hope Karma Slaps You In The Face Before I Do.\', \'An Angry Man Opens His Mouth And Shuts His Eyes.\', \'I Am Not In A Bad Mood, Everyone Is Just Annoying.\', \'A Quick Temper Will Make A Fool Of You Soon Enough.\', \'Yes I Am Smiling But You Are Not The Reason Anymore.\', \'My Attitude Will Always Be Based On How You Treat Me.\', \'You Blocked Me On Facebook & Noe You’Re Going To Die.\', \'Anger Tears Me Up Inside…My Own…Or Anyone Else’S. (\\xa0Angry\\xa0Quotes\\xa0\', \'You Should Make A Woman Angry If You Wish Her To Love.\', \'Sometimes I’M Not Angry. I’M Hurt And There’S A Big Diff.\', \'Never Go To Bed Angry, Stay Awake And Plot Your Revenge.\', \'It’S Easier To Say You’re Mad Than To Admit You’Re Hurt.\', \'Don’T Make So Many Promises When You Can’T Even Keep One.\', \'We Met For A Reason, Either You’Re A Blessing Or A Lesson.\', \'I Hate The Moments When Suddenly My Anger Turns Into Tears.\', \'Tell The Truth, Or Eventually Someone Will Tell It For You. (\\xa0Angry Status\\xa0\', \'Its Just A Chapter In Your Life, Turn The Page And Move On.\', \'When People Get Angry With Him, I Remind Them That He’S Kid.\', \'If Someone Is Angry With You And You Laugh At Them, You Win.\', \'Nobody Makes You Angry. You Decide To Use Anger As A Response.\', \'I Miss You That True But It Doesn’t Mean I Forget Your Lies.\', \'The Best Revenge Is To Be Unlike Hi Who Performed The Injury.\', \'Anger Is Never Without A Reason, Butt Seldom With A Good One.\', \'If I Delete Your Number, You’Re Basically Deleted For My Life. (\\xa0Angry Whatsapp Status\\xa0\', \'Don’T Judge Someone Just Because They Sin Differently Than You.\', \'People Change. Things Go Wrong. Shit Happens. But Life Goes On.\', \'Anger Is Feeling That Make Your Mouth Work Faster Than Your Mind.\', \'Don’T Be Angry With People Who Don’T Have The Capacity To Change.\', \'All Angry Persons Are To Be Treated, By The Prudent, As Children.\', \'When U Are Angry, Ur Text Speed Increases By A Ridiculous Amount.\', \'If You Wake Me Up & I Don’T Get Angry, You Must Be Pretty Special.\', \'Control Your ” Anger “. It Is Just One Letter Away From “D” Anger.\\xa0( Angry Whatsapp Status\\xa0\', \'For Every Minute You Are Angry You Lose Sixty Seconds Of Happiness.\', \'Anger Is A Condition In Which The Tongue Works Faster Than The Mind.\', \'I Don’T Need Anger Management, I Need People To Stop Pissing Me Off.\', \'Unless I Am Sitting On Your Face My Weight Is None Of Your Business!\', \'People Won’T Have Time For You If You Are Always Angry Or Complaining.\', \'Just Because You’Re Angry, Doesn’T Mean You Have The Right To Be Cruel.\', \'Sometimes I Get To The Point Of Frustration, That I Just Become Silent.\', \'Some People Need To Open Their Small Minds Instead Of Their Big Mouths.\', \'When I’M Shouting, Your Fine. It’S When I Go Silent You Need To Worried.\\xa0(\\xa0Anger Status for Whatsapp\\xa0\', \'Anger Is Nothing Than An Outward Expression Of Hurt, Fear & Frustration.\', \'Never Do Anything When U Are In A Temper, For U Will Do Everything Wrong.\', \'Never Regret Anything, Because At One Time It Was Exactly What You Wanted.\', \'Sometimes I Feel Like Giving People A High-Five In That Face, With A Chair.\', \'Six Letters, Two Words, Easy To Say, Hard To Explain, Harder To Do. Move On.\', \'You Will Not Be Punished For Your Anger, You Will Be Punished By Your Anger.\', \'Holding On To Anger Is Like Drinking Poison And Expecting The Person To Die. ( Angry Whatsapp Status\\xa0\', \'No Matter How Angry You Get, You Always End Up Forgiving The People You Love.\', \'Life Is Too Short To Spend Tim ...
#  '"[\'Hating Me Won’T Make You Pretty.\', \'Anger Is One Letter Short Of Danger.\', \'I Am If I Changed, But You Changed Too.\', \'Anger Is My Power So Don’t Make Me Angry.\', \'Even The Nicest People Have Their Limits.\', \'Whatever Is Begun In Anger Ends In Shame.\', \'Don’T Make Me Angry And Change Your Status.\', \'Silence Is The Best Way To React While Angry. ( Angry Whatsapp Status\\xa0\', \'I Hope Karma Slaps You In The Face Before I Do.\', \'An Angry Man Opens His Mouth And Shuts His Eyes.\', \'I Am Not In A Bad Mood, Everyone Is Just Annoying.\', \'A Quick Temper Will Make A Fool Of You Soon Enough.\', \'Yes I Am Smiling But You Are Not The Reason Anymore.\', \'My Attitude Will Always Be Based On How You Treat Me.\', \'You Blocked Me On Facebook & Noe You’Re Going To Die.\', \'Anger Tears Me Up Inside…My Own…Or Anyone Else’S. (\\xa0Angry\\xa0Quotes\\xa0\', \'You Should Make A Woman Angry If You Wish Her To Love.\', \'Sometimes I’M Not Angry. I’M Hurt And There’S A Big Diff.\', \'Never Go To Bed Angry, Stay Awake And Plot Your Revenge.\', \'It’S Easier To Say You’re Mad Than To Admit You’Re Hurt.\', \'Don’T Make So Many Promises When You Can’T Even Keep One.\', \'We Met For A Reason, Either You’Re A Blessing Or A Lesson.\', \'I Hate The Moments When Suddenly My Anger Turns Into Tears.\', \'Tell The Truth, Or Eventually Someone Will Tell It For You. (\\xa0Angry Status\\xa0\', \'Its Just A Chapter In Your Life, Turn The Page And Move On.\', \'When People Get Angry With Him, I Remind Them That He’S Kid.\', \'If Someone Is Angry With You And You Laugh At Them, You Win.\', \'Nobody Makes You Angry. You Decide To Use Anger As A Response.\', \'I Miss You That True But It Doesn’t Mean I Forget Your Lies.\', \'The Best Revenge Is To Be Unlike Hi Who Performed The Injury.\', \'Anger Is Never Without A Reason, Butt Seldom With A Good One.\', \'If I Delete Your Number, You’Re Basically Deleted For My Life. (\\xa0Angry Whatsapp Status\\xa0\', \'Don’T Judge Someone Just Because They Sin Differently Than You.\', \'People Change. Things Go Wrong. Shit Happens. But Life Goes On.\', \'Anger Is Feeling That Make Your Mouth Work Faster Than Your Mind.\', \'Don’T Be Angry With People Who Don’T Have The Capacity To Change.\', \'All Angry Persons Are To Be Treated, By The Prudent, As Children.\', \'When U Are Angry, Ur Text Speed Increases By A Ridiculous Amount.\', \'If You Wake Me Up & I Don’T Get Angry, You Must Be Pretty Special.\', \'Control Your ” Anger “. It Is Just One Letter Away From “D” Anger.\\xa0( Angry Whatsapp Status\\xa0\', \'For Every Minute You Are Angry You Lose Sixty Seconds Of Happiness.\', \'Anger Is A Condition In Which The Tongue Works Faster Than The Mind.\', \'I Don’T Need Anger Management, I Need People To Stop Pissing Me Off.\', \'Unless I Am Sitting On Your Face My Weight Is None Of Your Business!\', \'People Won’T Have Time For You If You Are Always Angry Or Complaining.\', \'Just Because You’Re Angry, Doesn’T Mean You Have The Right To Be Cruel.\', \'Sometimes I Get To The Point Of Frustration, That I Just Become Silent.\', \'Some People Need To Open Their Small Minds Instead Of Their Big Mouths.\', \'When I’M Shouting, Your Fine. It’S When I Go Silent You Need To Worried.\\xa0(\\xa0Anger Status for Whatsapp\\xa0\', \'Anger Is Nothing Than An Outward Expression Of Hurt, Fear & Frustration.\', \'Never Do Anything When U Are In A Temper, For U Will Do Everything Wrong.\', \'Never Regret Anything, Because At One Time It Was Exactly What You Wanted.\', \'Sometimes I Feel Like Giving People A High-Five In That Face, With A Chair.\', \'Six Letters, Two Words, Easy To Say, Hard To Explain, Harder To Do. Move On.\', \'You Will Not Be Punished For Your Anger, You Will Be Punished By Your Anger.\', \'Holding On To Anger Is Like Drinking Poison And Expecting The Person To Die. ( Angry Whatsapp Status\\xa0\', \'No Matter How Angry You Get, You Always End Up Forgiving The People You Love.\', \'Life Is Too Short To Spend Tim ...
# ...
#  'It just seems like the past few weeks have been one very long bad day!,angry',
#  'Thinks it would be really nice of you to go sit on a cactus,angry',
#  'Anger is an acid that can do more harm to the vessel in which it is stored than to anything on which it is poured. But I really don’t care.,angry',
#  'I actually don’t need to control my anger. Everyone around me needs to control their habit of pissing me off…,angry',
#  '"I think that stupid people were put on this planet to test my anger\xa0management\xa0skills.,",angry',
#  'A good woman doesn’t get angry and she sure as hell doesn’t get even. She gets over it and keeps it moving.,angry',
#  '"People don’t listen, they just wait for their turn to talk.",angry',
#  'How stupid of me to believe a boy like you could love a girl like me.,angry',
#  'Why stress over someone that won’t even text to see if you’re alright?,angry',
#  '"You were my cup of tea, I drink coffee now.",angry',
#  '"I don’t give up easily on someone, but when I finally do I will be so done with you and nothing you’ll ever do will bring me back.",angry',
#  '"I don’t have time to hate anyone,\xa0I\xa0will just forget about you.",angry',
#  'Choose people who choose you.,angry',
#  '"If someone breaks your heart, just punch them in the face. Seriously. Punch them in\xa0faceand go get some ice-cream",angry',
#  '"I don’t hate you, but I have lost all the reason to love you.",angry',
#  '“I didn’t lose you. you lost me. You’ll search for me inside of everyone you’re with &I won’t be found. ”- R.H.Sin.,angry',
#  '"I didn’t stop loving you. I decided to stop showing\xa0it\xa0because no matter how hard I tried, you wouldn’t get it.",angry',
#  'I had a lot of reasons to give up on you. But I still chose to stay. You had a lot of reasons to stay. But you chose to give up…,angry',
#  '"I’m a little bitter today, sorry if I offend anyone, but right now with the\xa0mood, I’m in I really don’t care..",angry',
#  '"Don’t chat with me when you are bored. Bitch, please! I’m not here for your entertainment.",angry',
#  'I just don’t care if anyone doesn’t like me. I wasn’t put on earth to entertain everyone.,angry',
#  'It sucks when you realize you rejected other people for that one person who wasted your time.,angry',
#  '"No matter how long you know someone, they eventually show their true colors.",angry',
#  'Sometimes I’m just not in the mood to talk.,angry',
#  '"Anger is never without a reason, but seldom with a good one.",angry',
#  '"Anger is not bad. Anger can be a very positive thing, the thing that moves us beyond the acceptance of evil.",angry',
#  'I will not delete you or block you. I am keeping you there so you will be able to see how happy I’m without you.,angry',
#  '"I may look calm, but in my head, I’ve killed you about 5 times.",angry',
#  'Some people need to open their small minds instead of their big mouths.,angry',
#  'Anger is a temporary madness.,angry',
#  '"Anger is a great force. If you control it, it can be transmuted into a power which can move the whole world.",angry',
#  '"Don’t try to please other people if, in the end, you know it won’t work.",angry',
#  '"Everything is getting expensive except some people, they are getting cheaper.",angry',
#  '"If you’re going to talk about me behind my back, don’t smile at me to my face!",angry',
#  '"People change, things go wrong, shit happens, but life goes on.",angry',
#  '"Just because I’m being quiet, that doesn’t mean I’m mad.",angry',
#  '"Nobody makes you angry, you decide to use anger as a response.",angry',
#  'Never forget what someone says to you when they are angry because that’s when the truth comes out.,angry',
#  'It sucks when you realize you rejected other people for that one person who wasted your time.,angry',
#  'Some people never realize the emotional and mental damage they do to others.,angry',
#  'My silence doesn’t mean that I quit… It simply means that I don’t want to argue with people who just don’t want to understand.,angry',
#  'Never make yourself feel like nothing to make someone else feel like everything.,angry',
#  '"It’s better to cry than to be angry because anger hurts others, while tears flow silently through the soul and cleanness the heart…",angry',
#  '"If you’re going to talk about me behind my back, don’t smile at me to my face!",angry',
#  'Sometimes one middle finger isn’t enough to let someone know how you feel. That’s why you have two hands.,angry',
#  'Anger is an acid that can do more harm to the vessel in which it is stored than to anything on which it is poured.,angry',
#  '"Sometimes I’m not angry, I’m hurt and there’s a big difference.",angry',
#  'Definition of EX: Thanks for the experience. Our time has expired. Now exit my life.,angry',
#  'Never regret something that once made you smile.,angry',
#  'Anger blows out the lamp of the mind.,angry',
#  'Anger dwells only in the bosom of fools.,angry',
#  '"Anger as soon as fed is dead, Its starving makes it fat.",angry',
#  '"Don’t be so happy, I don’t really forgive people, I just pretend like it’s OK and wait for my turn to destroy them.",angry',
#  'Never forget what someone says to you when they are angry because that’s when the truth comes out.,angry',
#  '"For every minute you remain angry, you give up sixty seconds of peace of mind.",angry',
#  'A person who has lots of anger inside definitely loves people more than anyone else can. because if red color indicates anger then it indicates love too…,angry',
#  '"By God, there’s a lot to make you angry.",angry',
#  'Some people will pretend to care just so they can get a better seat to watch your struggle. Every helping hand is not always there to help.,angry',
#  '"When you are angry, your text speed increases by a ridiculous amount.",angry',
#  '"Beware, I’m not in my greatest mood today.",angry',
#  'There are no words to describe the anger and frustration that I am feeling right now.,angry',
#  'Anger is a feeling that makes your mouth work faster than your mind.,angry',
#  'Only Two People will tell you the truth about yourself: someone who is angry with you and someone who loves you.,angry',
#  '"Anger is our natural defense against pain. So when I say, I hate you – it really means you hurt me.",angry',
#  '"It’s better to cry than to be angry because anger hurts others, while tears flow silently through the soul and cleanness the heart.",angry',
#  '"Feelings are much like waves, we can’t stop them from coming but we can choose which ones to surf.",angry',
#  '"If you want to hear the whole truth about yourself, make your neighbor angry.",angry',
#  'Anger is only one letter short of Danger.,angry',
#  'For every minute you are angry. You lose sixty seconds of happiness. Think about It…,angry',
#  '"No matter how long you know someone, they eventually show their true colors.",angry',
#  'May I kill you in the morning?,angry',
#  'Is getting close to just walking away?,angry',
#  '"Anger makes you smaller, while forgiveness forces you to grow beyond what you were.",angry',
#  'Hating Me Won’T Make You Pretty.,angry',
#  'Anger Is One Letter Short Of Danger.,angry',
#  '"I Am If I Changed, But You Changed Too.",angry',
#  'Anger Is My Power So Don’t Make Me Angry.,angry',
#  'Even The Nicest People Have Their Limits.,angry',
#  'Whatever Is Begun In Anger Ends In Shame.,angry',
#  'Don’t Make Me Angry And Change Your Status.,angry',
#  'Silence Is The Best Way To React While Angry.,angry',
#  '"It’s Just A Chapter In Your Life, Turn The Page And Move On.",angry',
#  '"When People Get Angry With Him, I Remind Them That He’S Kid.",angry',
#  '"If Someone Is Angry With You And You Laugh At Them, You Win.",angry',
#  'Nobody Makes You Angry. You Decide To Use Anger As A Response.,angry',
#  'I Miss You That True But It Doesn’t Mean I Forget Your Lies.,angry',
#  'I will not delete you or block you. I am keeping you there so you will be able to see how happy I’m without you.,angry',
#  '"I may look calm, but in my head, I’ve killed you about 5 times.",angry',
#  '"People change, things go wrong, shit happens, but life goes on.",angry',
#  '"Just because I’m being quiet, that doesn’t mean I’m mad.",angry',
#  'It sucks when you realize you rejected other people for that one person who wasted your time.,angry',
#  'My silence doesn’t mean that I quit… It simply means that I don’t want to argue with people who just don’t want to understand!,angry',
#  '"For every minute you remain angry, you give up sixty seconds of peace of mind.",angry',
#  'A person who has lots of anger inside definitely loves people more than anyone else can. because if red color indicates anger then it indicates love too…,angry',
#  'Never regret something that once made you smile.,angry',
#  'I do not exist to impress the world. I exist to live my life in a way that will make me happy.,angry',
#  '"Everything is getting expensive except some people, they are getting cheaper.",angry',
#  'My phone screen is brighter than my future ?,angry',
#  'Anger is a feeling that makes your mouth work than faster your mind..,angry',
#  '"This man, is man, a man, good man, way man, to man, keep man, a man, idiot man, busy man, for man, 30 man, seconds man! NOW READ WITHOUT MAN",angry',
#  'Sometimes the best way to get someone\\’s attention is to stop giving them yours.,angry',
#  'Girls r like potato chips…you can’t have 1,angry',
#  'Had you asked for my life i would have sacrificed it with a smile… but you’ve stripped me of my pride,angry',
#  'People always miss you more when they find out how much happier you are without them.,angry',
#  '"People change for one of two reasons: They have learned a lot, or they have been hurt too many times.",angry',
#  'If you fail and feels the shame then you are only few steps away from success,angry',
#  'Listen to people when they are\xa0angry\xa0because that is when the real truth comes out.,angry',
#  '"Don’t fuck with my feelings, just because you’re unsure of your own.",angry',
#  '"My feelings? Oh don’t worry about those, no one else does.",angry',
#  'A man is about as big as the things that\xa0make\xa0him angry.,angry',
#  'An angry man opens his mouth and shuts his eyes.,angry',
#  '"I didn’t text you just to exercise my fingers, I was expecting a reply back.",angry',
#  'I hate that I cry when I’m frustrated because people think I’m hurt when I’m really just trying not to kill you.,angry',
#  '"I don’t usually lose my temper, but if I get angry, it’s true I’m\xa0scary.",angry',
#  'I’m not anti-social. I’m just anti-bullshit.,angry',
#  'don’t be angry with people who don’t have\xa0the capacity\xa0to change.,angry',
#  '"My life, My choices, My problems, My mistakes, My lessons. Not your business, mind your own problems before you talk about mine.",angry',
#  '"I told you I needed you, you told me the same. I wasn’t lying, so why didn’t you tell the truth?",angry',
#  '"A fool gives full vent to his anger, but a wise man keeps himself under control.",angry',
#  'Anger is a condition in which the tongue works faster than the mind.,angry',
#  'I just don’t care if anyone doesn’t like me I wasn’t put on earth to entertain everyone.,angry',
#  '"When you stopped believing in me, I did too.",angry',
#  'Don’t get mad – Just get even.,angry',
#  '"My silence doesn’t mean that I quit, It simply means that I don’t want to argue with people who just don’t want to understand.",angry',
#  '"Don’t talk to me only when you need me, I am not here for entertainment.",angry',
#  'Don’t chat with me just when you’re bored. I am not here for entertainment.,angry',
#  'CAUTION!! I’m not in my greatest mood today.,angry',
#  'Beware!! I am in a bad mood today.,angry',
#  'Do you ever get the feeling that you would like to reach out and just choke someone?,angry',
#  'I am in a mood to kill somebody today.,angry',
#  '"When we don’t know who to hate, we hate ourselves.",angry',
#  'I’m gonna come back as a bird in my next life. There are some people who I feel deserve a little of their own medicine.,angry',
#  'There are no words to describe the anger and frustration that I am feeling right now.,angry',
#  '"When a woman cries, it’s not usually over one thing. It’s built up anger and emotions she’s been holding in for too long.",angry',
#  'I don’t have time for fake friends anymore. Either be real or be gone.,angry',
#  'And a mistake repeated more than once is a decision.,angry',
#  'I don’t allow you to treat me poorly just because\xa0I\xa0love you.,angry',
#  'Silence .. because that’s the only thing you deserve from me now.,angry',
#  '"Be careful with your words. Once they are said, they can be only forgiven, not forgotten.",angry',
#  '"Be careful with your words and action,\xa0I\xa0can only forgive, not forget.",angry',
#  'Isn’t it funny how people think you won’t find out about all the shit they have said about you?,angry',
#  'Who needs cocaine when human emotions can fuck you up just the same.,angry',
#  '"I gave up on you. Not because I don’t care anymore, but because I realized that you don’t.",angry',
#  '"If you think your opinion of me has any effect, honey let me assure you that none of my\xa0self-worth\xa0is wrapped up in what you think of\xa0me.",angry',
#  '"When we don’t know who to hate, we hate ourselves.",angry',
#  '"Never go to bed angry, stay up and fight.",angry',
#  '"The strong man is not the good wrestler, the strong man is, only the one who controls himself when he is angry.",angry',
#  'It Takes A Lot Of Energy To Get Angry. I Don’T Care To Use My Energy That Way.,angry',
#  '"I Will Not Delete You Or Block You. I Am Keeping You There So, You Will Be Able To See How Happy I’M Without You",angry',
#  '"Don’t Be So Happy, I Don’T Really Forgive People, I Just Pretend Like It’s Ok And Waits For My Turn To Destroy them.",angry',
#  'Some People Need To Open Their Small Minds Instead Of Their Big Mouths.,angry',
#  '"If I Delete Your Number, You’Re Basically Deleted From My Life.",angry',
#  'Anger repressed can poison a relationship as surely as the cruelest words.,angry',
#  '"Anger is never without a reason, but seldom with a good one.",angry',
#  '"Anger is not bad. Anger can be a very positive thing, the thing that moves us beyond the acceptance of evil.",angry',
#  '"Go Ahead, Judge Me. Just Remember To Be Perfect For The Rest Of Your Life!!",angry',
#  'I Wouldn’t Have To Manage My Anger If People Could Learn To Manage Their Stupidity.,angry',
#  'It Sucks When You Realise You Rejected Other People For That One Person Who Wasted Your Time.,angry',
#  '"Nobody makes you angry, you decide to use anger as a response.",angry',
#  '"All angry persons are to be treated, by the prudent, as children.",angry',
#  '"Anger is never without a Reason, but seldom with a good one.",angry',
#  'Silence is the best way to react while angry.,angry',
#  '"Never go to bed angry, stay awake and plot your revenge!",angry',
#  '"When you ask someone if you overreacted, then that’s your heart telling your mind that it was a stupid decision.",angry',
#  '"Angry? Take a deep breath before you speak, because your mouth acts quicker than your brain.",angry',
#  'The embarrassment after the anger is the biggest humiliation a person can experience.,angry',
#  'A moment of patience in a moment of anger saves a thousand moments of regret.,angry',
#  '"Never do anything when you are in a temper, for you will do everything wrong.",angry',
#  '"Don’t get mad, smile and creep them out instead.",angry',
#  'The strong man is not the good wrestler; the strong man is only the one who controls himself when he is angry.,angry',
#  '"Anger makes dull men witty, but it keeps them poor.",angry',
#  'A man is about as big as the things that make him angry.,angry',
#  'Anger repressed can poison a relationship as surely as the cruelest words.,angry',
#  '"No matter how long you know someone, they eventually show their true colors.",angry',
#  'May I kill you in the morning?,angry',
#  'Is getting close to just walking away?,angry',
#  'Did you ever just want to slap the stupid out of someone?,angry',
#  '"Is singing, if you’re angry & you know it punches their face…",angry',
#  'Telling someone to calm down just makes them so much angrier.,angry',
#  '"Your mistake is letting me go, my mistake was letting you in.",angry',
#  '']

# %%
'''
Example for dry run : '16/08/18, 20:09 - '

\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s-\s

the first part "d{1,2}" this means here we can have one or 2 digits
then after we have "/"
then after we have "d{1,2}" again,same we can have one or 2 digits
then after we have "/"
then after we have "d{2,4}" here we check for 2 or more digits
then we have a space represented as "\s"
then we have hour representation it can take either one or 2 digits 
then we have a seperator ":" 
and the pattern repeats so on..

'''

# username and message in different col

pattern = '\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s-\s'
messages = re.split(pattern,data)[1:]
print(len(messages))

## extracting dates as well in different col

dates = re.findall(pattern,data)
print(len(dates))
# Out:
# 0
# 0

# %%
# this is a simple time string,we will appply this kind of transformation
# inorder to get the date and the time for our analysis

string = '16/08/18, 20:09 - '
string = string.split(',')
date,time = string[0],string[1]
time = time.split('-')
time = time[0].strip()
print(date+" and "+time)
# Out:
# 16/08/18 and 20:09

# %%
# this function is to seperate the time and date

def gettimeanddate(string):
    string = string.split(',')
    date,time = string[0],string[1]
    time = time.split('-')
    time = time[0].strip()
    
    return date+" "+time

# %%
# creating a dataframe for messages and their dates

df = pd.DataFrame({'user_messages':messages,
                   'message_date':dates})

df['message_date'] = df['message_date'].apply(lambda text:gettimeanddate(text))
df.rename(columns={'message_date':'date'},inplace=True)

df.head()
# Out:
#                                        user_messages            date
# 0  Messages and calls are end-to-end encrypted. N...  16/08/18 20:09
# 1  Chinmayee created group "AGI OFFICIAL@IT 2018-...  16/08/18 20:09
# 2                              Chinmayee added you\n  16/08/18 20:09
# 3           Chinmayee: Hello this is official grup\n  16/08/18 20:09
# 4                            Jagss: Chusinam leaaa\n  16/08/18 20:10

# %%
df['user_messages']
# Out:
# 0       Messages and calls are end-to-end encrypted. N...
# 1       Chinmayee created group "AGI OFFICIAL@IT 2018-...
# 2                                   Chinmayee added you\n
# 3                Chinmayee: Hello this is official grup\n
# 4                                 Jagss: Chusinam leaaa\n
#                               ...
# 9198    +91 79950 77079: 12B1 - registration Completed...
# 9199    Asha Ma'am: 1275 and 1288 do respond please .....
# 9200                           Manoj: 75 registered mam\n
# 9201                              +91 6304 605 703 left\n
# 9202    Nagalakshmi Ma'am 🐍💲: Dear  students,\nGood mo...
# Name: user_messages, Length: 9203, dtype: object

# %%
'''
if we observe the usermessage,we find that the 
username is attached with the user message,so i need to get rid
of this,for that i will use the concept of the regular expression

sample of the regular expression output

['', 'Chinmayee', 'Hello this is official grup\n']

so here we can see that the username is at index 1 and message is at index2

sometimes it happens that we get the group notification,so 
for that case we have to handle it accordingly!


 Chinmayee: Hello this is official grup
 
 Chinmayee added you\n-->['Chinmayee added you','\n']

'''

users = []
messages = []

for message in df['user_messages']:
    
    entry = re.split('([\w\W]+?):\s', message)
    if entry[1:]:
        users.append(entry[1])
        messages.append(entry[2])

        
    else:
        users.append('Group Notification')
        messages.append(entry[0])
        
        
df['User'] = users
df['message'] = messages


def getstring(text):
    return text.split('\n')[0]

df['message'] = df['message'].apply(lambda text:getstring(text))


df = df.drop(['user_messages'],axis=1)
df = df[['message','date','User']]

df = df.rename(columns={'message':'Message',
                       'date':'Date'})



df.head()
# Out:
#                                              Message            Date  \
# 0  Messages and calls are end-to-end encrypted. N...  16/08/18 20:09
# 1  Chinmayee created group "AGI OFFICIAL@IT 2018-22"  16/08/18 20:09
# 2                                Chinmayee added you  16/08/18 20:09
# 3                        Hello this is official grup  16/08/18 20:09
# 4                                     Chusinam leaaa  16/08/18 20:10
#
#                  User
# 0  Group Notification
# 1  Group Notification
# 2  Group Notification
# 3           Chinmayee
# 4               Jagss

# %%
16/08/18 20:09
    
YYYY-MM-DD

# %%
df.shape
# Out:
# (9203, 3)

# %%
df['Only date'] = pd.to_datetime(df['Date']).dt.date

df['Year'] = pd.to_datetime(df['Date']).dt.year

df['Month_num'] = pd.to_datetime(df['Date']).dt.month

df['Month'] = pd.to_datetime(df['Date']).dt.month_name()

df['Day'] = pd.to_datetime(df['Date']).dt.day

df['Day_name'] = pd.to_datetime(df['Date']).dt.day_name()


df['Hour'] = pd.to_datetime(df['Date']).dt.hour

df['Minute'] = pd.to_datetime(df['Date']).dt.minute


df.head()
# Out:
#                                              Message            Date  \
# 0  Messages and calls are end-to-end encrypted. N...  16/08/18 20:09
# 1  Chinmayee created group "AGI OFFICIAL@IT 2018-22"  16/08/18 20:09
# 2                                Chinmayee added you  16/08/18 20:09
# 3                        Hello this is official grup  16/08/18 20:09
# 4                                     Chusinam leaaa  16/08/18 20:10
#
#                  User   Only date  Year  Month_num   Month  Day  Day_name  \
# 0  Group Notification  2018-08-16  2018          8  August   16  Thursday
# 1  Group Notification  2018-08-16  2018          8  August   16  Thursday
# 2  Group Notification  2018-08-16  2018          8  August   16  Thursday
# 3           Chinmayee  2018-08-16  2018          8  August   16  Thursday
# 4               Jagss  2018-08-16  2018          8  August   16  Thursday
#
#    Hour  Minute
# 0    20       9
# 1    20       9
# 2    20       9
# 3    20       9
# 4    20      10

# %%
df[df['User'] == 'Jagss']
# Out:
#                          Message            Date   User   Only date  Year  \
# 4                 Chusinam leaaa  16/08/18 20:10  Jagss  2018-08-16  2018
# 12      Adhea kadha cheppindhiii  16/08/18 20:11  Jagss  2018-08-16  2018
# 60                      Not more  17/08/18 10:02  Jagss  2018-08-17  2018
# 118                      Room no  17/08/18 23:01  Jagss  2018-08-17  2018
# 153            We are in B bloCK  18/08/18 09:55  Jagss  2018-08-18  2018
# ...                          ...             ...    ...         ...   ...
# 8859               1297 done sir  13/09/21 17:04  Jagss  2021-09-13  2021
# 8873                  18h61a1297  13/09/21 18:34  Jagss  2021-09-13  2021
# 9014         1292 registered mam  16/09/21 13:35  Jagss  2021-09-16  2021
# 9065                  18h61a1297  16/09/21 22:30  Jagss  2021-09-16  2021
# 9150  1297_Completed mam 19-0921  20/09/21 11:53  Jagss  2021-09-20  2021
#
#       Month_num      Month  Day  Day_name  Hour  Minute
# 4             8     August   16  Thursday    20      10
# 12            8     August   16  Thursday    20      11
# 60            8     August   17    Friday    10       2
# 118           8     August   17    Friday    23       1
# 153           8     August   18  Saturday     9      55
# ...         ...        ...  ...       ...   ...     ...
# 8859          9  September   13    Monday    17       4
# 8873          9  September   13    Monday    18      34
# 9014          9  September   16  Thursday    13      35
# 9065          9  September   16  Thursday    22      30
# 9150          9  September   20    Monday    11      53
#
# [162 rows x 11 columns]

# %%
words = []
for message in df['Message']:
    words.extend(message.split())
    
print(len(words))
# Out:
# 44880

# %%
words
# Out:
# ['Messages',
#  'and',
#  'calls',
#  'are',
#  'end-to-end',
#  'encrypted.',
#  'No',
#  'one',
#  'outside',
#  'of',
#  'this',
#  'chat,',
#  'not',
#  'even',
#  'WhatsApp,',
#  'can',
#  'read',
#  'or',
#  'listen',
#  'to',
#  'them.',
#  'Tap',
#  'to',
#  'learn',
#  'more.',
#  'Chinmayee',
#  'created',
#  'group',
#  '"AGI',
#  'OFFICIAL@IT',
#  '2018-22"',
#  'Chinmayee',
#  'added',
#  'you',
#  'Hello',
#  'this',
#  'is',
#  'official',
#  'grup',
#  'Chusinam',
#  'leaaa',
#  'Admin',
#  'cheyyi',
#  'First',
#  'Kkkk',
#  'No',
#  'msg',
#  'anything',
#  'except',
#  'studies',
#  'Hello',
#  'sirs',
#  'kuda',
#  'unarru',
#  'Chusi',
#  'matladu',
#  "You're",
#  'now',
#  'an',
#  'admin',
#  'Adhea',
#  'kadha',
#  'cheppindhiii',
#  'Chinmayee',
#  'added',
#  'Abhiramitb',
#  'and',
#  'S*2',
#  'Nc',
#  'job',
#  '+91',
#  '91331',
#  '12884',
#  'left',
#  'Harifriend',
#  'changed',
#  'the',
#  'subject',
#  'from',
#  '"AGI',
#  'OFFICIAL@IT',
#  '2018-22"',
#  'to',
#  '"ONLY',
#  'FOR',
#  'STUDIES"',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  '+91',
#  '6309',
#  '604',
#  '570',
#  'added',
#  '+91',
#  '91331',
#  '12884',
#  'You',
#  'added',
#  'Ali',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  '<Media',
#  'omitted>',
#  'This',
#  'is',
#  'the',
#  'workshop',
#  'manual',
#  'everyone',
#  'plz',
#  'r8',
#  'your',
#  'respective',
#  'trait',
#  'in',
#  'the',
#  'record',
#  'with',
#  'diagrams..',
#  'Today',
#  'is',
#  'holiday',
#  'guys',
#  'R8',
#  'Holiday',
#  'guys',
#  'Krishna',
#  '2',
#  'marrow',
#  'Unada',
#  'That',
#  'is',
#  'not',
#  'yet',
#  'known',
#  'Adhi',
#  'telvad',
#  'inka',
#  'Emaina',
#  'info',
#  'vasthey',
#  'pamputha',
#  '+91',
#  '6309',
#  '604',
#  '570',
#  'added',
#  '+91',
#  '90525',
#  '52661',
#  'and',
#  '+91',
#  '99083',
#  '50196',
#  'Guys',
#  'I',
#  'had',
#  'added',
#  'seniors',
#  'to',
#  'the',
#  'group',
#  'They',
#  'pass',
#  'the',
#  'info',
#  'Kk',
#  'Hlo',
#  'dudes',
#  'This',
#  'is',
#  'Sujith',
#  'U',
#  'r',
#  'senior',
#  'from',
#  'itb',
#  'I',
#  'am',
#  'here',
#  'to',
#  'inform',
#  'about',
#  'u',
#  'r',
#  'dress',
#  'code',
#  'Yes',
#  'Bhai..',
#  'Except',
#  'blazer',
#  ',white',
#  'shirt,black',
#  'pants',
#  'and',
#  'torn',
#  'jeans',
#  'u',
#  'can',
#  'wear',
#  'any',
#  'other',
#  'things',
#  'that',
#  'u',
#  'want',
#  'Kk',
#  'Dress',
#  'code',
#  'for',
#  'girls',
#  'will',
#  'be',
#  'informed',
#  'by',
#  'Harshita',
#  'U',
#  'r',
#  'senior',
#  'Ohk',
#  'bro',
#  'Any',
#  'more',
#  'doubt',
#  's',
#  'Regarding',
#  'to',
#  'freshers',
#  'U',
#  'can',
#  'ask',
#  'me',
#  'I',
#  'will',
#  'be',
#  'available',
#  'today',
#  'Kk',
#  'Bhai..',
#  'Ok',
#  'Bayya',
#  'black',
#  'paint',
#  'kuda',
#  'na',
#  'Not',
#  'allowed',
#  'aa',
#  'Bro',
#  'black',
#  'pants',
#  'kuda',
#  'not',
#  'allowed',
#  'ah?',
#  'That',
#  'mean',
#  'only',
#  'black',
#  'cotton',
#  'pants',
#  'Hey',
#  'guys',
#  '!',
#  'This',
#  'is',
#  'Harshita',
#  'U',
#  'can',
#  'wear',
#  'jeans',
#  'Excited',
#  'for',
#  'tomorrow??',
#  'Ya',
#  'Not',
#  'more',
#  'Nice',
#  '!',
#  'Soooooooo',
#  'do',
#  'all',
#  'the',
#  'girls',
#  'know',
#  'the',
#  'dress',
#  'code?',
#  "It's",
#  'gonna',
#  'be',
#  'funn!',
#  'Ya',
#  'no',
#  'jeans',
#  'crop',
#  'tops',
#  '....',
#  'Oh',
#  'Half',
#  'sarees',
#  'and',
#  'sarees',
#  'also',
#  'Haa',
#  'so',
#  '..the',
#  'dress',
#  'code',
#  'for',
#  'girls',
#  'is',
#  'no',
#  'jeans,',
#  'crop',
#  'tops,',
#  'sarees',
#  'and',
#  'half',
#  'Sarees..',
#  'Wear',
#  'any',
#  'thing',
#  'dressy',
#  'and',
#  'with',
#  'sleeves',
#  ',long',
#  'frocks',
#  'are',
#  'also',
#  'fine',
#  'But',
#  'should',
#  'look',
#  'neat',
#  'Ok',
#  'sister',
#  'Ok',
#  'If',
#  'we',
#  'find',
#  'any',
#  'dress',
#  'that',
#  'is',
#  'awkward',
#  'you',
#  'guys',
#  'will',
#  'be',
#  'sent',
#  'home',
#  'and',
#  'the',
#  'faculty',
#  'is',
#  'very',
#  'firm',
#  'on',
#  'this',
#  'Sister',
#  'Wat',
#  're',
#  '🤷🏻\u200d♀🤷🏻\u200d♀',
#  "What's",
#  'wrong',
#  'in',
#  'tht?',
#  'Makes',
#  'me',
#  'look',
#  'old',
#  ':p',
#  'Lol😂',
#  'Ok',
#  'Harshita',
#  'Find',
#  'some',
#  'other',
#  'name😂😂',
#  '😂😂',
#  'Yeah',
#  'better',
#  '☺😌😌',
#  'He',
#  'he',
#  'amazeeeeee!',
#  'So',
#  'wat',
#  'r',
#  'u',
#  'bachas',
#  'upto',
#  'And',
#  'btw',
#  'I',
#  'almost',
#  'forgot',
#  'You',
#  'guys',
#  'can',
#  'also',
#  'participate',
#  'and',
#  'come',
#  'up',
#  'with',
#  'a',
#  'dance',
#  'or',
#  'something',
#  'If',
#  'u',
#  'have',
#  'something',
#  'in',
#  'mind',
#  'pm',
#  'me',
#  'We',
#  'will',
#  'add',
#  'your',
#  'performance',
#  'in',
#  'the',
#  'event',
#  'schedule.',
#  'So',
#  '4',
#  'pm',
#  'is',
#  'your',
#  'deadline',
#  'before',
#  'that',
#  'you',
#  'guys',
#  'can',
#  'pm',
#  'me',
#  'about',
#  'your',
#  'ideas',
#  'Ha',
#  'ok',
#  'Duppata',
#  'must',
#  'aaa',
#  'People',
#  'get',
#  'your',
#  'dupattas',
#  'and',
#  'wear',
#  'them',
#  'when',
#  'the',
#  'faculty',
#  'is',
#  'around.',
#  'Kk',
#  'Guys',
#  'u',
#  'need',
#  'not',
#  'wear',
#  'black',
#  'cotton',
#  'pant',
#  'U',
#  'can',
#  'wear',
#  'black',
#  'jeans',
#  'Hi',
#  'Any',
#  'more',
#  'participants',
#  'Who',
#  'all',
#  'r',
#  'participating?',
#  'Krishna',
#  'r',
#  'u',
#  'participating?',
#  'Who',
#  'all',
#  'are',
#  'participating',
#  'Yaa',
#  'Dance',
#  'or',
#  'peotry?',
#  'Dance',
#  'One',
#  'grp',
#  'Two',
#  'solo',
#  'Ohhh',
#  'Nc',
#  'all',
#  'd',
#  'best',
#  'Peeps',
#  'I',
#  'got',
#  'some',
#  'PMs',
#  'Anyone',
#  'else',
#  'who',
#  'is',
#  'interested',
#  '<Media',
#  'omitted>',
#  '🤩🤩...Lets',
#  'rock🤘',
#  'People',
#  'Be',
#  'there',
#  'tomorrow',
#  'by',
#  '9am',
#  'And',
#  'gather',
#  'in',
#  'a',
#  'block',
#  'second',
#  'year',
#  'it',
#  'class',
#  'room',
#  "Don't",
#  'go',
#  'to',
#  'the',
#  'auditorium',
#  'directly',
#  'Ok',
#  'Room',
#  'no',
#  'Okay',
#  '😀',
#  "I'll",
#  'text',
#  'the',
#  'room',
#  'no.',
#  'Acha...',
#  'Which',
#  'block',
#  'A',
#  '???',
#  'Yup',
#  'Room',
#  'no',
#  'pls',
#  'A',
#  'block',
#  'Bpharmacy',
#  'auditorium',
#  'We',
#  'know',
#  'that',
#  'Room',
#  'no.????',
#  'Give',
#  'us',
#  'clarity',
#  'about',
#  'where',
#  'we',
#  'should',
#  'gather',
#  'All',
#  'gather',
#  'at',
#  'Ablock',
#  'Ok',
#  'Bpharmacy',
#  '3rd',
#  'or',
#  '4th',
#  'floor',
#  'And',
#  'moreover',
#  'all',
#  'rock',
#  'it',
#  '<Media',
#  'omitted>',
#  'Guys',
#  '207',
#  'or',
#  '206',
#  'Room',
#  'number',
#  'K',
#  'K',
#  'Two',
#  'rooms',
#  'aa',
#  'Guys',
#  'all',
#  'of',
#  'u',
#  'sit',
#  'in',
#  'class',
#  'Only',
#  'Kk',
#  'Seniors',
#  'will',
#  'come',
#  'and',
#  'give',
#  'invitation',
#  'For',
#  'us',
#  'Any',
#  'one',
#  "don't",
#  'go',
#  'to',
#  'any',
#  'block',
#  'go',
#  'to',
#  'our',
#  'block',
#  'And',
#  'sit',
#  'in',
#  'our',
#  'class',
#  'Inform',
#  'to',
#  'all',
#  'Hmm',
#  'No',
#  '206',
#  'and',
#  'no',
#  '207',
#  'Only',
#  '313',
#  'and',
#  '311',
#  "That's",
#  'it',
#  'Guys',
#  'come',
#  'to',
#  'ur',
#  'class',
#  'We',
#  'are',
#  'in',
#  'B',
#  'bloCK',
#  '2nd',
#  'FlOoR',
#  'No',
#  'senior',
#  'is',
#  'asking',
#  'to',
#  'gather',
#  'in',
#  'our',
#  'class',
#  'Hooo',
#  'Okkk',
#  'Pls',
#  'come',
#  'fast',
#  'Ok',
#  '<Media',
#  'omitted>',
#  'Chinmayee',
#  'added',
#  'Ravi',
#  'Raju',
#  'Sir',
#  'Guys',
#  'Full',
#  'enjoyed',
#  'ga',
#  '❤',
#  'How',
#  'r',
#  'performances',
#  'by',
#  'all',
#  'Either',
#  'senior',
#  'or',
#  'junior',
#  'Thope!!',
#  '👌👌👌',
#  'Thop',
#  'ai',
#  'na',
#  'I',
#  'think',
#  'unlimited',
#  'Energy',
#  'Yup',
#  'Krishna',
#  'u',
#  'were',
#  'really',
#  'energetic..',
#  'Tq',
#  'Full',
#  'enjoyed',
#  'Andaru',
#  'enjoy',
#  'chesaraa',
#  'Haa',
#  'bro',
#  'Full',
#  'ga',
#  'TQ',
#  'bro',
#  'for',
#  'providing',
#  'us',
#  'such',
#  'a',
#  'marvelous',
#  'Freshers',
#  'party',
#  'uu',
#  'made',
#  'our',
#  'day',
#  'so',
#  'happy',
#  'TQ',
#  'once',
#  'again',
#  'bro',
#  'Kk',
#  "It's",
#  'my',
#  'responsibility',
#  'Chala',
#  'annaya',
#  'tqsm',
#  'Harifriend',
#  'added',
#  'Irfan,',
#  'Jessica,',
#  'Ke**,',
#  'Laz,',
#  'Narshima,',
#  'Preetham,',
#  'Rishi,',
#  'Sid,',
#  'Srujana,',
#  '+91',
#  '79950',
#  '77079,',
#  '+91',
#  '83329',
#  '96614',
#  'and',
#  '+91',
#  '99483',
#  '03382',
#  'Sujith',
#  'anna',
#  'asal',
#  'unlimited',
#  'ga',
#  'enjoy',
#  'chesam',
#  'Tq',
#  'anna',
#  'Very',
#  'much',
#  'U',
#  'guys',
#  'were',
#  'really',
#  'enthusiastic..',
#  'Neenokadinae',
#  'Kadu',
#  'raa',
#  'Maa',
#  'friends,sir',
#  ',madam',
#  'valuukuda',
#  'help',
#  'chesaru',
#  'Kk',
#  'Edhaina',
#  'okkadi',
#  'thone',
#  'modhal',
#  'avthundhi',
#  'aa',
#  'okka',
#  'divi',
#  'maku',
#  'nuv',
#  'Andaruuu',
#  'satisfied',
#  'kada',
#  'Only',
#  'satisfied',
#  'ai',
#  'na',
#  'So',
#  'I',
#  'am',
#  'also',
#  'satisfied',
#  'Haa',
#  'anna',
#  'Anna',
#  'asal',
#  'memorable',
#  'day',
#  'for',
#  'lifetime',
#  'Full',
#  'ga👌👍',
#  'Asal',
#  'thop',
#  'enjoy',
#  'chesnam',
#  'anna',
#  'Soo',
#  'glad',
#  'you',
#  'guys',
#  'liked',
#  'it!',
#  '<Media',
#  'omitted>',
#  'Ss',
#  'ra',
#  "It's",
#  'came',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  'Haa',
#  'Stop',
#  'unnecessary',
#  'discussions',
#  'in',
#  'this',
#  'group..',
#  '+91',
#  '91331',
#  '12884',
#  'left',
#  'Sry',
#  'sir',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  '+91',
#  '90525',
#  '52661',
#  'left',
#  'Good',
#  'evening',
#  'everyone',
#  '<Media',
#  'omitted>',
#  'What',
#  'we',
#  'must',
#  'do',
#  'by',
#  'this',
#  'PDF',
#  'U',
#  'have',
#  'to',
#  'write',
#  'about',
#  'your',
#  'trade',
#  'in',
#  'the',
#  'workshop',
#  'record',
#  'along',
#  'with',
#  'diagrams',
#  '+91',
#  '6309',
#  '604',
#  '570',
#  'changed',
#  'this',
#  "group's",
#  'icon',
#  '+91',
#  '6309',
#  '604',
#  '570',
#  'changed',
#  'the',
#  'group',
#  'description',
#  '+91',
#  '6309',
#  '604',
#  '570',
#  'changed',
#  'the',
#  'subject',
#  'from',
#  '"ONLY',
#  'FOR',
#  'STUDIES"',
#  'to',
#  '"AGI@buddies"',
#  '+91',
#  '6309',
#  '604',
#  '570',
#  'changed',
#  'the',
#  'subject',
#  'from',
#  '"AGI@buddies"',
#  'to',
#  '"AGI@buddies👌😜♥️"',
#  '+91',
#  '99083',
#  '50196',
#  'left',
#  'Guys',
#  'pls',
#  'donate',
#  'money',
#  'for',
#  'kerala',
#  'Eppudu',
#  'ekkada',
#  'While',
#  'doing',
#  'prayer',
#  'keep',
#  'kerala',
#  'in',
#  'ur',
#  'heart',
#  'and',
#  'do',
#  'that',
#  'Paytm,',
#  'phone',
#  'pe,',
#  'tez',
#  'Or',
#  'NSS',
#  'Okk',
#  'Chesina',
#  'raaa',
#  'OK',
#  'mama',
#  '<Media',
#  'omitted>',
#  'Ninu',
#  'kuda',
#  'Chesa',
#  'Download',
#  'Databuddy',
#  'App',
#  'and',
#  'get',
#  'upto',
#  'Rs.',
#  '215',
#  'Paytm',
#  'Cash.',
#  'Click',
#  'https://databuddy.co/i/?id=12011445',
#  'Download',
#  'the',
#  'app',
#  'And',
#  ...]

# %%
df[(df['Message'] == '<Media omitted>')&(df['User'] == 'Jagss')].shape
# Out:
# (27, 11)

# %% [raw]
# 'Chinmayee created group "AGI OFFICIAL@IT 2018-22"',
#        'Chinmayee added you', ..., '75 registered mam',
#
#
# 'Chinmayee created group "AGI OFFICIAL@IT 2018-22"
#        'Chinmayee added you', ..., '75 registered mam',

# %%
df['Message'].unique()
# Out:
# array(['Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.',
#        'Chinmayee created group "AGI OFFICIAL@IT 2018-22"',
#        'Chinmayee added you', ..., '75 registered mam',
#        '+91 6304 605 703 left', 'Dear  students,'], dtype=object)

# %%
df[df['Message']=='<Media omitted>']
# Out:
#               Message            Date              User   Only date  Year  \
# 21    <Media omitted>  16/08/18 21:40              Meet  2018-08-16  2018
# 111   <Media omitted>  17/08/18 17:05   +91 99083 50196  2018-08-17  2018
# 134   <Media omitted>  18/08/18 07:50  +91 6309 604 570  2018-08-18  2018
# 160   <Media omitted>  18/08/18 10:00             Jagss  2018-08-18  2018
# 198   <Media omitted>  18/08/18 20:17        Harifriend  2018-08-18  2018
# ...               ...             ...               ...         ...   ...
# 9020  <Media omitted>  16/09/21 15:27     Ravi Raju Sir  2021-09-16  2021
# 9021  <Media omitted>  16/09/21 15:28     Ravi Raju Sir  2021-09-16  2021
# 9097  <Media omitted>  18/09/21 10:56       Prudhvi Raj  2021-09-18  2021
# 9099  <Media omitted>  19/09/21 10:07     Ravi Raju Sir  2021-09-19  2021
# 9176  <Media omitted>  22/09/21 13:14        Ananad Sir  2021-09-22  2021
#
#       Month_num      Month  Day   Day_name  Hour  Minute
# 21            8     August   16   Thursday    21      40
# 111           8     August   17     Friday    17       5
# 134           8     August   18   Saturday     7      50
# 160           8     August   18   Saturday    10       0
# 198           8     August   18   Saturday    20      17
# ...         ...        ...  ...        ...   ...     ...
# 9020          9  September   16   Thursday    15      27
# 9021          9  September   16   Thursday    15      28
# 9097          9  September   18   Saturday    10      56
# 9099          9  September   19     Sunday    10       7
# 9176          9  September   22  Wednesday    13      14
#
# [1393 rows x 11 columns]

# %%
df['User'].value_counts().head()
# Out:
# Asha Ma'am            869
# Group Notification    778
# +91 85559 80272       657
# Ravi Raju Sir         588
# Chinmayee             438
# Name: User, dtype: int64

# %%
counts = df['User'].value_counts().head()
plt.figure(figsize=(15,7))
plt.bar(counts.index,counts.values)
plt.xticks(rotation = 'vertical')
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# computationally heavy

wordmap = {}
for message in df['Message']:
    dummy = message.split()
    for word in dummy:
        if word in wordmap:
            wordmap[word]+=1
            
        else:
            wordmap[word] = 1
            
            
wordmap = dict(sorted(wordmap.items(),key = lambda x:x[1],reverse = True))

wordmap
# Out:
# {'to': 1512,
#  '<Media': 1393,
#  'omitted>': 1393,
#  'the': 786,
#  'with': 715,
#  'for': 606,
#  'learn': 602,
#  'code': 602,
#  'Tap': 597,
#  'Your': 595,
#  'more.': 594,
#  'security': 592,
#  'changed.': 592,
#  'This': 508,
#  'join': 506,
#  'message': 501,
#  'deleted': 488,
#  'are': 481,
#  'was': 480,
#  'and': 458,
#  '+91': 376,
#  'All': 375,
#  'in': 373,
#  'immediately': 337,
#  'is': 316,
#  'class': 298,
#  'you': 268,
#  'requested': 265,
#  'sir': 264,
#  'of': 254,
#  'all': 214,
#  'Dear': 200,
#  'will': 196,
#  'please': 194,
#  'students': 191,
#  'Please': 189,
#  'your': 184,
#  'Join': 182,
#  'not': 180,
#  'mam': 161,
#  'u': 160,
#  'this': 156,
#  'on': 147,
#  'have': 144,
#  'by': 143,
#  'as': 136,
#  'I': 132,
#  'it': 129,
#  'ur': 129,
#  'Guys': 128,
#  '-': 124,
#  'session': 123,
#  'be': 122,
#  'Good': 122,
#  'Ok': 119,
#  'from': 109,
#  'Thank': 108,
#  'training': 107,
#  'we': 103,
#  'who': 103,
#  'register': 101,
#  'registered': 100,
#  'only': 93,
#  'added': 91,
#  'at': 90,
#  'any': 88,
#  'link': 84,
#  'a': 83,
#  'that': 82,
#  'Sir': 81,
#  'if': 78,
#  'guys': 76,
#  'can': 71,
#  'need': 70,
#  'one': 67,
#  'or': 65,
#  'also': 64,
#  'If': 64,
#  'Remaining': 64,
#  'me': 63,
#  'write': 63,
#  'students,': 62,
#  'mail': 61,
#  'complete': 61,
#  '2': 60,
#  'there': 60,
#  'lab': 60,
#  'left': 59,
#  'submit': 59,
#  'take': 58,
#  'test': 58,
#  'come': 57,
#  'attend': 57,
#  'get': 56,
#  'tomorrow': 56,
#  '79950': 56,
#  '.': 56,
#  '77079': 55,
#  'classes': 55,
#  'You': 53,
#  'joined': 53,
#  'Only': 52,
#  'respond': 50,
#  'plz': 49,
#  'time': 49,
#  'received': 49,
#  'completed': 49,
#  '85559': 49,
#  '80272': 49,
#  'bring': 48,
#  'disqualified': 48,
#  'our': 47,
#  'check': 47,
#  'exam': 47,
#  'present': 47,
#  'today': 46,
#  'should': 46,
#  'evening': 46,
#  '1': 46,
#  'record': 45,
#  'members': 45,
#  'had': 44,
#  'so': 44,
#  'And': 44,
#  'interested': 44,
#  'soon': 44,
#  "ma'am": 44,
#  'dwdm': 44,
#  'Jagss': 43,
#  'above': 43,
#  'do': 42,
#  'registration': 42,
#  'morning': 42,
#  'without': 42,
#  'fill': 42,
#  'We': 41,
#  'Congratulations': 41,
#  'AM': 41,
#  'everyone': 40,
#  'form': 40,
#  'am': 39,
#  'Yes': 39,
#  'no': 39,
#  'program': 39,
#  'last': 38,
#  'about': 37,
#  'post': 37,
#  'immediately..': 37,
#  'now': 36,
#  'Mam': 36,
#  'those': 36,
#  'The': 36,
#  'all,': 36,
#  'Round': 36,
#  'group': 35,
#  'changed': 35,
#  'r': 35,
#  'college': 35,
#  'before': 34,
#  'has': 34,
#  'Today': 33,
#  'Kk': 33,
#  'pls': 33,
#  'i': 33,
#  'assignment': 33,
#  '✋': 33,
#  'No': 32,
#  'English': 32,
#  'immediately.': 32,
#  'remaining': 32,
#  'know': 31,
#  'pm': 31,
#  'them': 31,
#  'records': 31,
#  'details': 31,
#  'frnds': 31,
#  '15th': 31,
#  'login': 31,
#  'inform': 30,
#  'For': 30,
#  'Those': 30,
#  'using': 30,
#  'ML': 30,
#  'number': 29,
#  'my': 29,
#  'round': 29,
#  'LRQA': 29,
#  'year': 28,
#  "don't": 28,
#  'Notpaid': 28,
#  'possible': 28,
#  'java': 28,
#  'PM': 28,
#  'block': 27,
#  'online': 27,
#  'Students,': 27,
#  'anyone': 27,
#  'given': 26,
#  'their': 26,
#  'Chinmayee': 25,
#  '6309': 25,
#  '604': 25,
#  '570': 25,
#  'participate': 25,
#  'A': 25,
#  'name': 25,
#  'date': 25,
#  '18H61A1285': 25,
#  'an': 24,
#  'here': 24,
#  'work': 24,
#  "Ma'am": 24,
#  'Everyone': 24,
#  'Registered': 24,
#  'pay': 23,
#  'roll': 23,
#  ',': 23,
#  'thank': 23,
#  'fail': 23,
#  '18H61A1282': 23,
#  '18H61A1291': 23,
#  '18H61A12A8': 23,
#  'Who': 22,
#  'Ravi': 22,
#  'Raju': 22,
#  'pdf': 22,
#  '10': 22,
#  'mid': 22,
#  'Aditya': 22,
#  '*New*': 22,
#  'google': 22,
#  'TCS': 22,
#  '18H61A1289': 22,
#  'codechef': 22,
#  '18H61A1294': 22,
#  '18H61A1264': 22,
#  '18H61A1267': 22,
#  '18H61A1263': 22,
#  '18H61A1274': 22,
#  'must': 21,
#  'book': 21,
#  'after': 21,
#  'programs': 21,
#  'afternoon': 21,
#  'questions': 21,
#  'these': 21,
#  'Narshima': 21,
#  'Raj': 21,
#  'Cisco': 21,
#  '18h61a12b3': 21,
#  '18H61A1278': 21,
#  'So': 20,
#  'us': 20,
#  'tmrw': 20,
#  'did': 20,
#  'send': 20,
#  '3': 20,
#  'attendance': 20,
#  'list': 20,
#  'end': 20,
#  'Prudhvi': 20,
#  'assemble': 20,
#  '10:00': 20,
#  '👆': 20,
#  '18H61A1296': 20,
#  'Ali': 19,
#  'more': 19,
#  'which': 19,
#  'ever': 19,
#  'new': 19,
#  'mandatory': 19,
#  '18H61A1272': 19,
#  '18h61a1299': 19,
#  'U': 18,
#  'day': 18,
#  'share': 18,
#  'first': 18,
#  'question': 18,
#  'same': 18,
#  'forget': 18,
#  'sheet': 18,
#  '20': 18,
#  'eligible': 18,
#  '5': 18,
#  'issue': 18,
#  '18H61A1292': 18,
#  '18H61A12B7': 18,
#  '18h61a1286': 18,
#  '18H61A1271': 18,
#  "group's": 17,
#  "didn't": 17,
#  'id': 17,
#  'too': 17,
#  'what': 17,
#  'they': 17,
#  'papers': 17,
#  'After': 17,
#  '95026': 17,
#  '09678': 17,
#  'course': 17,
#  'revision': 17,
#  '18h61a1297': 17,
#  '18H61A1262': 17,
#  '17': 17,
#  'round-1': 17,
#  'sept': 17,
#  'Abhiramitb': 16,
#  'some': 16,
#  'got': 16,
#  'team': 16,
#  'through': 16,
#  'meet': 16,
#  'dont': 16,
#  'hour': 16,
#  'but': 16,
#  'regarding': 16,
#  'then': 16,
#  'Manoj': 16,
#  'Irfan': 16,
#  'These': 16,
#  'out': 16,
#  'having': 16,
#  'Rishi': 16,
#  'Students': 16,
#  'fail.': 16,
#  '9': 16,
#  '19h65a1208': 16,
#  'Student,': 16,
#  '18H61A1293': 16,
#  '18h61a12a0': 16,
#  '18H61A1283': 16,
#  '18H61A1270': 16,
#  '18h61a1287': 16,
#  '18H61A1288': 16,
#  '✋🏻': 16,
#  'ins': 16,
#  'other': 15,
#  'find': 15,
#  'very': 15,
#  'ok': 15,
#  "Don't": 15,
#  'conducted': 15,
#  'In': 15,
#  'Tomorrow': 15,
#  'people': 15,
#  'It': 15,
#  'make': 15,
#  'books': 15,
#  'next': 15,
#  'applied': 15,
#  'few': 15,
#  'two': 15,
#  'certificate': 15,
#  'assessment': 15,
#  '18H61A12C0': 15,
#  '18H61A1277': 15,
#  '18H61A1275': 15,
#  '18H61A12B9': 15,
#  '18H61A1290': 15,
#  '18H61A1266': 15,
#  'AECS': 15,
#  '18H61A1298': 15,
#  '||': 15,
#  'msg': 14,
#  'Krishna': 14,
#  'Not': 14,
#  "It's": 14,
#  'sent': 14,
#  'event': 14,
#  'best': 14,
#  'room': 14,
#  '3rd': 14,
#  'give': 14,
#  'request': 14,
#  'done': 14,
#  'may': 14,
#  'clg': 14,
#  'exams': 14,
#  'paper': 14,
#  'taken': 14,
#  '79939': 14,
#  '58391': 14,
#  'absent': 14,
#  'everyone,': 14,
#  'student,': 14,
#  'Mid-3': 14,
#  '18H61A1273': 14,
#  'Disqualified': 14,
#  '91331': 13,
#  '12884': 13,
#  'subject': 13,
#  'want': 13,
#  'go': 13,
#  'Tq': 13,
#  'help': 13,
#  'collect': 13,
#  'its': 13,
#  '81': 13,
#  'getting': 13,
#  'information': 13,
#  '96523': 13,
#  '49806': 13,
#  'many': 13,
#  '6': 13,
#  '96030': 13,
#  '20610': 13,
#  'Complete': 13,
#  '61': 13,
#  'Plz': 13,
#  'previous': 13,
#  '..': 13,
#  'table': 13,
#  'hall': 13,
#  'notes': 13,
#  'IT': 13,
#  'good': 13,
#  '95503': 13,
#  '48124': 13,
#  'Mid': 13,
#  'call': 13,
#  'start': 13,
#  '?': 13,
#  'unit': 13,
#  'program.': 13,
#  '8': 13,
#  'Registration': 13,
#  'Ashwita': 13,
#  '25': 13,
#  'CN': 13,
#  '18h61a1268': 13,
#  '18H61A1280': 13,
#  'Completed': 13,
#  '18h61a12b5': 13,
#  'na': 12,
#  '4': 12,
#  'Okay': 12,
#  '2nd': 12,
#  'once': 12,
#  '83329': 12,
#  '96614': 12,
#  'fee': 12,
#  'like': 12,
#  'going': 12,
#  'link.': 12,
#  '84650': 12,
#  '80632': 12,
#  'names': 12,
#  'already': 12,
#  'till': 12,
#  'Shushmita': 12,
#  'pps': 12,
#  'Register': 12,
#  '12': 12,
#  'every': 12,
#  'numbers': 12,
#  '15': 12,
#  'lost': 12,
#  'class.': 12,
#  'qualified': 12,
#  'Anurag': 12,
#  'test.': 12,
#  'problem': 12,
#  'scheduled': 12,
#  'today.': 12,
#  '18H61A12A5': 12,
#  'AI': 12,
#  'TASK,': 12,
#  '18H61A12B0': 12,
#  '18h61a12b2': 12,
#  '18h61a12b4': 12,
#  '19h65a1209': 12,
#  'https://meet.google.com/lookup/g72jwq6pyb?authuser=0&hs=179': 12,
#  'OOAD': 12,
#  'network': 12,
#  'holiday': 11,
#  'wear': 11,
#  'Any': 11,
#  'How': 11,
#  'keep': 11,
#  'OK': 11,
#  'app': 11,
#  'observation': 11,
#  'Manohar': 11,
#  'tomorrow.': 11,
#  'ticket': 11,
#  'ready': 11,
#  'Monday': 11,
#  'marks': 11,
#  'dear': 11,
#  'less': 11,
#  'Last': 11,
#  'internal': 11,
#  '99484': 11,
#  '61869': 11,
#  'python': 11,
#  'status': 11,
#  'CD': 11,
#  '18H61A12A4': 11,
#  '19H65A1212': 11,
#  'training.': 11,
#  'Training': 11,
#  '18h61a1279': 11,
#  '83': 11,
#  'INS': 11,
#  'anything': 10,
#  'bro': 10,
#  'faculty': 10,
#  'Ha': 10,
#  'participating': 10,
#  'icon': 10,
#  'doing': 10,
#  'phone': 10,
#  'vocabulary': 10,
#  'small': 10,
#  'As': 10,
#  'time..': 10,
#  'Kiran': 10,
#  'important': 10,
#  'prepare': 10,
#  'wait': 10,
#  'invite': 10,
#  '1st': 10,
#  '...': 10,
#  '11': 10,
#  'Happy': 10,
#  'madam': 10,
#  'student': 10,
#  'time.': 10,
#  'into': 10,
#  'opportunity': 10,
#  'Self': 10,
#  'return': 10,
#  '65': 10,
#  "I'm": 10,
#  'both': 10,
#  'Rk': 10,
#  '18': 10,
#  'required': 10,
#  'II': 10,
#  'conduct': 10,
#  'Java': 10,
#  'technical': 10,
#  'meeting': 10,
#  'Morning': 10,
#  '19h65a1212': 10,
#  '18H61A1284': 10,
#  '19h65a1210': 10,
#  '18h61a12b8': 10,
#  '18H61A1281': 10,
#  '62': 10,
#  'CLASS': 10,
#  '9:00': 10,
#  'Hello': 9,
#  'Hlo': 9,
#  'ask': 9,
#  'Hi': 9,
#  'auditorium': 9,
#  'What': 9,
#  'asked': 9,
#  'Reddy': 9,
#  'said': 9,
#  'events': 9,
#  'file': 9,
#  'held': 9,
#  'Vishwam': 9,
#  'correct': 9,
#  'page': 9,
#  '&': 9,
#  'section': 9,
#  'Tejika': 9,
#  'use': 9,
#  'Jessica': 9,
#  'than': 9,
#  'otherwise': 9,
#  'early': 9,
#  'Do': 9,
#  'Interested': 9,
#  'onwards': 9,
#  'DM': 9,
#  'submitted': 9,
#  'structures': 9,
#  'placement': 9,
#  'frnds,': 9,
#  'DLD': 9,
#  'contest': 9,
#  'Ravichandra': 9,
#  'update': 9,
#  '81858': 9,
#  '72781': 9,
#  '76759': 9,
#  '49408': 9,
#  'I’m': 9,
#  'course.': 9,
#  'Lab': 9,
#  'started': 9,
#  '19H65A1207': 9,
#  'MEFA': 9,
#  'https://rebrand.ly/IT-A-B': 9,
#  'mails': 9,
#  'Pl': 9,
#  '30': 9,
#  '72': 9,
#  '18H61A12A3': 9,
#  '18h61a1280': 9,
#  '18H61A12B1': 9,
#  '18H61A1269': 9,
#  '18H61A12A9': 9,
#  'All,': 9,
#  'Morning,': 9,
#  '89': 9,
#  'contest.': 9,
#  '71': 9,
#  '18h61a1284': 9,
#  'LE': 9,
#  '12:00': 9,
#  'cognizant': 9,
#  'kuda': 8,
#  'workshop': 8,
#  'They': 8,
#  'available': 8,
#  'add': 8,
#  'when': 8,
#  'grp': 8,
#  '9am': 8,
#  'K': 8,
#  'Inform': 8,
#  'Pls': 8,
#  'again': 8,
#  'Very': 8,
#  'much': 8,
#  'PDF': 8,
#  'would': 8,
#  'per': 8,
#  '50': 8,
#  'mobile': 8,
#  'lo': 8,
#  'project': 8,
#  'teams': 8,
#  'Lakshmi': 8,
#  'Ananad': 8,
#  'monday': 8,
#  'Sept': 8,
#  'groups': 8,
#  'Google': 8,
#  'sure': 8,
#  'students.': 8,
#  'it.': 8,
#  '12pm': 8,
#  'following': 8,
#  'topic': 8,
#  'parents': 8,
#  '91103': 8,
#  '54642': 8,
#  'Afternoon': 8,
#  'classes.': 8,
#  'D': 8,
#  'free': 8,
#  'her': 8,
#  'system': 8,
#  'results': 8,
#  'Check': 8,
#  'how': 8,
#  'asap': 8,
#  'classwork': 8,
#  'number.': 8,
#  'note': 8,
#  '24': 8,
#  'solve': 8,
#  'Abhinav': 8,
#  'issues': 8,
#  'exam.': 8,
#  'Shekhar': 8,
#  'internship': 8,
#  'ideathon': 8,
#  'class..': 8,
#  '40': 8,
#  'Online': 8,
#  '22': 8,
#  'starts': 8,
#  'feedback': 8,
#  '19h65a1207': 8,
#  '19h65a1211': 8,
#  'OS': 8,
#  'joined.': 8,
#  'possible.': 8,
#  '82': 8,
#  '18h61a1298': 8,
#  '18H61A1279': 8,
#  '18h61a12a1': 8,
#  '18H61A12A7': 8,
#  '18h61a1269': 8,
#  '18h61a12b1': 8,
#  '63': 8,
#  'DAA': 8,
#  '64': 8,
#  'Le': 8,
#  'completion': 8,
#  'training,': 8,
#  '18h61a12a9': 8,
#  '9:00am': 8,
#  'LTI': 8,
#  'official': 7,
#  'S*2': 7,
#  'respective': 7,
#  'girls': 7,
#  'black': 7,
#  'aa': 7,
#  'better': 7,
#  'up': 7,
#  'second': 7,
#  'Room': 7,
#  "I'll": 7,
#  'text': 7,
#  'B': 7,
#  'fast': 7,
#  'ga': 7,
#  'money': 7,
#  'Laz': 7,
#  'library': 7,
#  'bank': 7,
#  'each': 7,
#  'Is': 7,
#  'open': 7,
#  'email': 7,
#  'forward': 7,
#  'Even': 7,
#  'Why': 7,
#  'introduction': 7,
#  'Roll': 7,
#  'Yesu': 7,
#  "it's": 7,
#  'week': 7,
#  'just': 7,
#  'website': 7,
#  'topics': 7,
#  'refer': 7,
#  'itself': 7,
#  'apply': 7,
#  '35': 7,
#  'Kalyan': 7,
#  'friends': 7,
#  'Try': 7,
#  '🤣': 7,
#  'elcs': 7,
#  "CR's": 7,
#  'because': 7,
#  'semester': 7,
#  'all.': 7,
#  'From': 7,
#  'Because': 7,
#  'external': 7,
#  'task': 7,
#  '❤️': 7,
#  'survey': 7,
#  'coding': 7,
#  'codevita': 7,
#  'attending': 7,
#  'certification': 7,
#  '28': 7,
#  'TASK': 7,
#  '70': 7,
#  '27': 7,
#  'mailids': 7,
#  'min': 7,
#  'responded': 7,
#  'University': 7,
#  'started,': 7,
#  "today's": 7,
#  'https://meet.google.com/cwv-cyef-nrh': 7,
#  'contest,': 7,
#  'HTNO': 7,
#  '14': 7,
#  '18H61A1265': 7,
#  'Network': 7,
#  'hallticket': 7,
#  'Data': 7,
#  'session..': 7,
#  'packet': 7,
#  'Heads': 7,
#  'JLabs/Faculty': 7,
#  '18h61a1276': 7,
#  'IBM': 7,
#  '18h61a12a4': 7,
#  '7': 7,
#  '18h61a1283': 7,
#  '97': 7,
#  '94': 7,
#  '98': 7,
#  '99': 7,
#  '92': 7,
#  '79': 7,
#  '88': 7,
#  '18h61a12b0': 7,
#  'Accenture': 7,
#  'Round-2': 7,
#  'interview': 7,
#  '10:00am': 7,
#  'read': 6,
#  'First': 6,
#  'That': 6,
#  'info': 6,
#  'senior': 6,
#  'informed': 6,
#  'Wat': 6,
#  'upto': 6,
#  'no.': 6,
#  'such': 6,
#  'cards': 6,
#  '90': 6,
#  'Guys,': 6,
#  'skill': 6,
#  'club': 6,
#  '👍': 6,
#  'pic': 6,
#  '??': 6,
#  'Did': 6,
#  'lunch': 6,
#  'fees': 6,
#  'phonetics': 6,
#  'told': 6,
#  'projects': 6,
#  'let': 6,
#  'under': 6,
#  'Chandana': 6,
#  'Hemanth': 6,
#  'well': 6,
#  'leave': 6,
#  'bee': 6,
#  'chapter': 6,
#  'see': 6,
#  '33': 6,
#  'ep': 6,
#  'session.': 6,
#  'reminder': 6,
#  'Srujana': 6,
#  'Preetham': 6,
#  'Teja': 6,
#  'There': 6,
#  'Thanks': 6,
#  'sem': 6,
#  'based': 6,
#  'games': 6,
#  'pages': 6,
#  'side': 6,
#  'Exciting': 6,
#  'Every': 6,
#  'By': 6,
#  'ID': 6,
#  'minutes': 6,
#  'On': 6,
#  'Next': 6,
#  'hod': 6,
#  'Srijan_mobile': 6,
#  'verify': 6,
#  'chemistry': 6,
#  '99122': 6,
#  '36961': 6,
#  '98487': 6,
#  '47911': 6,
#  'hackathon': 6,
#  '93980': 6,
#  '32560': 6,
#  'written': 6,
#  'tests': 6,
#  "won't": 6,
#  'c0': 6,
#  'during': 6,
#  'registration.': 6,
#  'A5': 6,
#  'essentials': 6,
#  'qsn': 6,
#  'Respond': 6,
#  'problems': 6,
#  'hours': 6,
#  'showing': 6,
#  'DS': 6,
#  'lateral': 6,
#  'D-Block': 6,
#  'placements': 6,
#  'attempt': 6,
#  'Nilesh': 6,
#  'regular': 6,
#  'idea': 6,
#  'DBMS': 6,
#  'activated': 6,
#  'FLAT': 6,
#  'joining': 6,
#  'April': 6,
#  '44': 6,
#  'Use': 6,
#  '19': 6,
#  'Student': 6,
#  'rollno': 6,
#  'only.': 6,
#  'Attend': 6,
#  '8.55': 6,
#  'Auditorium': 6,
#  '41': 6,
#  '2:00': 6,
#  '18h61a1281': 6,
#  '18H61A1276': 6,
#  '18H61A12A2': 6,
#  '18H61A12B5': 6,
#  '32': 6,
#  'testing': 6,
#  'Present': 6,
#  'cocubes': 6,
#  '26': 6,
#  '🎊': 6,
#  'URL': 6,
#  'Coordinators,': 6,
#  '78': 6,
#  '86': 6,
#  'EEES': 6,
#  '18H61A12A1': 6,
#  'https://meet.google.com/lookup/et54cmpmkm': 6,
#  '87': 6,
#  '67': 6,
#  '91': 6,
#  'b7': 6,
#  'PM.': 6,
#  'Cognizant': 6,
#  'Genc': 6,
#  'Qualified': 6,
#  '12:00pm': 6,
#  'listen': 5,
#  'them.': 5,
#  'except': 5,
#  'job': 5,
#  'seniors': 5,
#  'pass': 5,
#  'dress': 5,
#  's': 5,
#  'allowed': 5,
#  '!': 5,
#  'Ya': 5,
#  'look': 5,
#  'else': 5,
#  'Which': 5,
#  'where': 5,
#  'floor': 5,
#  'moreover': 5,
#  'sit': 5,
#  'Full': 5,
#  'raa': 5,
#  'ra': 5,
#  'donate': 5,
#  'Or': 5,
#  'Okk': 5,
#  'raaa': 5,
#  'Download': 5,
#  'Click': 5,
#  'leaders': 5,
#  'filled': 5,
#  'selected': 5,
#  'long': 5,
#  'whole': 5,
#  'forwarded': 5,
#  'Meet': 5,
#  'batch': 5,
#  '21': 5,
#  'practice': 5,
#  'order': 5,
#  'useful': 5,
#  'within': 5,
#  'wish': 5,
#  'Jhanavi': 5,
#  'Sai': 5,
#  'writing': 5,
#  'M': 5,
#  'schedule': 5,
#  'assignments': 5,
#  'physics': 5,
#  'AGI': 5,
#  'years': 5,
#  'Now': 5,
#  'laptops': 5,
#  'value': 5,
#  'Nikhil': 5,
#  'Srilekha': 5,
#  'nd': 5,
#  'Hareth': 5,
#  'units': 5,
#  '75': 5,
#  'data': 5,
#  'Our': 5,
#  'Nagalakshmi': 5,
#  '🐍💲': 5,
#  'mini': 5,
#  'Startup': 5,
#  'presents': 5,
#  '"': 5,
#  'boys': 5,
#  'Need': 5,
#  'follow': 5,
#  'Hall': 5,
#  'Just': 5,
#  'english': 5,
#  'New': 5,
#  'maintain': 5,
#  ...}

# %%
# top 20 words used in the whatsapp group

from collections import Counter
words = []
for message in df['Message']:
    words.extend(message.split())
    
wordmap = dict(Counter(words).most_common(20))
wordmap = dict(sorted(wordmap.items(),key=lambda x:x[1],reverse=True))
newdf = pd.DataFrame(wordmap.items())
newdf
# Out:
#            0     1
# 0         to  1512
# 1     <Media  1393
# 2   omitted>  1393
# 3        the   786
# 4       with   715
# 5        for   606
# 6      learn   602
# 7       code   602
# 8        Tap   597
# 9       Your   595
# 10     more.   594
# 11  security   592
# 12  changed.   592
# 13      This   508
# 14      join   506
# 15   message   501
# 16   deleted   488
# 17       are   481
# 18       was   480
# 19       and   458

# %%
a,an,the,you,ok,...

# %%
temp = df[(df['User']!='Group Notification') | (df['User']!='<Media omitted>')]
temp
# Out:
#                                                 Message            Date  \
# 0     Messages and calls are end-to-end encrypted. N...  16/08/18 20:09
# 1     Chinmayee created group "AGI OFFICIAL@IT 2018-22"  16/08/18 20:09
# 2                                   Chinmayee added you  16/08/18 20:09
# 3                           Hello this is official grup  16/08/18 20:09
# 4                                        Chusinam leaaa  16/08/18 20:10
# ...                                                 ...             ...
# 9198                  12B1 - registration Completed sir  23/09/21 16:18
# 9199  1275 and 1288 do respond please ...done with r...  23/09/21 21:53
# 9200                                  75 registered mam  23/09/21 22:28
# 9201                              +91 6304 605 703 left  24/09/21 08:01
# 9202                                    Dear  students,  24/09/21 08:43
#
#                       User   Only date  Year  Month_num      Month  Day  \
# 0       Group Notification  2018-08-16  2018          8     August   16
# 1       Group Notification  2018-08-16  2018          8     August   16
# 2       Group Notification  2018-08-16  2018          8     August   16
# 3                Chinmayee  2018-08-16  2018          8     August   16
# 4                    Jagss  2018-08-16  2018          8     August   16
# ...                    ...         ...   ...        ...        ...  ...
# 9198       +91 79950 77079  2021-09-23  2021          9  September   23
# 9199            Asha Ma'am  2021-09-23  2021          9  September   23
# 9200                 Manoj  2021-09-23  2021          9  September   23
# 9201    Group Notification  2021-09-24  2021          9  September   24
# 9202  Nagalakshmi Ma'am 🐍💲  2021-09-24  2021          9  September   24
#
#       Day_name  Hour  Minute
# 0     Thursday    20       9
# 1     Thursday    20       9
# 2     Thursday    20       9
# 3     Thursday    20       9
# 4     Thursday    20      10
# ...        ...   ...     ...
# 9198  Thursday    16      18
# 9199  Thursday    21      53
# 9200  Thursday    22      28
# 9201    Friday     8       1
# 9202    Friday     8      43
#
# [9203 rows x 11 columns]

# %%
def gettopwords(selecteduser,df):

    # getting the stopwords

    file = open('stop_hinglish.txt','r')
    stopwords = file.read()
    stopwords = stopwords.split('\n')
    
    if selecteduser!='Overall':
        df = df[df['User']==selecteduser]
        
    temp = df[(df['User']!='Group Notification') |
             (df['User']!='<Media omitted>')]
    
    words = []
    
    for message in df['Message']:
        for word in message.lower().split():
            if word not in stopwords:
                words.append(word)
                
    
    mostcommon = pd.DataFrame(Counter(words).most_common(20))
    return mostcommon



mostcommon = gettopwords('Overall',df)

mostcommon
# Out:
#               0     1
# 0        <media  1393
# 1      omitted>  1393
# 2          join   689
# 3         learn   603
# 4          code   602
# 5           tap   597
# 6         more.   594
# 7      security   592
# 8      changed.   592
# 9       message   502
# 10      deleted   488
# 11          +91   376
# 12  immediately   339
# 13        class   312
# 14    requested   266
# 15         dear   211
# 16     students   209
# 17          mam   198
# 18            u   178
# 19           ur   133

# %% [raw]
# !pip install emoji

# %%
import emoji

# %%
def emojihelp(selecteduser,df):
    
    if selecteduser!='Overall':
        df = df[df['User']==selecteduser]
        
    emojis = []
    for message in df['Message']:
        emojis.extend([c for c in message if c in emoji.UNICODE_EMOJI['en']])
        
    
    emojidf = pd.DataFrame(Counter(emojis).most_common(len(Counter(emojis))))
    
    return emojidf


dfmoji = emojihelp('Overall',df)
dfmoji
# Out:
#     0    1
# 0   ✋  183
# 1   🏻   88
# 2   😂   41
# 3   👍   39
# 4   👆   38
# .. ..  ...
# 69  ✨    1
# 70  🔝    1
# 71  🙌    1
# 72  🤟    1
# 73  🖖    1
#
# [74 rows x 2 columns]

# %%
dfmoji.columns = ['Emoji','Count']
dfmoji
# Out:
#    Emoji  Count
# 0      ✋    183
# 1      🏻     88
# 2      😂     41
# 3      👍     39
# 4      👆     38
# ..   ...    ...
# 69     ✨      1
# 70     🔝      1
# 71     🙌      1
# 72     🤟      1
# 73     🖖      1
#
# [74 rows x 2 columns]

# %%
df.head()
# Out:
#                                              Message            Date  \
# 0  Messages and calls are end-to-end encrypted. N...  16/08/18 20:09
# 1  Chinmayee created group "AGI OFFICIAL@IT 2018-22"  16/08/18 20:09
# 2                                Chinmayee added you  16/08/18 20:09
# 3                        Hello this is official grup  16/08/18 20:09
# 4                                     Chusinam leaaa  16/08/18 20:10
#
#                  User   Only date  Year  Month_num   Month  Day  Day_name  \
# 0  Group Notification  2018-08-16  2018          8  August   16  Thursday
# 1  Group Notification  2018-08-16  2018          8  August   16  Thursday
# 2  Group Notification  2018-08-16  2018          8  August   16  Thursday
# 3           Chinmayee  2018-08-16  2018          8  August   16  Thursday
# 4               Jagss  2018-08-16  2018          8  August   16  Thursday
#
#    Hour  Minute
# 0    20       9
# 1    20       9
# 2    20       9
# 3    20       9
# 4    20      10

# %%
'''
We want the count of messages month-wise,
so we will apply group by and then by 
adding reset_index() we will get the 
result in a dataframe format

then we will add the "Year and month columns" 
like "January-2018",so that to analyze the things become simple

'''


def monthtimeline(selecteduser,df):


    temp = df.groupby(['Year','Month_num','Month']).count()['Message'].reset_index().sort_values(['Message'])
    
    time = []
    for i in range(temp.shape[0]):
        time.append(temp['Month'][i]+"-"+str(temp['Year'][i]))
        
    temp['Time'] = time
    
    return temp
# Out:
#     Year  Month_num      Month  Message
# 0   2018          1    January       47
# 1   2018          2   February       35
# 2   2018          3      March       78
# 3   2018          4      April       66
# 4   2018          5        May       29
# 5   2018          6       June       25
# 6   2018          7       July       47
# 7   2018          8     August      520
# 8   2018          9  September      264
# 9   2018         10    October      208
# 10  2018         11   November      247
# 11  2018         12   December       99
# 12  2019          1    January      222
# 13  2019          2   February      207
# 14  2019          3      March      201
# 15  2019          4      April      152
# 16  2019          5        May      123
# 17  2019          6       June      115
# 18  2019          7       July      211
# 19  2019          8     August      200
# 20  2019          9  September      150
# 21  2019         10    October      184
# 22  2019         11   November       82
# 23  2019         12   December      134
# 24  2020          1    January      142
# 25  2020          2   February       56
# 26  2020          3      March      101
# 27  2020          4      April      149
# 28  2020          5        May      154
# 29  2020          6       June       89
# 30  2020          7       July      171
# 31  2020          8     August      354
# 32  2020          9  September      186
# 33  2020         10    October      148
# 34  2020         11   November      155
# 35  2020         12   December      223
# 36  2021          1    January      204
# 37  2021          2   February       84
# 38  2021          3      March      268
# 39  2021          4      April      615
# 40  2021          5        May      444
# 41  2021          6       June      315
# 42  2021          7       July      272
# 43  2021          8     August      721
# 44  2021          9  September      547
# 45  2021         10    October       70
# 46  2021         11   November       49
# 47  2021         12   December       40

# %%
df.head()
# Out:
#                                              Message            Date  \
# 0  Messages and calls are end-to-end encrypted. N...  16/08/18 20:09
# 1  Chinmayee created group "AGI OFFICIAL@IT 2018-22"  16/08/18 20:09
# 2                                Chinmayee added you  16/08/18 20:09
# 3                        Hello this is official grup  16/08/18 20:09
# 4                                     Chusinam leaaa  16/08/18 20:10
#
#                  User   Only date  Year  Month_num   Month  Day  Day_name  \
# 0  Group Notification  2018-08-16  2018          8  August   16  Thursday
# 1  Group Notification  2018-08-16  2018          8  August   16  Thursday
# 2  Group Notification  2018-08-16  2018          8  August   16  Thursday
# 3           Chinmayee  2018-08-16  2018          8  August   16  Thursday
# 4               Jagss  2018-08-16  2018          8  August   16  Thursday
#
#    Hour  Minute
# 0    20       9
# 1    20       9
# 2    20       9
# 3    20       9
# 4    20      10

# %%
1,2,2,3,4,4,4,5,6,7,3,4


1| 2 2 | 3 3| 4 4 4 4 | 5 | 6 | 7

{4 : 4, 3:2 , 2:2,}

# %%
temp = df.groupby(['Year','Month_num','Month']).count()['Message'].reset_index()
temp
# Out:
#     Year  Month_num      Month  Message
# 0   2018          1    January       47
# 1   2018          2   February       35
# 2   2018          3      March       78
# 3   2018          4      April       66
# 4   2018          5        May       29
# 5   2018          6       June       25
# 6   2018          7       July       47
# 7   2018          8     August      520
# 8   2018          9  September      264
# 9   2018         10    October      208
# 10  2018         11   November      247
# 11  2018         12   December       99
# 12  2019          1    January      222
# 13  2019          2   February      207
# 14  2019          3      March      201
# 15  2019          4      April      152
# 16  2019          5        May      123
# 17  2019          6       June      115
# 18  2019          7       July      211
# 19  2019          8     August      200
# 20  2019          9  September      150
# 21  2019         10    October      184
# 22  2019         11   November       82
# 23  2019         12   December      134
# 24  2020          1    January      142
# 25  2020          2   February       56
# 26  2020          3      March      101
# 27  2020          4      April      149
# 28  2020          5        May      154
# 29  2020          6       June       89
# 30  2020          7       July      171
# 31  2020          8     August      354
# 32  2020          9  September      186
# 33  2020         10    October      148
# 34  2020         11   November      155
# 35  2020         12   December      223
# 36  2021          1    January      204
# 37  2021          2   February       84
# 38  2021          3      March      268
# 39  2021          4      April      615
# 40  2021          5        May      444
# 41  2021          6       June      315
# 42  2021          7       July      272
# 43  2021          8     August      721
# 44  2021          9  September      547
# 45  2021         10    October       70
# 46  2021         11   November       49
# 47  2021         12   December       40

# %%
temp = df.groupby(['Year','Month_num','Month']).count()['Message'].reset_index()
temp
# Out:
#     Year  Month_num      Month  Message
# 0   2018          1    January       47
# 1   2018          2   February       35
# 2   2018          3      March       78
# 3   2018          4      April       66
# 4   2018          5        May       29
# 5   2018          6       June       25
# 6   2018          7       July       47
# 7   2018          8     August      520
# 8   2018          9  September      264
# 9   2018         10    October      208
# 10  2018         11   November      247
# 11  2018         12   December       99
# 12  2019          1    January      222
# 13  2019          2   February      207
# 14  2019          3      March      201
# 15  2019          4      April      152
# 16  2019          5        May      123
# 17  2019          6       June      115
# 18  2019          7       July      211
# 19  2019          8     August      200
# 20  2019          9  September      150
# 21  2019         10    October      184
# 22  2019         11   November       82
# 23  2019         12   December      134
# 24  2020          1    January      142
# 25  2020          2   February       56
# 26  2020          3      March      101
# 27  2020          4      April      149
# 28  2020          5        May      154
# 29  2020          6       June       89
# 30  2020          7       July      171
# 31  2020          8     August      354
# 32  2020          9  September      186
# 33  2020         10    October      148
# 34  2020         11   November      155
# 35  2020         12   December      223
# 36  2021          1    January      204
# 37  2021          2   February       84
# 38  2021          3      March      268
# 39  2021          4      April      615
# 40  2021          5        May      444
# 41  2021          6       June      315
# 42  2021          7       July      272
# 43  2021          8     August      721
# 44  2021          9  September      547
# 45  2021         10    October       70
# 46  2021         11   November       49
# 47  2021         12   December       40

# %%
temp.shape
# Out:
# (48, 4)

# %%
str(temp['Month'][0])+"-"+str(temp['Year'][0])
# Out:
# 'January-2018'

# %%
time = []
for i in range(temp.shape[0]):
    time.append(temp['Month'][i]+ "-" +str(temp['Year'][i]))
    
temp['Time'] = time

temp
# Out:
#     Year  Month_num      Month  Message            Time
# 0   2018          1    January       47    January-2018
# 1   2018          2   February       35   February-2018
# 2   2018          3      March       78      March-2018
# 3   2018          4      April       66      April-2018
# 4   2018          5        May       29        May-2018
# 5   2018          6       June       25       June-2018
# 6   2018          7       July       47       July-2018
# 7   2018          8     August      520     August-2018
# 8   2018          9  September      264  September-2018
# 9   2018         10    October      208    October-2018
# 10  2018         11   November      247   November-2018
# 11  2018         12   December       99   December-2018
# 12  2019          1    January      222    January-2019
# 13  2019          2   February      207   February-2019
# 14  2019          3      March      201      March-2019
# 15  2019          4      April      152      April-2019
# 16  2019          5        May      123        May-2019
# 17  2019          6       June      115       June-2019
# 18  2019          7       July      211       July-2019
# 19  2019          8     August      200     August-2019
# 20  2019          9  September      150  September-2019
# 21  2019         10    October      184    October-2019
# 22  2019         11   November       82   November-2019
# 23  2019         12   December      134   December-2019
# 24  2020          1    January      142    January-2020
# 25  2020          2   February       56   February-2020
# 26  2020          3      March      101      March-2020
# 27  2020          4      April      149      April-2020
# 28  2020          5        May      154        May-2020
# 29  2020          6       June       89       June-2020
# 30  2020          7       July      171       July-2020
# 31  2020          8     August      354     August-2020
# 32  2020          9  September      186  September-2020
# 33  2020         10    October      148    October-2020
# 34  2020         11   November      155   November-2020
# 35  2020         12   December      223   December-2020
# 36  2021          1    January      204    January-2021
# 37  2021          2   February       84   February-2021
# 38  2021          3      March      268      March-2021
# 39  2021          4      April      615      April-2021
# 40  2021          5        May      444        May-2021
# 41  2021          6       June      315       June-2021
# 42  2021          7       July      272       July-2021
# 43  2021          8     August      721     August-2021
# 44  2021          9  September      547  September-2021
# 45  2021         10    October       70    October-2021
# 46  2021         11   November       49   November-2021
# 47  2021         12   December       40   December-2021

# %%
temp
# Out:
#     Year  Month_num      Month  Message            Time
# 0   2018          1    January       47    January-2018
# 1   2018          2   February       35   February-2018
# 2   2018          3      March       78      March-2018
# 3   2018          4      April       66      April-2018
# 4   2018          5        May       29        May-2018
# 5   2018          6       June       25       June-2018
# 6   2018          7       July       47       July-2018
# 7   2018          8     August      520     August-2018
# 8   2018          9  September      264  September-2018
# 9   2018         10    October      208    October-2018
# 10  2018         11   November      247   November-2018
# 11  2018         12   December       99   December-2018
# 12  2019          1    January      222    January-2019
# 13  2019          2   February      207   February-2019
# 14  2019          3      March      201      March-2019
# 15  2019          4      April      152      April-2019
# 16  2019          5        May      123        May-2019
# 17  2019          6       June      115       June-2019
# 18  2019          7       July      211       July-2019
# 19  2019          8     August      200     August-2019
# 20  2019          9  September      150  September-2019
# 21  2019         10    October      184    October-2019
# 22  2019         11   November       82   November-2019
# 23  2019         12   December      134   December-2019
# 24  2020          1    January      142    January-2020
# 25  2020          2   February       56   February-2020
# 26  2020          3      March      101      March-2020
# 27  2020          4      April      149      April-2020
# 28  2020          5        May      154        May-2020
# 29  2020          6       June       89       June-2020
# 30  2020          7       July      171       July-2020
# 31  2020          8     August      354     August-2020
# 32  2020          9  September      186  September-2020
# 33  2020         10    October      148    October-2020
# 34  2020         11   November      155   November-2020
# 35  2020         12   December      223   December-2020
# 36  2021          1    January      204    January-2021
# 37  2021          2   February       84   February-2021
# 38  2021          3      March      268      March-2021
# 39  2021          4      April      615      April-2021
# 40  2021          5        May      444        May-2021
# 41  2021          6       June      315       June-2021
# 42  2021          7       July      272       July-2021
# 43  2021          8     August      721     August-2021
# 44  2021          9  September      547  September-2021
# 45  2021         10    October       70    October-2021
# 46  2021         11   November       49   November-2021
# 47  2021         12   December       40   December-2021

# %%
df.head()
# Out:
#                                              Message            Date  \
# 0  Messages and calls are end-to-end encrypted. N...  16/08/18 20:09
# 1  Chinmayee created group "AGI OFFICIAL@IT 2018-22"  16/08/18 20:09
# 2                                Chinmayee added you  16/08/18 20:09
# 3                        Hello this is official grup  16/08/18 20:09
# 4                                     Chusinam leaaa  16/08/18 20:10
#
#                  User   Only date  Year  Month_num   Month  Day  Day_name  \
# 0  Group Notification  2018-08-16  2018          8  August   16  Thursday
# 1  Group Notification  2018-08-16  2018          8  August   16  Thursday
# 2  Group Notification  2018-08-16  2018          8  August   16  Thursday
# 3           Chinmayee  2018-08-16  2018          8  August   16  Thursday
# 4               Jagss  2018-08-16  2018          8  August   16  Thursday
#
#    Hour  Minute
# 0    20       9
# 1    20       9
# 2    20       9
# 3    20       9
# 4    20      10

# %%
temp1 = df['Day_name'].value_counts()

# %%
temp1
# Out:
# Monday       1478
# Tuesday      1406
# Saturday     1373
# Thursday     1350
# Friday       1335
# Wednesday    1280
# Sunday        981
# Name: Day_name, dtype: int64

# %%
list(temp1.index)
# Out:
# ['Monday', 'Tuesday', 'Saturday', 'Thursday', 'Friday', 'Wednesday', 'Sunday']

# %%
list(temp1.values)
# Out:
# [1478, 1406, 1373, 1350, 1335, 1280, 981]

# %%
temp2 = df['Month'].value_counts()

# %%
temp2
# Out:
# August       1795
# September    1147
# April         982
# May           750
# July          701
# March         648
# January       615
# October       610
# June          544
# November      533
# December      496
# February      382
# Name: Month, dtype: int64

# %%
list(temp2.index),list(temp2.values)
# Out:
# (['August',
#   'September',
#   'April',
#   'May',
#   'July',
#   'March',
#   'January',
#   'October',
#   'June',
#   'November',
#   'December',
#   'February'],
#  [1795, 1147, 982, 750, 701, 648, 615, 610, 544, 533, 496, 382])

# %% [raw]
# def monthly_timeline(selected_user,df):
#
#     if selected_user != 'Overall':
#         df = df[df['user'] == selected_user]
#
#     timeline = df.groupby(['year', 'month_num', 'month']).count()['message'].reset_index()
#
#     time = []
#     for i in range(timeline.shape[0]):
#         time.append(timeline['month'][i] + "-" + str(timeline['year'][i]))
#
#     timeline['time'] = time
#
#     return timeline
